# %% [markdown]
# # Welcome
#
# ## Day 1 Agenda: Python data manipulation soup-to-nuts using Pandas
#
# ### Introduction to Pandas

# %% [markdown]
# __Purpose:__ The purpose of this lecture is to explore the extremely powerful Python package - Pandas. We will learn what Pandas is, why it is so useful for Data Scientists, how to use Pandas Series and DataFrames for indexing and manipulation tasks. We will also look at more advanced capabilities like grouping, aggregating, sorting, converting categorical columns, and handling missing values when they exist.
#
# __At the end of this lecture you will be able to:__
# > 1. Understand what the Pandas Package is and what it can be used for
# > 2. Understand the concept of a Pandas Series and Pandas DataFrame and how they can be created, accessed, and manipulated
# > 3. Perform indexing and manipulation (concatenating/merging/joining/reshaping) tasks on Pandas DataFrames
# > 4. Perform advanced tasks on Pandas DataFrames such as aggregating and grouping
# > 5. Perform feature scaling making it so that all columns (features) range over the same values is very helpful for many (but not all) machine learning models. In some cases, scaling along samples is useful, as well.
# > 6. Convert categorical values into numerical values as machine learning algorithms only understand numbers, not categories.
# > 7. Handle missing values as models break when you give them `NaN`s. We will go over some strategies to replace `NaN`s with useful numbers.

# %% [markdown]
# ### What is Pandas?

# %% [markdown]
# __Overview:__
# - __[Pandas](http://pandas.pydata.org/pandas-docs/stable/index.html):__ Pandas is a Python package that provides fast and flexible data structures that are designed to make working with [relational](https://en.wikipedia.org/wiki/Relational_database) or "labeled" data easy and intuitive
# - In the words of [Wes McKinney](https://en.wikipedia.org/wiki/Wes_McKinney), who created Pandas in 2008, and published [this](http://www.dlr.de/sc/Portaldata/15/Resources/dokumente/pyhpc2011/submissions/pyhpc2011_submission_9.pdf) paper in 2011 at PyHPC describing the usefulness and need for Pandas (which was a play on [__Pan__ el __Da__ ta](https://en.wikipedia.org/wiki/Panel_data) )
#
# _"Pandas enables people to analyze and work with data who are not expert computer scientists...the code is intuitive and accessible. Pandas helps people move beyond just using Excel for data analysis"_
#
# - When Python was first developed, it was very difficult to perform tasks such as importing CSV files, dealing with spreadsheet-like datasets with rows and columns and merging tables
# - Therefore, Pandas was developed to solve these problems by introducing the `DataFrame` object, which made it possible to do intuitive analysis and exploration in Python that was not possible (and still not possible) in other programming languages (like Java, for example).
# - In recent years, the Pandas Package has become a staple in the Data Scientist's toolbox for some of the following reasons. In fact, Python is one of the most popular programming languages for Data Scientists specifically because of packages such as Pandas and Matplotlib.
# > 1. As a Data Scientist, it is common to work with tabular data where the data in each column is different, known as __hetereogenously-typed data__ (similar to a SQL table or Excel spreadsheet). Pandas `DataFrame` class replicates tabular data and allows you to do everything you would in a spreadsheet, but better and faster.
# > 2. The most time-consuming part of any Data Scientist's job is __[Data Munging](https://en.wikipedia.org/wiki/Data_wrangling)__ (Data Cleaning/Wrangling) and Pandas provides all the necessary tools at your fingertips to do this quicker and cleaner.
# > 3. Exploratory Data Analysis is often overlooked in Data Science, but remains one of the most important tasks of a Data Scientist and Pandas provides many easy and intuitive methods to perform data manipulation.
#
# - Now you understand why Data Scientists use the Pandas Package, but what is it about the Pandas Package that allows us to realize these benefits?
# > 1. __Missing Data:__ Pandas handles missing data well (represented as `NaN` a NumPy-defined missing value type)
# > 2. __Size Mutability:__ Pandas DataFrames are size mutable which means columns and rows can be inserted and deleted at will.
# > 3. __Data Aligment:__ Pandas allows you to align an object to a specific set of labels OR allow Pandas align the data for you.
# > 4. __Grouping Data:__ Pandas `groupby` function allows both aggregating and transforming of data.
# > 5. __Data Access:__ Pandas has extensive capabilities for slicing, indexing and subsetting large data sets.
# > 6. __Reshaping Data:__ Pandas has extensive capabilities for merging, joining, and reshaping data.
# > 7. __Input/Output:__ Pandas allows easy import and export of flat files such as CSV, json, etc.

# %% [markdown]
# ### Pandas Basics

# %% [markdown]
# __Overview:__
# - Recall that the usefulness of Pandas has to do with its fundamental data structures
# - There are 2 types of data structures in Pandas:
# > 1. [`Series`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html#pandas.Series): Series is a one-dimensional labeled array that is capable of holding any data type (i.e. `int`, `str`, `float`, etc.), but every element is of this same type. The axis labels of a Series are referred to as the __Index__ of the Series
# >> - The `pd.Series(data, index)` function which creates a Series data structure, has 2 arguments:<br>
# >> a. `index`: The `index` argument is a list of axis labels<br>
# >> b. `data`: The `data` argument can be any of the following:
# >> > 1. Python dictionary (`dict`)
# >> > 2. NumPy Array (`ndarray`)
# >> > 3. Scalar value (5)<br>
# > 2. [`DataFrame`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html): Dataframe is a two-dimensional labeled data structure with columns of potentially different types. It largely resembles a spreadsheet or SQL table. The first axis labels of a Dataframe (rows) are referred to as the __Index__ of the Series, whereas the second axis labels labels of a Dataframe (columns) are referred to as the __Columns__ of the Series
# >> - The `pd.DataFrame(data, index, columns)` function which creates a Dataframe data structure, has 3 arguments:<br>
# >> a. `index`: The `index` argument is a list of axis 0 labels<br>
# >> b. `columns`: The `column` argument is a list of axis 1 labels<br>
# >> c. `data`: The `data` argument can be any of the following:
# >> > 1. Dictionary of 1D ndarrays, lists, dicts, or Series
# >> > 2. 2-D NumPy Array (`ndarray` object)
# >> > 3. A `Series` object
# >> > 4. Another `DataFrame` object
# >> > 5. List of Python dictionaries
# >> > 6. From CSV or Excel file (or any of the possible file formats which can be found [here](http://pandas.pydata.org/pandas-docs/stable/io.html)
#
# __Helpful Points:__
# 1. Remember that data alignment in Pandas is intrinsic which means that the link between labels and data will not be broken unless you do so explicitly
# 2. If you pass an index and/or columns into the function, you guarantee these in the resulting object. Therefore, if you also pass a dictionary, for example, you will lose all the data from the dictionary that does not match the passed-in index.
# 3. If axis labels are not passed into the function, they will be constructed from the input data.
# 4. We will see examples of creating both types of data structures below.
#
# __Practice:__ Examples of creating Pandas Data Structures in Python

# %%
# dependencies
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Creating Series from Python Dictionary:

# %%
# dictionary: indexing is done through key-value pairs
# keys must be unique; single key can refer to complicated things (e.g., value being the list)
my_dict = {"Sergey": 34, "Sean": [1,2,3,"hello"], "June": {"deep_dict": "why"}}
my_dict.keys() # identifies all the keys in the dict
# Out:
# dict_keys(['Sergey', 'Sean', 'June'])

# %%
my_series = pd.Series(my_dict)
print(my_series)
# Out:
# Sergey                      34
# Sean          [1, 2, 3, hello]
# June      {'deep_dict': 'why'}
# dtype: object

# %%
# new indexes replace the old indexes 
pd.Series(my_dict, index = ["Sergey", "Bob", "Mary"])
# Out:
# Sergey     34
# Bob       NaN
# Mary      NaN
# dtype: object

# %%
# if you want to merge the two series
## 1. adding them together
other_index = ["a", "b", "c"]
final_index = set(other_index + list(my_dict.keys()))
final_index

## 2. adding more to the original dict
# Out:
# {'June', 'Sean', 'Sergey', 'a', 'b', 'c'}

# %% [markdown]
# See **Helpful Point 2** above which states that if you pass an index into the function (`["Sergey", "Bob", "Mary"]`), you guarantee these indexes in the resulting object, whether they existed in your data or not. We passed in a dictionary of data that only had 1 of 3 indexes the same as the `index` argument. Therefore, the remaining indexes that were passed in, but not in the data are shown with `NaN` to represent "missing data" and the remaining indexes that were in the data, but not passed in, are simply not shown.

# %% [markdown]
# ### Creating Series from NumPy Array:

# %%
my_array = np.arange(4)
print(my_array)
# Out:
# [0 1 2 3]

# %%
pd_2 = pd.Series(my_array, index = ["a", "b", "c", "d"]) # explicitly define index argument
pd_2
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
pd_2.index # ".index" = extract the index labels
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %% [markdown]
# ### Creating DataFrames from Dictionaries:

# %%
my_dict = {"ndarray":np.arange(4),
           "List":[10,12,1,2],
           "Series":pd.Series(10, index = ["row_1", "row_2", "row_3", "row_4"])} # number of index must match # of obvs
my_dict
# Out:
# {'ndarray': array([0, 1, 2, 3]), 'List': [10, 12, 1, 2], 'Series': row_1    10
#  row_2    10
#  row_3    10
#  row_4    10
#  dtype: int64}

# %%
# converting dictionary into a dataframe
my_df = pd.DataFrame(my_dict)
my_df
# Out:
#        ndarray  List  Series
# row_1        0    10      10
# row_2        1    12      10
# row_3        2     1      10
# row_4        3     2      10

# %%
type(my_df) # checking the type of object
type(type)
type(True)
# Out:
# bool

# %% [markdown]
# Few points here:
#
# 1. We can see that to create this dataframe from a dictionary that has a NumPy Array, List, and Series object, we need all objects to have the same length (4) which corresponds to the number of rows
# 2. The index of the Series object was explicitly assigned index labels, therefore they were not imputed
# 3. Each key-value pair in the dictionary becomes a column in the associated DataFrame

# %%
my_df.dtypes # ".dtypes" = identify the types of each column
# Out:
# ndarray    int64
# List       int64
# Series     int64
# dtype: object

# %%
my_df.index # row names
# Out:
# Index(['row_1', 'row_2', 'row_3', 'row_4'], dtype='object')

# %%
my_df.columns # column names
# Out:
# Index(['ndarray', 'List', 'Series'], dtype='object')

# %% [markdown]
# ### Creating DataFrames from Series Objects:

# %%
my_series = pd.Series(range(1,6), index = range(5))
my_series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df_2 = pd.DataFrame(my_series, columns = ["column_1"])
df_2
# Out:
#    column_1
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %% [markdown]
# ### Creating DataFrames from other DataFrames:

# %%
df_3 = pd.DataFrame(df_2, columns = ["new_column_1"])
df_3
# Out:
#                new_column_1
# name_of_index
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
df_3.index.name = "name_of_index"
df_3
# Out:
#                new_column_1
# name_of_index
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
df_3 = df_3.reset_index(drop=False) # turns the index into a new column; "drop=T" means dropping index completely
df_3
# Out:
#    level_0  index  name_of_index  new_column_1
# 0        0      0              0           NaN
# 1        1      1              1           NaN
# 2        2      2              2           NaN
# 3        3      3              3           NaN
# 4        4      4              4           NaN

# %% [markdown]
# **Since the column labels were passed into the function, these have now been explicitly defined and the new dataframe must have the same index labels AND column labels, otherwise it will appear as missing data, which it does here (`NaN`)**

# %% [markdown]
# ### Creating DataFrames from List of Dictionaries:

# %%
my_list = [{"First":"Sergey", "Last":"Fogelson"},
           {"First":"Daniel", "Last":"Wilson"},
           {"First":"Justin", "Last":"Trudeau"}]
my_list
# Out:
# [{'First': 'Sergey', 'Last': 'Fogelson'},
#  {'First': 'Daniel', 'Last': 'Wilson'},
#  {'First': 'Justin', 'Last': 'Trudeau'}]

# %%
pd.DataFrame(my_list, index = ["Person_1", "Person_2", "Person_3"])
# Out:
#            First      Last
# Person_1  Sergey  Fogelson
# Person_2  Daniel    Wilson
# Person_3  Justin   Trudeau

# %% [markdown]
# We can see that each item in the `list` turns out to be a row in the resulting `DataFrame`.

# %% [markdown]
# ### Creating DataFrames from CSV:

# %% [markdown]
# Pandas has extensive capabilities of reading and writing to different formats. The most common input/output (I/O) that you will perform is with the [CSV](https://en.wikipedia.org/wiki/Comma-separated_values) file format, but Python also supports many other formats shown below, each with their respective reader and writer functions:
#
# > 1. __CSV:__ `read_csv` and `to_csv`
# > 2. __MS Excel:__ `read_excel` and `to_excel`
# > 3. __Python Pickle:__ `read_pickle` and `to_pickle`
# > 4. __SQL:__ `read_sql` and `to_sql`
#
# See below for the CSV file that we will create a DataFrame from:

# %% [markdown]
# ### Dataset Attribute Information:
#
# Let's use an example dataset called the [Chronic Kidney Disease Dataset](https://archive.ics.uci.edu/ml/datasets/Chronic_Kidney_Disease) and can be used to create a model that predicts whether someone has CKD (chronic kidney disease) or not.
#
# The columns in the dataset are as follows:
#
# * **age**: subject age, numeric
# * **bp**: blood pressure,  numeric
# * **sg**: specific gravity, numeric but discrete
# * **al**: albumin, numeric but discrete
# * **su**: sugar, numeric but discrete
# * **rbc**: red blood cells, categorical
# * **pc**: pus cell, categorical
# * **pcc**: pus cell clumps, categorical
# * **ba**: bacteria, categorical
# * **bgr**: blood glucose random, numeric
# * **bu**: blood urea, numeric
# * **sc**: serum creatinine, numeric
# * **sod**: sodium, numeric
# * **pot**: potassium, numeric
# * **hemo**: hemoglobin, numeric
# * **pcv**: packed cell volume, numeric
# * **wc**: white blood cell count, numeric
# * **rc**: red blood cell count, numeric
# * **htn**: hypertension, categorical
# * **dm**: diabetes mellitus, categorical
# * **cad**: coronary artery disease, categorical
# * **appet**: appetite, categorical
# * **pe**: pedal edema, categorical
# * **ane**: anemia, categorical
# * **class**: class, categorical

# %%
# import data
## pd::read_csv(url or one-string argument)
### pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")

## Note: txt file must be at exact path specified in the argument string
# "shift + tap" gives you help page
# pd.read_csv

##1. define the header names before importing
kidney_columns = ["age","bp","sg","al","su","rbc","pc","pcc","ba",
                  "bgr","bu","sc","sod","pot","hemo","pcv","wc","rc",
                  "htn","dm","cad","appet","pe","ane","class"]
##2. import dataset with the user-defined header names
my_df = pd.read_csv("../data/chronic_kidney_disease.csv",
           names = kidney_columns,
           na_values = "?")  # without this, "?" is treated as a real value

# %%
my_df.head(10)
# Out:
#     age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent  notpresent
# 2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent
# 3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent  notpresent
# 6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent  notpresent
# 8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present  notpresent
# 9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
#
#      bgr  ...    pcv       wc   rc  htn   dm  cad  appet   pe  ane class
# 0  121.0  ...   44.0   7800.0  5.2  yes  yes   no   good   no   no   ckd
# 1    NaN  ...   38.0   6000.0  NaN   no   no   no   good   no   no   ckd
# 2  423.0  ...   31.0   7500.0  NaN   no  yes   no   poor   no  yes   ckd
# 3  117.0  ...   32.0   6700.0  3.9  yes   no   no   poor  yes  yes   ckd
# 4  106.0  ...   35.0   7300.0  4.6   no   no   no   good   no   no   ckd
# 5   74.0  ...   39.0   7800.0  4.4  yes  yes   no   good  yes   no   ckd
# 6  100.0  ...   36.0      NaN  NaN   no   no   no   good   no   no   ckd
# 7  410.0  ...   44.0   6900.0  5.0   no  yes   no   good  yes   no   ckd
# 8  138.0  ...   33.0   9600.0  4.0  yes  yes   no   good   no  yes   ckd
# 9   70.0  ...   29.0  12100.0  3.7  yes  yes   no   poor   no  yes   ckd
#
# [10 rows x 25 columns]

# %% [markdown]
# The `pd.read_csv` function assumed that this contained header information, lets add header info in, and also let pandas know that there are missing values in the data, denoted by a `?`.

# %% [markdown]
# ### Inspecting Pandas Data Structures
#
# __Overview:__
# - Pandas offers many ways to "inspect" tabular data.
# - The following are useful ways of inspecting Pandas Data Structures where `obj` is either a `Series` or a `DataFrame`.
# > 1. __Dimensions:__ Dimensions can be accessed using `len(obj)`, `obj.shape`, and `obj.size`
# > 2. __Row Labels:__ Row labels can be accessed using `obj.index`, `obj.index.name`
# > 3. __Column Labels:__ (Only for DataFrames) Column labels can be accessed using `obj.columns`, `obj.columns.values`, `obj.columns.values.tolist()`, `obj.columns.tolist()`
# > 4. __Name Labels:__ (Only for Series, unless accessing specific columns) Name labels can be accessed using `obj.name`
# > 5. __Data Values:__ Data values can be accessed using `obj.values`
# > 6. __Data Type:__ Data types can be accessed using `obj.dtypes`
# > 7. __Data Quick Look:__  Data quick looks can be accessed using `obj.head(n)`, `obj.tail(n)`
# > 8. __Data Summary:__ Data summary can be completed by `obj.describe`
#
# __Helpful Points:__
# 1. It is possible to inspect both Series and DataFrames, however DataFrames have some additional functions for inspection given that they have an additional dimension and attributes.
# 2. Pandas Series and DataFrames will be explored separately below
#
# __Practice:__ Examples of Inspecting Pandas Data Structures in Python

# %% [markdown]
# ### Inspecting Pandas Series:

# %%
my_series_1 = pd.Series(10, index = ["row_1", "row_2", "row_3", "row_4"], name = "Series_1")
my_series_1
# Out:
# row_1    10
# row_2    10
# row_3    10
# row_4    10
# Name: Series_1, dtype: int64

# %% [markdown]
# ### Dimensions:

# %%
print(len(my_series_1))

print(my_series_1.shape) # gives you tupules that are immutable objects (list is modifiable)

print(my_series_1.size) # number of columns
# Out:
# 4
# (4,)
# 4

# %% [markdown]
# ### Row Labels:

# %%
my_series_1.index
# Out:
# Index(['row_1', 'row_2', 'row_3', 'row_4'], dtype='object')

# %% [markdown]
# ### Name Labels:

# %%
my_series_1.name
# Out:
# 'Series_1'

# %% [markdown]
# ### Data Values:

# %%
my_series_1.values
# Out:
# array([10, 10, 10, 10])

# %% [markdown]
# ### Data Type:

# %%
my_series_1.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### Data Quick Look:

# %%
print(my_series_1.head(2))

print(my_series_1.tail(2))
# Out:
# row_1    10
# row_2    10
# Name: Series_1, dtype: int64
# row_3    10
# row_4    10
# Name: Series_1, dtype: int64

# %% [markdown]
# ### Data Summary:

# %%
my_series_1.describe()
# Out:
# count     4.0
# mean     10.0
# std       0.0
# min      10.0
# 25%      10.0
# 50%      10.0
# 75%      10.0
# max      10.0
# Name: Series_1, dtype: float64

# %% [markdown]
# ### Inspecting Pandas DataFrames:

# %%
# my_df = pd.read_csv("../data/chronic_kidney_disease.csv",names=kidney_columns,na_values="?")

# %% [markdown]
# ### Dimensions:

# %%
print(len(my_df))

print(my_df.shape)

print(my_df.size)
# Out:
# 400
# (400, 25)
# 10000

# %% [markdown]
# ### Row Labels:

# %%
my_df.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %% [markdown]
# ### Column Labels:

# %%
my_df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'class'],
#       dtype='object')

# %%
my_df.columns.values
# Out:
# array(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm',
#        'cad', 'appet', 'pe', 'ane', 'class'], dtype=object)

# %%
my_df.columns.values.tolist()
# Out:
# ['age',
#  'bp',
#  'sg',
#  'al',
#  'su',
#  'rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'bgr',
#  'bu',
#  'sc',
#  'sod',
#  'pot',
#  'hemo',
#  'pcv',
#  'wc',
#  'rc',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'class']

# %%
col_list = my_df.columns.tolist()
col_list
# Out:
# ['age',
#  'bp',
#  'sg',
#  'al',
#  'su',
#  'rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'bgr',
#  'bu',
#  'sc',
#  'sod',
#  'pot',
#  'hemo',
#  'pcv',
#  'wc',
#  'rc',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'class']

# %%
# indexing
col_list[0:5:] 
col_list[-1::-1] # reversing
# Out:
# ['age', 'bp', 'sg', 'al', 'su']

# %% [markdown]
# ### Data Values:

# %%
my_df.values
# Out:
# array([[48.0, 80.0, 1.02, ..., 'no', 'no', 'ckd'],
#        [7.0, 50.0, 1.02, ..., 'no', 'no', 'ckd'],
#        [62.0, 80.0, 1.01, ..., 'no', 'yes', 'ckd'],
#        ...,
#        [12.0, 80.0, 1.02, ..., 'no', 'no', 'notckd'],
#        [17.0, 60.0, 1.025, ..., 'no', 'no', 'notckd'],
#        [58.0, 80.0, 1.025, ..., 'no', 'no', 'notckd']], dtype=object)

# %% [markdown]
# ### Data Type:

# %%
my_df.dtypes
# Out:
# age      float64
# bp       float64
# sg       float64
# al       float64
# su       float64
# rbc       object
# pc        object
# pcc       object
# ba        object
# bgr      float64
# bu       float64
# sc       float64
# sod      float64
# pot      float64
# hemo     float64
# pcv      float64
# wc       float64
# rc       float64
# htn       object
# dm        object
# cad       object
# appet     object
# pe        object
# ane       object
# class     object
# dtype: object

# %% [markdown]
# ### Data Quick Look:

# %%
my_df.head(2)
# Out:
#     age    bp    sg   al   su  rbc      pc         pcc          ba    bgr  \
# 0  48.0  80.0  1.02  1.0  0.0  NaN  normal  notpresent  notpresent  121.0
# 1   7.0  50.0  1.02  4.0  0.0  NaN  normal  notpresent  notpresent    NaN
#
#    ...    pcv      wc   rc  htn   dm  cad  appet  pe ane class
# 0  ...   44.0  7800.0  5.2  yes  yes   no   good  no  no   ckd
# 1  ...   38.0  6000.0  NaN   no   no   no   good  no  no   ckd
#
# [2 rows x 25 columns]

# %%
# indexing in the dataframe or series of objects
# ".loc "= value-based indexing
my_df.loc[:, "pc":"ba"] # give me every row for the columns starting from "pc" ending in "ba"
# Out:
#            pc         pcc          ba
# 0      normal  notpresent  notpresent
# 1      normal  notpresent  notpresent
# 2      normal  notpresent  notpresent
# 3    abnormal     present  notpresent
# 4      normal  notpresent  notpresent
# 5         NaN  notpresent  notpresent
# 6      normal  notpresent  notpresent
# 7    abnormal  notpresent  notpresent
# 8    abnormal     present  notpresent
# 9    abnormal     present  notpresent
# 10   abnormal     present  notpresent
# 11   abnormal     present  notpresent
# 12     normal     present  notpresent
# 13        NaN  notpresent  notpresent
# 14   abnormal     present     present
# 15     normal  notpresent  notpresent
# 16     normal  notpresent  notpresent
# 17        NaN  notpresent  notpresent
# 18     normal  notpresent  notpresent
# 19   abnormal     present  notpresent
# 20   abnormal  notpresent  notpresent
# 21        NaN  notpresent  notpresent
# 22   abnormal  notpresent  notpresent
# 23     normal  notpresent  notpresent
# 24   abnormal  notpresent     present
# 25     normal  notpresent  notpresent
# 26     normal  notpresent  notpresent
# 27   abnormal  notpresent  notpresent
# 28        NaN  notpresent  notpresent
# 29   abnormal     present  notpresent
# ..        ...         ...         ...
# 370    normal  notpresent  notpresent
# 371    normal  notpresent  notpresent
# 372    normal  notpresent  notpresent
# 373    normal  notpresent  notpresent
# 374    normal  notpresent  notpresent
# 375    normal  notpresent  notpresent
# 376    normal  notpresent  notpresent
# 377    normal  notpresent  notpresent
# 378    normal  notpresent  notpresent
# 379    normal  notpresent  notpresent
# 380    normal  notpresent  notpresent
# 381       NaN  notpresent  notpresent
# 382    normal  notpresent  notpresent
# 383    normal  notpresent  notpresent
# 384    normal  notpresent  notpresent
# 385    normal  notpresent  notpresent
# 386    normal  notpresent  notpresent
# 387    normal  notpresent  notpresent
# 388    normal  notpresent  notpresent
# 389    normal  notpresent  notpresent
# 390    normal  notpresent  notpresent
# 391    normal  notpresent  notpresent
# 392    normal  notpresent  notpresent
# 393    normal  notpresent  notpresent
# 394    normal  notpresent  notpresent
# 395    normal  notpresent  notpresent
# 396    normal  notpresent  notpresent
# 397    normal  notpresent  notpresent
# 398    normal  notpresent  notpresent
# 399    normal  notpresent  notpresent
#
# [400 rows x 3 columns]

# %%
# ".iloc": position-based indexing 
## this creates the same as .loc only when the index is 0-based (so not when it's abcd...)
my_df.iloc[: ,6:9]
# Out:
#            pc         pcc          ba
# 0      normal  notpresent  notpresent
# 1      normal  notpresent  notpresent
# 2      normal  notpresent  notpresent
# 3    abnormal     present  notpresent
# 4      normal  notpresent  notpresent
# 5         NaN  notpresent  notpresent
# 6      normal  notpresent  notpresent
# 7    abnormal  notpresent  notpresent
# 8    abnormal     present  notpresent
# 9    abnormal     present  notpresent
# 10   abnormal     present  notpresent
# 11   abnormal     present  notpresent
# 12     normal     present  notpresent
# 13        NaN  notpresent  notpresent
# 14   abnormal     present     present
# 15     normal  notpresent  notpresent
# 16     normal  notpresent  notpresent
# 17        NaN  notpresent  notpresent
# 18     normal  notpresent  notpresent
# 19   abnormal     present  notpresent
# 20   abnormal  notpresent  notpresent
# 21        NaN  notpresent  notpresent
# 22   abnormal  notpresent  notpresent
# 23     normal  notpresent  notpresent
# 24   abnormal  notpresent     present
# 25     normal  notpresent  notpresent
# 26     normal  notpresent  notpresent
# 27   abnormal  notpresent  notpresent
# 28        NaN  notpresent  notpresent
# 29   abnormal     present  notpresent
# ..        ...         ...         ...
# 370    normal  notpresent  notpresent
# 371    normal  notpresent  notpresent
# 372    normal  notpresent  notpresent
# 373    normal  notpresent  notpresent
# 374    normal  notpresent  notpresent
# 375    normal  notpresent  notpresent
# 376    normal  notpresent  notpresent
# 377    normal  notpresent  notpresent
# 378    normal  notpresent  notpresent
# 379    normal  notpresent  notpresent
# 380    normal  notpresent  notpresent
# 381       NaN  notpresent  notpresent
# 382    normal  notpresent  notpresent
# 383    normal  notpresent  notpresent
# 384    normal  notpresent  notpresent
# 385    normal  notpresent  notpresent
# 386    normal  notpresent  notpresent
# 387    normal  notpresent  notpresent
# 388    normal  notpresent  notpresent
# 389    normal  notpresent  notpresent
# 390    normal  notpresent  notpresent
# 391    normal  notpresent  notpresent
# 392    normal  notpresent  notpresent
# 393    normal  notpresent  notpresent
# 394    normal  notpresent  notpresent
# 395    normal  notpresent  notpresent
# 396    normal  notpresent  notpresent
# 397    normal  notpresent  notpresent
# 398    normal  notpresent  notpresent
# 399    normal  notpresent  notpresent
#
# [400 rows x 3 columns]

# %%
my_df.tail(1)
# Out:
#       age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#        bgr   ...     pcv      wc   rc  htn  dm  cad  appet  pe ane   class
# 399  131.0   ...    53.0  6800.0  6.1   no  no   no   good  no  no  notckd
#
# [1 rows x 25 columns]

# %%
my_df.iloc[1,2]
# Out:
# 1.02

# %% [markdown]
# ### Data Summary:

# %%
print(my_df.head())
my_df.describe() # this cannot do categorical variables; only numeric columns
# Out:
#     age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr  ...    pcv      wc   rc  htn   dm  cad  appet   pe  ane class
# 0  121.0  ...   44.0  7800.0  5.2  yes  yes   no   good   no   no   ckd
# 1    NaN  ...   38.0  6000.0  NaN   no   no   no   good   no   no   ckd
# 2  423.0  ...   31.0  7500.0  NaN   no  yes   no   poor   no  yes   ckd
# 3  117.0  ...   32.0  6700.0  3.9  yes   no   no   poor  yes  yes   ckd
# 4  106.0  ...   35.0  7300.0  4.6   no   no   no   good   no   no   ckd
#
# [5 rows x 25 columns]
#               age          bp          sg          al          su         bgr  \
# count  391.000000  388.000000  353.000000  354.000000  351.000000  356.000000
# mean    51.483376   76.469072    1.017408    1.016949    0.450142  148.036517
# std     17.169714   13.683637    0.005717    1.352679    1.099191   79.281714
# min      2.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     42.000000   70.000000    1.010000    0.000000    0.000000   99.000000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  121.000000
# 75%     64.500000   80.000000    1.020000    2.000000    0.000000  163.000000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo         pcv  \
# count  381.000000  383.000000  313.000000  312.000000  348.000000  329.000000
# mean    57.425722    3.072454  137.528754    4.627244   12.526437   38.884498
# std     50.503006    5.741126   10.408752    3.193904    2.912587    8.990105
# min      1.500000    0.400000    4.500000    2.500000    3.100000    9.000000
# 25%     27.000000    0.900000  135.000000    3.800000   10.300000   32.000000
# 50%     42.000000    1.300000  138.000000    4.400000   12.650000   40.000000
# 75%     66.000000    2.800000  142.000000    4.900000   15.000000   45.000000
# max    391.000000   76.000000  163.000000   47.000000   17.800000   54.000000
#
#                  wc          rc
# count    294.000000  269.000000
# mean    8406.122449    4.707435
# std     2944.474190    1.025323
# min     2200.000000    2.100000
# 25%     6500.000000    3.900000
# 50%     8000.000000    4.800000
# 75%     9800.000000    5.400000
# max    26400.000000    8.000000

# %% [markdown]
# ### Indexing Pandas Data Structures:
#
# __Overview:__
# - Pandas offers many different techniques to index (access) elements within Data Structures which can be found [here](http://pandas.pydata.org/pandas-docs/stable/indexing.html)
# - There are 6 main ways of indexing Pandas data structures:
# > 1. __Select by Column Name:__ The syntax of this method is `df[col_name]` and it returns a `Series` object
# > 2. __[Select by Label](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-label):__ This describes __purely label-based indexing__ which selects labels based on what is included in the index of the object. The syntax of this method (for DataFrames) is `df.loc[row_label, column_label]` and it returns a `Series` object. The following provides a list of the possible arguments for the `row_label` and/or `column_label`:
# >> a. A single label (i.e. `5` or `a`, but the number `5` is interpreted as the label and NOT as the index (use `.iloc` for this)<br>
# >> b. A list or array of labels (i.e. `['a', 'b', 'c']`<br>
# >> c. A slice object with labels (i.e. `['a':'f']`, but unlike with other slices in Python, the `stop` argument is included in the slide
# >> d. A boolean array
# > 3. __[Select by Integer Location (Position)](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-integer):__ This describes __purely integer-based indexing__ which requires an integer (0-based indexing) for input. The syntax of this method is (for DataFrames) `df.iloc[row_number, column_number]` and it returns a `Series` object. The following provides a list of the possible arguments for `row_number` and/or `column_number`:
# >> a. An integer (i.e. `5`)<br>
# >> b. A list or array of integers (i.e. `[4, 3, 0]`<br>
# >> c. A slice object with integers (i.e. `[1:7]`<br>
# >> d. A boolean array
# > 4. __[Slicing Ranges](http://pandas.pydata.org/pandas-docs/stable/indexing.html#slicing-ranges):__ The syntax of this method is (for DataFrames) `df[row_number_1:row_number_2]` and it returns a `DataFrame` object. The `[` and `]` operator is responsible for the slicing and this ONLY operates on rows
# > 5. __[Boolean Indexing](http://pandas.pydata.org/pandas-docs/stable/indexing.html#boolean-indexing):__ The syntax of this method is (for DataFrames) `df[boolean_vector]` and it returns a `DataFrame` object. This is performed using boolean operators such as `|` for `or`, `&` for `and` and `~` for not and each must be grouped by parantheseses
# > 6. __[Indexing with isin](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-with-isin):__ The syntax of this method is (for DataFrames) `df.isin(values)` and it returns a boolean vector that is true wherever the Series elements exist in the passed list
#
# __Helpful Points:__
# 1. Both Series and DataFrames can be indexed, naturally though, Series have less functionality
#
# __Practice:__ Examples of Indexing Pandas Data Structures in Python

# %% [markdown]
# ### Indexing Method 1 - Select by Column Name:

# %%
my_df["bp"] # 2nd column
# my_df["werid as name"]
# my_df[["bp", "age", "ba"]] # multiple columns
# Out:
# 0       80.0
# 1       50.0
# 2       80.0
# 3       70.0
# 4       80.0
# 5       90.0
# 6       70.0
# 7        NaN
# 8      100.0
# 9       90.0
# 10      60.0
# 11      70.0
# 12      70.0
# 13      70.0
# 14      80.0
# 15      80.0
# 16      70.0
# 17      80.0
# 18     100.0
# 19      60.0
# 20      80.0
# 21      90.0
# 22      80.0
# 23      70.0
# 24     100.0
# 25      60.0
# 26      80.0
# 27      70.0
# 28      70.0
# 29      70.0
#        ...
# 370     70.0
# 371     60.0
# 372     60.0
# 373     70.0
# 374     80.0
# 375     80.0
# 376     70.0
# 377     70.0
# 378     60.0
# 379     80.0
# 380     60.0
# 381     70.0
# 382     80.0
# 383     80.0
# 384     60.0
# 385     70.0
# 386     70.0
# 387     80.0
# 388     80.0
# 389     80.0
# 390     80.0
# 391     80.0
# 392     80.0
# 393     60.0
# 394     80.0
# 395     80.0
# 396     70.0
# 397     80.0
# 398     60.0
# 399     80.0
# Name: bp, Length: 400, dtype: float64

# %%
type(my_df["bp"]) # returns a Series object
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Access 1 Column by Name - Method 2:

# %%
# column names must be syntatically correct (e.g., no spaces)
my_df.bp # "." acts as "$"
# Out:
# 0       80.0
# 1       50.0
# 2       80.0
# 3       70.0
# 4       80.0
# 5       90.0
# 6       70.0
# 7        NaN
# 8      100.0
# 9       90.0
# 10      60.0
# 11      70.0
# 12      70.0
# 13      70.0
# 14      80.0
# 15      80.0
# 16      70.0
# 17      80.0
# 18     100.0
# 19      60.0
# 20      80.0
# 21      90.0
# 22      80.0
# 23      70.0
# 24     100.0
# 25      60.0
# 26      80.0
# 27      70.0
# 28      70.0
# 29      70.0
#        ...
# 370     70.0
# 371     60.0
# 372     60.0
# 373     70.0
# 374     80.0
# 375     80.0
# 376     70.0
# 377     70.0
# 378     60.0
# 379     80.0
# 380     60.0
# 381     70.0
# 382     80.0
# 383     80.0
# 384     60.0
# 385     70.0
# 386     70.0
# 387     80.0
# 388     80.0
# 389     80.0
# 390     80.0
# 391     80.0
# 392     80.0
# 393     60.0
# 394     80.0
# 395     80.0
# 396     70.0
# 397     80.0
# 398     60.0
# 399     80.0
# Name: bp, Length: 400, dtype: float64

# %%
type(my_df.bp) # returns a Series object
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Access 2 Columns by Names:

# %%
my_df[["age", "bp"]] # 1st and 2nd column
# Out:
#       age     bp
# 0    48.0   80.0
# 1     7.0   50.0
# 2    62.0   80.0
# 3    48.0   70.0
# 4    51.0   80.0
# 5    60.0   90.0
# 6    68.0   70.0
# 7    24.0    NaN
# 8    52.0  100.0
# 9    53.0   90.0
# 10   50.0   60.0
# 11   63.0   70.0
# 12   68.0   70.0
# 13   68.0   70.0
# 14   68.0   80.0
# 15   40.0   80.0
# 16   47.0   70.0
# 17   47.0   80.0
# 18   60.0  100.0
# 19   62.0   60.0
# 20   61.0   80.0
# 21   60.0   90.0
# 22   48.0   80.0
# 23   21.0   70.0
# 24   42.0  100.0
# 25   61.0   60.0
# 26   75.0   80.0
# 27   69.0   70.0
# 28   75.0   70.0
# 29   68.0   70.0
# ..    ...    ...
# 370  69.0   70.0
# 371  28.0   60.0
# 372  72.0   60.0
# 373  61.0   70.0
# 374  79.0   80.0
# 375  70.0   80.0
# 376  58.0   70.0
# 377  64.0   70.0
# 378  71.0   60.0
# 379  62.0   80.0
# 380  59.0   60.0
# 381  71.0   70.0
# 382  48.0   80.0
# 383  80.0   80.0
# 384  57.0   60.0
# 385  63.0   70.0
# 386  46.0   70.0
# 387  15.0   80.0
# 388  51.0   80.0
# 389  41.0   80.0
# 390  52.0   80.0
# 391  36.0   80.0
# 392  57.0   80.0
# 393  43.0   60.0
# 394  50.0   80.0
# 395  55.0   80.0
# 396  42.0   70.0
# 397  12.0   80.0
# 398  17.0   60.0
# 399  58.0   80.0
#
# [400 rows x 2 columns]

# %%
type(my_df[["age", "bp"]]) # returns a DataFrame object
# Out:
# pandas.core.frame.DataFrame

# %%
type(my_df[["bp"]]) # treat this one-column dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Access with Single Label - Series:

# %%
series_1 = pd.Series(np.arange(5), index = ["a", "b", "c", "d", 4])
series_1
# Out:
# a    0
# b    1
# c    2
# d    3
# 4    4
# dtype: int64

# %%
series_1.loc["b"] # this gets you the value for the key, "b"
# Out:
# 1

# %%
series_1.loc[1] # 2nd row value???
# Out:
# 1

# %% [markdown]
# The above will output a (rather lengthy) error message (in times like these, just skip to the very bottom for the actual error info). The reason this results in an error is because when using `loc`, we are indexing by row label so the number `1` is interpreted as a row label and **there is clearly not a row label named `1`.**

# %%
series_1.loc[4] # no error
# Out:
# 4

# %% [markdown]
# However, there IS a row label named `4`, therefore we can index with the integer 4. Make sure you understand though, this is NOT integer indexing and the argument `4` is interpreted as a row label and NOT an integer position.
# ### Access with Single Label - DataFrame:

# %%
my_df.loc[0, ] # 1st row
# Out:
# age              48
# bp               80
# sg             1.02
# al                1
# su                0
# rbc             NaN
# pc           normal
# pcc      notpresent
# ba       notpresent
# bgr             121
# bu               36
# sc              1.2
# sod             NaN
# pot             NaN
# hemo           15.4
# pcv              44
# wc             7800
# rc              5.2
# htn             yes
# dm              yes
# cad              no
# appet          good
# pe               no
# ane              no
# class           ckd
# Name: 0, dtype: object

# %%
my_df.iloc[0:5] # First to fifth rows
# Out:
#     age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr  ...    pcv      wc   rc  htn   dm  cad  appet   pe  ane class
# 0  121.0  ...   44.0  7800.0  5.2  yes  yes   no   good   no   no   ckd
# 1    NaN  ...   38.0  6000.0  NaN   no   no   no   good   no   no   ckd
# 2  423.0  ...   31.0  7500.0  NaN   no  yes   no   poor   no  yes   ckd
# 3  117.0  ...   32.0  6700.0  3.9  yes   no   no   poor  yes  yes   ckd
# 4  106.0  ...   35.0  7300.0  4.6   no   no   no   good   no   no   ckd
#
# [5 rows x 25 columns]

# %%
my_df.loc[0, "age"] # 1st row, 1st column
# Out:
# 48.0

# %% [markdown]
# ### Access with List of Labels - Series:

# %%
series_1.loc[["a", "c", 4]] # 1st row, 3rd row, last row
# Out:
# a    0
# c    2
# 4    4
# dtype: int64

# %% [markdown]
# ### Access with List of Labels - DataFrame:

# %%
my_df.loc[[0, 399]] # 1st row and last row
# Out:
#       age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 0    48.0  80.0  1.020  1.0  0.0     NaN  normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#        bgr   ...     pcv      wc   rc  htn   dm  cad  appet  pe ane   class
# 0    121.0   ...    44.0  7800.0  5.2  yes  yes   no   good  no  no     ckd
# 399  131.0   ...    53.0  6800.0  6.1   no   no   no   good  no  no  notckd
#
# [2 rows x 25 columns]

# %%
my_df.loc[[0, 399], ["age", "class"]] # 1st row and last row and last two columns
# Out:
#       age   class
# 0    48.0     ckd
# 399  58.0  notckd

# %% [markdown]
# ### Access with Slice Object - Series:

# %%
series_1.loc["b":"d"] # 2nd to 4th row, inclusive
# Out:
# b    1
# c    2
# d    3
# dtype: int64

# %%
### Access with Slice Object - DataFrame:

# %%
my_df.loc[2:3] # 3rd and 4th row, inclusive
# Out:
#     DGN  PRE4  PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19 PRE25  \
# 2  DGN3  2.76  2.08  PRZ1    F    F    F     T     F  OC11     F     F     F
# 3  DGN3  3.68  3.04  PRZ0    F    F    F     F     F  OC11     F     F     F
#
#   PRE30 PRE32  AGE Risk1Yr
# 2     T     F   59       F
# 3     F     F   54       F

# %% [markdown]
# Notice how the `stop` argument in the slice `"Employee_2":"Employee_3"` is included in the result. **Also, remember that indexing by default in Python is 0-based.**

# %%
my_df.loc[2:3, "bp":] # 3rd and 4th row, inclusive and 2nd column onwards
# Out:
#      bp     sg   al   su     rbc        pc         pcc          ba    bgr  \
# 2  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent  423.0
# 3  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent  117.0
#
#      bu  ...    pcv      wc   rc  htn   dm  cad  appet   pe  ane class
# 2  53.0  ...   31.0  7500.0  NaN   no  yes   no   poor   no  yes   ckd
# 3  56.0  ...   32.0  6700.0  3.9  yes   no   no   poor  yes  yes   ckd
#
# [2 rows x 24 columns]

# %%
my_df.loc[3:10, ["bp", "pcc"]] # mix slice object with list of labels
# Out:
#        bp         pcc
# 3    70.0     present
# 4    80.0  notpresent
# 5    90.0  notpresent
# 6    70.0  notpresent
# 7     NaN  notpresent
# 8   100.0     present
# 9    90.0     present
# 10   60.0     present

# %% [markdown]
# ### Access with Boolean Array - Series:

# %%
# 1. define a boolean statement
series_1 > 0 # returns series of same shape with boolean values
# Out:
# a    False
# b     True
# c     True
# d     True
# 4     True
# dtype: bool

# %%
# 2. use the boolean statement as a filter
## returns new series object that satisfies the boolean conditional
series_1[series_1>0]
# Out:
# b    1
# c    2
# d    3
# 4    4
# dtype: int64

# %% [markdown]
# ### Access with Boolean Array - DataFrame:

# %%
my_df.loc[:, "age"] > 30
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7      False
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23     False
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 370     True
# 371    False
# 372     True
# 373     True
# 374     True
# 375     True
# 376     True
# 377     True
# 378     True
# 379     True
# 380     True
# 381     True
# 382     True
# 383     True
# 384     True
# 385     True
# 386     True
# 387    False
# 388     True
# 389     True
# 390     True
# 391     True
# 392     True
# 393     True
# 394     True
# 395     True
# 396     True
# 397    False
# 398    False
# 399     True
# Name: age, Length: 400, dtype: bool

# %%
# getting data that satisfies the boolean statement 
my_df.loc[my_df.loc[:, "age"] > 30, ]
my_df[my_df.age >30]
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 0    48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 2    62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent
# 3    48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 4    51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 5    60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent  notpresent
# 6    68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 8    52.0  100.0  1.015  3.0  0.0    normal  abnormal     present  notpresent
# 9    53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 10   50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present  notpresent
# 11   63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 12   68.0   70.0  1.015  3.0  1.0       NaN    normal     present  notpresent
# 13   68.0   70.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 14   68.0   80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 15   40.0   80.0  1.015  3.0  0.0       NaN    normal  notpresent  notpresent
# 16   47.0   70.0  1.015  2.0  0.0       NaN    normal  notpresent  notpresent
# 17   47.0   80.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 18   60.0  100.0  1.025  0.0  3.0       NaN    normal  notpresent  notpresent
# 19   62.0   60.0  1.015  1.0  0.0       NaN  abnormal     present  notpresent
# 20   61.0   80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 21   60.0   90.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 22   48.0   80.0  1.025  4.0  0.0    normal  abnormal  notpresent  notpresent
# 24   42.0  100.0  1.015  4.0  0.0    normal  abnormal  notpresent     present
# 25   61.0   60.0  1.025  0.0  0.0       NaN    normal  notpresent  notpresent
# 26   75.0   80.0  1.015  0.0  0.0       NaN    normal  notpresent  notpresent
# 27   69.0   70.0  1.010  3.0  4.0    normal  abnormal  notpresent  notpresent
# 28   75.0   70.0    NaN  1.0  3.0       NaN       NaN  notpresent  notpresent
# 29   68.0   70.0  1.005  1.0  0.0  abnormal  abnormal     present  notpresent
# 31   73.0   90.0  1.015  3.0  0.0       NaN  abnormal     present  notpresent
# 32   61.0   90.0  1.010  1.0  1.0       NaN    normal  notpresent  notpresent
# 33   60.0  100.0  1.020  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# ..    ...    ...    ...  ...  ...       ...       ...         ...         ...
# 364  73.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 366  60.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 367  68.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 369  75.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 370  69.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 372  72.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 373  61.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 374  79.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 375  70.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 376  58.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 377  64.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 378  71.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 379  62.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 380  59.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 381  71.0   70.0  1.025  0.0  0.0       NaN       NaN  notpresent  notpresent
# 382  48.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 383  80.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 384  57.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 385  63.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 386  46.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 388  51.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 389  41.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 390  52.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 391  36.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 392  57.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 393  43.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 394  50.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 395  55.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 396  42.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 399  58.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
#
#        bgr   ...     pcv       wc   rc  htn   dm  cad  appet   pe  ane   class
# 0    121.0   ...    44.0   7800.0  5.2  yes  yes   no   good   no   no     ckd
# 2    423.0   ...    31.0   7500.0  NaN   no  yes   no   poor   no  yes     ckd
# 3    117.0   ...    32.0   6700.0  3.9  yes   no   no   poor  yes  yes     ckd
# 4    106.0   ...    35.0   7300.0  4.6   no   no   no   good   no   no     ckd
# 5     74.0   ...    39.0   7800.0  4.4  yes  yes   no   good  yes   no     ckd
# 6    100.0   ...    36.0      NaN  NaN   no   no   no   good   no   no     ckd
# 8    138.0   ...    33.0   9600.0  4.0  yes  yes   no   good   no  yes     ckd
# 9     70.0   ...    29.0  12100.0  3.7  yes  yes   no   poor   no  yes     ckd
# 10   490.0   ...    28.0      NaN  NaN  yes  yes   no   good   no  yes     ckd
# 11   380.0   ...    32.0   4500.0  3.8  yes  yes   no   poor  yes   no     ckd
# 12   208.0   ...    28.0  12200.0  3.4  yes  yes  yes   poor  yes   no     ckd
# 13    98.0   ...     NaN      NaN  NaN  yes  yes  yes   poor  yes   no     ckd
# 14   157.0   ...    16.0  11000.0  2.6  yes  yes  yes   poor  yes   no     ckd
# 15    76.0   ...    24.0   3800.0  2.8  yes   no   no   good   no  yes     ckd
# 16    99.0   ...     NaN      NaN  NaN   no   no   no   good   no   no     ckd
# 17   114.0   ...     NaN      NaN  NaN  yes   no   no   poor   no   no     ckd
# 18   263.0   ...    37.0  11400.0  4.3  yes  yes  yes   good   no   no     ckd
# 19   100.0   ...    30.0   5300.0  3.7  yes   no  yes   good   no   no     ckd
# 20   173.0   ...    24.0   9200.0  3.2  yes  yes  yes   poor  yes  yes     ckd
# 21     NaN   ...    32.0   6200.0  3.6  yes  yes  yes   good   no   no     ckd
# 22    95.0   ...    32.0   6900.0  3.4  yes   no   no   good   no  yes     ckd
# 24     NaN   ...    39.0   8300.0  4.6  yes   no   no   poor   no   no     ckd
# 25   108.0   ...    29.0   8400.0  3.7  yes  yes   no   good   no  yes     ckd
# 26   156.0   ...    35.0  10300.0  4.0  yes  yes   no   poor   no   no     ckd
# 27   264.0   ...    37.0   9600.0  4.1  yes  yes  yes   good  yes   no     ckd
# 28   123.0   ...     NaN      NaN  NaN   no  yes   no   good   no   no     ckd
# 29     NaN   ...    38.0      NaN  NaN   no   no  yes   good   no   no     ckd
# 31   107.0   ...    30.0   7800.0  4.0   no   no   no   poor   no   no     ckd
# 32   159.0   ...    34.0   9600.0  4.0  yes  yes   no   poor   no   no     ckd
# 33   140.0   ...    29.0      NaN  NaN  yes   no   no   poor   no   no     ckd
# ..     ...   ...     ...      ...  ...  ...  ...  ...    ...  ...  ...     ...
# 364  118.0   ...    45.0   9300.0  4.7   no   no   no   good   no   no  notckd
# 366   81.0   ...    46.0  10500.0  5.3   no   no   no   good   no   no  notckd
# 367  125.0   ...    50.0   6700.0  6.1   no   no   no   good   no   no  notckd
# 369  107.0   ...    46.0  10300.0  4.8   no   no   no   good   no   no  notckd
# 370   83.0   ...    50.0   9300.0  5.4   no   no   no   good   no   no  notckd
# 372  109.0   ...    52.0  10500.0  5.5   no   no   no   good   no   no  notckd
# 373  133.0   ...    47.0   9200.0  4.9   no   no   no   good   no   no  notckd
# 374  111.0   ...    40.0   8000.0  6.4   no   no   no   good   no   no  notckd
# 375   74.0   ...    48.0   9700.0  5.6   no   no   no   good   no   no  notckd
# 376   88.0   ...    53.0   9100.0  5.2   no   no   no   good   no   no  notckd
# 377   97.0   ...    49.0   6400.0  4.8   no   no   no   good   no   no  notckd
# 378    NaN   ...    42.0   7700.0  5.5   no   no   no   good   no   no  notckd
# 379   78.0   ...    50.0   5400.0  5.7   no   no   no   good   no   no  notckd
# 380  113.0   ...    54.0   6500.0  4.9   no   no   no   good   no   no  notckd
# 381   79.0   ...    40.0   5800.0  5.9   no   no   no   good   no   no  notckd
# 382   75.0   ...    51.0   6000.0  6.5   no   no   no   good   no   no  notckd
# 383  119.0   ...    49.0   5100.0  5.0   no   no   no   good   no   no  notckd
# 384  132.0   ...    42.0  11000.0  4.5   no   no   no   good   no   no  notckd
# 385  113.0   ...    52.0   8000.0  5.1   no   no   no   good   no   no  notckd
# 386  100.0   ...    43.0   5700.0  6.5   no   no   no   good   no   no  notckd
# 388   94.0   ...    46.0   9500.0  6.4   no   no   no   good   no   no  notckd
# 389  112.0   ...    52.0   7200.0  5.8   no   no   no   good   no   no  notckd
# 390   99.0   ...    52.0   6300.0  5.3   no   no   no   good   no   no  notckd
# 391   85.0   ...    44.0   5800.0  6.3   no   no   no   good   no   no  notckd
# 392  133.0   ...    46.0   6600.0  5.5   no   no   no   good   no   no  notckd
# 393  117.0   ...    54.0   7400.0  5.4   no   no   no   good   no   no  notckd
# 394  137.0   ...    45.0   9500.0  4.6   no   no   no   good   no   no  notckd
# 395  140.0   ...    47.0   6700.0  4.9   no   no   no   good   no   no  notckd
# 396   75.0   ...    54.0   7800.0  6.2   no   no   no   good   no   no  notckd
# 399  131.0   ...    53.0   6800.0  6.1   no   no   no   good   no   no  notckd
#
# [340 rows x 25 columns]

# %%
my_df[~(my_df["age"] == 4)] # filter(age == 4)
# my_df[my_df["age"] !=4]
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 0    48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 1     7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent  notpresent
# 2    62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent
# 3    48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 4    51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 5    60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent  notpresent
# 6    68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 7    24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent  notpresent
# 8    52.0  100.0  1.015  3.0  0.0    normal  abnormal     present  notpresent
# 9    53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 10   50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present  notpresent
# 11   63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 12   68.0   70.0  1.015  3.0  1.0       NaN    normal     present  notpresent
# 13   68.0   70.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 14   68.0   80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 15   40.0   80.0  1.015  3.0  0.0       NaN    normal  notpresent  notpresent
# 16   47.0   70.0  1.015  2.0  0.0       NaN    normal  notpresent  notpresent
# 17   47.0   80.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 18   60.0  100.0  1.025  0.0  3.0       NaN    normal  notpresent  notpresent
# 19   62.0   60.0  1.015  1.0  0.0       NaN  abnormal     present  notpresent
# 20   61.0   80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 21   60.0   90.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 22   48.0   80.0  1.025  4.0  0.0    normal  abnormal  notpresent  notpresent
# 23   21.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 24   42.0  100.0  1.015  4.0  0.0    normal  abnormal  notpresent     present
# 25   61.0   60.0  1.025  0.0  0.0       NaN    normal  notpresent  notpresent
# 26   75.0   80.0  1.015  0.0  0.0       NaN    normal  notpresent  notpresent
# 27   69.0   70.0  1.010  3.0  4.0    normal  abnormal  notpresent  notpresent
# 28   75.0   70.0    NaN  1.0  3.0       NaN       NaN  notpresent  notpresent
# 29   68.0   70.0  1.005  1.0  0.0  abnormal  abnormal     present  notpresent
# ..    ...    ...    ...  ...  ...       ...       ...         ...         ...
# 370  69.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 371  28.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 372  72.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 373  61.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 374  79.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 375  70.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 376  58.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 377  64.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 378  71.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 379  62.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 380  59.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 381  71.0   70.0  1.025  0.0  0.0       NaN       NaN  notpresent  notpresent
# 382  48.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 383  80.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 384  57.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 385  63.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 386  46.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 387  15.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 388  51.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 389  41.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 390  52.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 391  36.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 392  57.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 393  43.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 394  50.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 395  55.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 396  42.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 397  12.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 398  17.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 399  58.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
#
#        bgr   ...     pcv       wc   rc  htn   dm  cad  appet   pe  ane   class
# 0    121.0   ...    44.0   7800.0  5.2  yes  yes   no   good   no   no     ckd
# 1      NaN   ...    38.0   6000.0  NaN   no   no   no   good   no   no     ckd
# 2    423.0   ...    31.0   7500.0  NaN   no  yes   no   poor   no  yes     ckd
# 3    117.0   ...    32.0   6700.0  3.9  yes   no   no   poor  yes  yes     ckd
# 4    106.0   ...    35.0   7300.0  4.6   no   no   no   good   no   no     ckd
# 5     74.0   ...    39.0   7800.0  4.4  yes  yes   no   good  yes   no     ckd
# 6    100.0   ...    36.0      NaN  NaN   no   no   no   good   no   no     ckd
# 7    410.0   ...    44.0   6900.0  5.0   no  yes   no   good  yes   no     ckd
# 8    138.0   ...    33.0   9600.0  4.0  yes  yes   no   good   no  yes     ckd
# 9     70.0   ...    29.0  12100.0  3.7  yes  yes   no   poor   no  yes     ckd
# 10   490.0   ...    28.0      NaN  NaN  yes  yes   no   good   no  yes     ckd
# 11   380.0   ...    32.0   4500.0  3.8  yes  yes   no   poor  yes   no     ckd
# 12   208.0   ...    28.0  12200.0  3.4  yes  yes  yes   poor  yes   no     ckd
# 13    98.0   ...     NaN      NaN  NaN  yes  yes  yes   poor  yes   no     ckd
# 14   157.0   ...    16.0  11000.0  2.6  yes  yes  yes   poor  yes   no     ckd
# 15    76.0   ...    24.0   3800.0  2.8  yes   no   no   good   no  yes     ckd
# 16    99.0   ...     NaN      NaN  NaN   no   no   no   good   no   no     ckd
# 17   114.0   ...     NaN      NaN  NaN  yes   no   no   poor   no   no     ckd
# 18   263.0   ...    37.0  11400.0  4.3  yes  yes  yes   good   no   no     ckd
# 19   100.0   ...    30.0   5300.0  3.7  yes   no  yes   good   no   no     ckd
# 20   173.0   ...    24.0   9200.0  3.2  yes  yes  yes   poor  yes  yes     ckd
# 21     NaN   ...    32.0   6200.0  3.6  yes  yes  yes   good   no   no     ckd
# 22    95.0   ...    32.0   6900.0  3.4  yes   no   no   good   no  yes     ckd
# 23     NaN   ...     NaN      NaN  NaN   no   no   no   poor   no  yes     ckd
# 24     NaN   ...    39.0   8300.0  4.6  yes   no   no   poor   no   no     ckd
# 25   108.0   ...    29.0   8400.0  3.7  yes  yes   no   good   no  yes     ckd
# 26   156.0   ...    35.0  10300.0  4.0  yes  yes   no   poor   no   no     ckd
# 27   264.0   ...    37.0   9600.0  4.1  yes  yes  yes   good  yes   no     ckd
# 28   123.0   ...     NaN      NaN  NaN   no  yes   no   good   no   no     ckd
# 29     NaN   ...    38.0      NaN  NaN   no   no  yes   good   no   no     ckd
# ..     ...   ...     ...      ...  ...  ...  ...  ...    ...  ...  ...     ...
# 370   83.0   ...    50.0   9300.0  5.4   no   no   no   good   no   no  notckd
# 371   79.0   ...    51.0   6500.0  5.0   no   no   no   good   no   no  notckd
# 372  109.0   ...    52.0  10500.0  5.5   no   no   no   good   no   no  notckd
# 373  133.0   ...    47.0   9200.0  4.9   no   no   no   good   no   no  notckd
# 374  111.0   ...    40.0   8000.0  6.4   no   no   no   good   no   no  notckd
# 375   74.0   ...    48.0   9700.0  5.6   no   no   no   good   no   no  notckd
# 376   88.0   ...    53.0   9100.0  5.2   no   no   no   good   no   no  notckd
# 377   97.0   ...    49.0   6400.0  4.8   no   no   no   good   no   no  notckd
# 378    NaN   ...    42.0   7700.0  5.5   no   no   no   good   no   no  notckd
# 379   78.0   ...    50.0   5400.0  5.7   no   no   no   good   no   no  notckd
# 380  113.0   ...    54.0   6500.0  4.9   no   no   no   good   no   no  notckd
# 381   79.0   ...    40.0   5800.0  5.9   no   no   no   good   no   no  notckd
# 382   75.0   ...    51.0   6000.0  6.5   no   no   no   good   no   no  notckd
# 383  119.0   ...    49.0   5100.0  5.0   no   no   no   good   no   no  notckd
# 384  132.0   ...    42.0  11000.0  4.5   no   no   no   good   no   no  notckd
# 385  113.0   ...    52.0   8000.0  5.1   no   no   no   good   no   no  notckd
# 386  100.0   ...    43.0   5700.0  6.5   no   no   no   good   no   no  notckd
# 387   93.0   ...    50.0   6200.0  5.2   no   no   no   good   no   no  notckd
# 388   94.0   ...    46.0   9500.0  6.4   no   no   no   good   no   no  notckd
# 389  112.0   ...    52.0   7200.0  5.8   no   no   no   good   no   no  notckd
# 390   99.0   ...    52.0   6300.0  5.3   no   no   no   good   no   no  notckd
# 391   85.0   ...    44.0   5800.0  6.3   no   no   no   good   no   no  notckd
# 392  133.0   ...    46.0   6600.0  5.5   no   no   no   good   no   no  notckd
# 393  117.0   ...    54.0   7400.0  5.4   no   no   no   good   no   no  notckd
# 394  137.0   ...    45.0   9500.0  4.6   no   no   no   good   no   no  notckd
# 395  140.0   ...    47.0   6700.0  4.9   no   no   no   good   no   no  notckd
# 396   75.0   ...    54.0   7800.0  6.2   no   no   no   good   no   no  notckd
# 397  100.0   ...    49.0   6600.0  5.4   no   no   no   good   no   no  notckd
# 398  114.0   ...    51.0   7200.0  5.9   no   no   no   good   no   no  notckd
# 399  131.0   ...    53.0   6800.0  6.1   no   no   no   good   no   no  notckd
#
# [399 rows x 25 columns]

# %% [markdown]
# ### Indexing Method 3 - Select by Integer Location:

# %%
series_1 = pd.Series(np.arange(5), index = ["a", "b", "c", "d", 4])
series_1
# Out:
# a    0
# b    1
# c    2
# d    3
# 4    4
# dtype: int64

# %% [markdown]
# ### Access with Integer - Series:

# %%
series_1.iloc[2] # 3rd row
# Out:
# 2

# %% [markdown]
# ### Access with Integer - DataFrame:

# %%
my_df.iloc[1, 2] # 2nd row, 3rd column
# Out:
# 1.88

# %% [markdown]
# ### Access with List of Integers - Series:

# %%
series_1.iloc[[1,2,4]] # 2nd, 3rd and 5th rows
# Out:
# b    1
# c    2
# 4    4
# dtype: int64

# %%
### Access with List of Integers - DataFrame:

# %%
my_df.iloc[[0,2], [1,2]] # 1st row and 3rd row, 2nd and 3rd columns
# Out:
#    PRE4  PRE5
# 0  2.88  2.16
# 2  2.76  2.08

# %% [markdown]
# ### Access with Slice Object - Series:

# %%
series_1.iloc[2:4] # 3rd and 4th rows
# Out:
# c    2
# d    3
# dtype: int64

# %%
series_1.iloc[2:10] # out-of-bound indexing is handled gracefully
# Out:
# c    2
# d    3
# 4    4
# dtype: int64

# %%
series_1.iloc[10:] # out-of-bound indexing is handled gracefully
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Access with Slice Object - DataFrame:

# %%
my_df.iloc[1:, :] # 2nd and 3rd rows, all columns
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 1     7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent  notpresent
# 2    62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent
# 3    48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 4    51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 5    60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent  notpresent
# 6    68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 7    24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent  notpresent
# 8    52.0  100.0  1.015  3.0  0.0    normal  abnormal     present  notpresent
# 9    53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 10   50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present  notpresent
# 11   63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 12   68.0   70.0  1.015  3.0  1.0       NaN    normal     present  notpresent
# 13   68.0   70.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 14   68.0   80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 15   40.0   80.0  1.015  3.0  0.0       NaN    normal  notpresent  notpresent
# 16   47.0   70.0  1.015  2.0  0.0       NaN    normal  notpresent  notpresent
# 17   47.0   80.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 18   60.0  100.0  1.025  0.0  3.0       NaN    normal  notpresent  notpresent
# 19   62.0   60.0  1.015  1.0  0.0       NaN  abnormal     present  notpresent
# 20   61.0   80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 21   60.0   90.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 22   48.0   80.0  1.025  4.0  0.0    normal  abnormal  notpresent  notpresent
# 23   21.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 24   42.0  100.0  1.015  4.0  0.0    normal  abnormal  notpresent     present
# 25   61.0   60.0  1.025  0.0  0.0       NaN    normal  notpresent  notpresent
# 26   75.0   80.0  1.015  0.0  0.0       NaN    normal  notpresent  notpresent
# 27   69.0   70.0  1.010  3.0  4.0    normal  abnormal  notpresent  notpresent
# 28   75.0   70.0    NaN  1.0  3.0       NaN       NaN  notpresent  notpresent
# 29   68.0   70.0  1.005  1.0  0.0  abnormal  abnormal     present  notpresent
# 30    NaN   70.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# ..    ...    ...    ...  ...  ...       ...       ...         ...         ...
# 370  69.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 371  28.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 372  72.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 373  61.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 374  79.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 375  70.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 376  58.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 377  64.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 378  71.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 379  62.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 380  59.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 381  71.0   70.0  1.025  0.0  0.0       NaN       NaN  notpresent  notpresent
# 382  48.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 383  80.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 384  57.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 385  63.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 386  46.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 387  15.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 388  51.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 389  41.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 390  52.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 391  36.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 392  57.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 393  43.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 394  50.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 395  55.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 396  42.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 397  12.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 398  17.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 399  58.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
#
#        bgr   ...     pcv       wc   rc  htn    dm  cad  appet   pe  ane  \
# 1      NaN   ...    38.0   6000.0  NaN   no    no   no   good   no   no
# 2    423.0   ...    31.0   7500.0  NaN   no   yes   no   poor   no  yes
# 3    117.0   ...    32.0   6700.0  3.9  yes    no   no   poor  yes  yes
# 4    106.0   ...    35.0   7300.0  4.6   no    no   no   good   no   no
# 5     74.0   ...    39.0   7800.0  4.4  yes   yes   no   good  yes   no
# 6    100.0   ...    36.0      NaN  NaN   no    no   no   good   no   no
# 7    410.0   ...    44.0   6900.0  5.0   no   yes   no   good  yes   no
# 8    138.0   ...    33.0   9600.0  4.0  yes   yes   no   good   no  yes
# 9     70.0   ...    29.0  12100.0  3.7  yes   yes   no   poor   no  yes
# 10   490.0   ...    28.0      NaN  NaN  yes   yes   no   good   no  yes
# 11   380.0   ...    32.0   4500.0  3.8  yes   yes   no   poor  yes   no
# 12   208.0   ...    28.0  12200.0  3.4  yes   yes  yes   poor  yes   no
# 13    98.0   ...     NaN      NaN  NaN  yes   yes  yes   poor  yes   no
# 14   157.0   ...    16.0  11000.0  2.6  yes   yes  yes   poor  yes   no
# 15    76.0   ...    24.0   3800.0  2.8  yes    no   no   good   no  yes
# 16    99.0   ...     NaN      NaN  NaN   no    no   no   good   no   no
# 17   114.0   ...     NaN      NaN  NaN  yes    no   no   poor   no   no
# 18   263.0   ...    37.0  11400.0  4.3  yes   yes  yes   good   no   no
# 19   100.0   ...    30.0   5300.0  3.7  yes    no  yes   good   no   no
# 20   173.0   ...    24.0   9200.0  3.2  yes   yes  yes   poor  yes  yes
# 21     NaN   ...    32.0   6200.0  3.6  yes   yes  yes   good   no   no
# 22    95.0   ...    32.0   6900.0  3.4  yes    no   no   good   no  yes
# 23     NaN   ...     NaN      NaN  NaN   no    no   no   poor   no  yes
# 24     NaN   ...    39.0   8300.0  4.6  yes    no   no   poor   no   no
# 25   108.0   ...    29.0   8400.0  3.7  yes   yes   no   good   no  yes
# 26   156.0   ...    35.0  10300.0  4.0  yes   yes   no   poor   no   no
# 27   264.0   ...    37.0   9600.0  4.1  yes   yes  yes   good  yes   no
# 28   123.0   ...     NaN      NaN  NaN   no   yes   no   good   no   no
# 29     NaN   ...    38.0      NaN  NaN   no    no  yes   good   no   no
# 30    93.0   ...     NaN      NaN  NaN  yes   yes   no   good   no   no
# ..     ...   ...     ...      ...  ...  ...   ...  ...    ...  ...  ...
# 370   83.0   ...    50.0   9300.0  5.4   no    no   no   good   no   no
# 371   79.0   ...    51.0   6500.0  5.0   no    no   no   good   no   no
# 372  109.0   ...    52.0  10500.0  5.5   no    no   no   good   no   no
# 373  133.0   ...    47.0   9200.0  4.9   no    no   no   good   no   no
# 374  111.0   ...    40.0   8000.0  6.4   no    no   no   good   no   no
# 375   74.0   ...    48.0   9700.0  5.6   no    no   no   good   no   no
# 376   88.0   ...    53.0   9100.0  5.2   no    no   no   good   no   no
# 377   97.0   ...    49.0   6400.0  4.8   no    no   no   good   no   no
# 378    NaN   ...    42.0   7700.0  5.5   no    no   no   good   no   no
# 379   78.0   ...    50.0   5400.0  5.7   no    no   no   good   no   no
# 380  113.0   ...    54.0   6500.0  4.9   no    no   no   good   no   no
# 381   79.0   ...    40.0   5800.0  5.9   no    no   no   good   no   no
# 382   75.0   ...    51.0   6000.0  6.5   no    no   no   good   no   no
# 383  119.0   ...    49.0   5100.0  5.0   no    no   no   good   no   no
# 384  132.0   ...    42.0  11000.0  4.5   no    no   no   good   no   no
# 385  113.0   ...    52.0   8000.0  5.1   no    no   no   good   no   no
# 386  100.0   ...    43.0   5700.0  6.5   no    no   no   good   no   no
# 387   93.0   ...    50.0   6200.0  5.2   no    no   no   good   no   no
# 388   94.0   ...    46.0   9500.0  6.4   no    no   no   good   no   no
# 389  112.0   ...    52.0   7200.0  5.8   no    no   no   good   no   no
# 390   99.0   ...    52.0   6300.0  5.3   no    no   no   good   no   no
# 391   85.0   ...    44.0   5800.0  6.3   no    no   no   good   no   no
# 392  133.0   ...    46.0   6600.0  5.5   no    no   no   good   no   no
# 393  117.0   ...    54.0   7400.0  5.4   no    no   no   good   no   no
# 394  137.0   ...    45.0   9500.0  4.6   no    no   no   good   no   no
# 395  140.0   ...    47.0   6700.0  4.9   no    no   no   good   no   no
# 396   75.0   ...    54.0   7800.0  6.2   no    no   no   good   no   no
# 397  100.0   ...    49.0   6600.0  5.4   no    no   no   good   no   no
# 398  114.0   ...    51.0   7200.0  5.9   no    no   no   good   no   no
# 399  131.0   ...    53.0   6800.0  6.1   no    no   no   good   no   no
#
#       class
# 1       ckd
# 2       ckd
# 3       ckd
# 4       ckd
# 5       ckd
# 6       ckd
# 7       ckd
# 8       ckd
# 9       ckd
# 10      ckd
# 11      ckd
# 12      ckd
# 13      ckd
# 14      ckd
# 15      ckd
# 16      ckd
# 17      ckd
# 18      ckd
# 19      ckd
# 20      ckd
# 21      ckd
# 22      ckd
# 23      ckd
# 24      ckd
# 25      ckd
# 26      ckd
# 27      ckd
# 28      ckd
# 29      ckd
# 30      ckd
# ..      ...
# 370  notckd
# 371  notckd
# 372  notckd
# 373  notckd
# 374  notckd
# 375  notckd
# 376  notckd
# 377  notckd
# 378  notckd
# 379  notckd
# 380  notckd
# 381  notckd
# 382  notckd
# 383  notckd
# 384  notckd
# 385  notckd
# 386  notckd
# 387  notckd
# 388  notckd
# 389  notckd
# 390  notckd
# 391  notckd
# 392  notckd
# 393  notckd
# 394  notckd
# 395  notckd
# 396  notckd
# 397  notckd
# 398  notckd
# 399  notckd
#
# [399 rows x 25 columns]

# %%
my_df.iloc[1:, [0,1,2]] # mix of slice object and list of integers
# Out:
#       age     bp     sg
# 1     7.0   50.0  1.020
# 2    62.0   80.0  1.010
# 3    48.0   70.0  1.005
# 4    51.0   80.0  1.010
# 5    60.0   90.0  1.015
# 6    68.0   70.0  1.010
# 7    24.0    NaN  1.015
# 8    52.0  100.0  1.015
# 9    53.0   90.0  1.020
# 10   50.0   60.0  1.010
# 11   63.0   70.0  1.010
# 12   68.0   70.0  1.015
# 13   68.0   70.0    NaN
# 14   68.0   80.0  1.010
# 15   40.0   80.0  1.015
# 16   47.0   70.0  1.015
# 17   47.0   80.0    NaN
# 18   60.0  100.0  1.025
# 19   62.0   60.0  1.015
# 20   61.0   80.0  1.015
# 21   60.0   90.0    NaN
# 22   48.0   80.0  1.025
# 23   21.0   70.0  1.010
# 24   42.0  100.0  1.015
# 25   61.0   60.0  1.025
# 26   75.0   80.0  1.015
# 27   69.0   70.0  1.010
# 28   75.0   70.0    NaN
# 29   68.0   70.0  1.005
# 30    NaN   70.0    NaN
# ..    ...    ...    ...
# 370  69.0   70.0  1.020
# 371  28.0   60.0  1.025
# 372  72.0   60.0  1.020
# 373  61.0   70.0  1.025
# 374  79.0   80.0  1.025
# 375  70.0   80.0  1.020
# 376  58.0   70.0  1.025
# 377  64.0   70.0  1.020
# 378  71.0   60.0  1.025
# 379  62.0   80.0  1.025
# 380  59.0   60.0  1.020
# 381  71.0   70.0  1.025
# 382  48.0   80.0  1.025
# 383  80.0   80.0  1.025
# 384  57.0   60.0  1.020
# 385  63.0   70.0  1.020
# 386  46.0   70.0  1.025
# 387  15.0   80.0  1.025
# 388  51.0   80.0  1.020
# 389  41.0   80.0  1.025
# 390  52.0   80.0  1.025
# 391  36.0   80.0  1.025
# 392  57.0   80.0  1.020
# 393  43.0   60.0  1.025
# 394  50.0   80.0  1.020
# 395  55.0   80.0  1.020
# 396  42.0   70.0  1.025
# 397  12.0   80.0  1.020
# 398  17.0   60.0  1.025
# 399  58.0   80.0  1.025
#
# [399 rows x 3 columns]

# %%
my_df.iloc[:, 2:8] # out-of-bound indexing is handled gracefully
# Out:
#         sg   al   su       rbc        pc         pcc
# 0    1.020  1.0  0.0       NaN    normal  notpresent
# 1    1.020  4.0  0.0       NaN    normal  notpresent
# 2    1.010  2.0  3.0    normal    normal  notpresent
# 3    1.005  4.0  0.0    normal  abnormal     present
# 4    1.010  2.0  0.0    normal    normal  notpresent
# 5    1.015  3.0  0.0       NaN       NaN  notpresent
# 6    1.010  0.0  0.0       NaN    normal  notpresent
# 7    1.015  2.0  4.0    normal  abnormal  notpresent
# 8    1.015  3.0  0.0    normal  abnormal     present
# 9    1.020  2.0  0.0  abnormal  abnormal     present
# 10   1.010  2.0  4.0       NaN  abnormal     present
# 11   1.010  3.0  0.0  abnormal  abnormal     present
# 12   1.015  3.0  1.0       NaN    normal     present
# 13     NaN  NaN  NaN       NaN       NaN  notpresent
# 14   1.010  3.0  2.0    normal  abnormal     present
# 15   1.015  3.0  0.0       NaN    normal  notpresent
# 16   1.015  2.0  0.0       NaN    normal  notpresent
# 17     NaN  NaN  NaN       NaN       NaN  notpresent
# 18   1.025  0.0  3.0       NaN    normal  notpresent
# 19   1.015  1.0  0.0       NaN  abnormal     present
# 20   1.015  2.0  0.0  abnormal  abnormal  notpresent
# 21     NaN  NaN  NaN       NaN       NaN  notpresent
# 22   1.025  4.0  0.0    normal  abnormal  notpresent
# 23   1.010  0.0  0.0       NaN    normal  notpresent
# 24   1.015  4.0  0.0    normal  abnormal  notpresent
# 25   1.025  0.0  0.0       NaN    normal  notpresent
# 26   1.015  0.0  0.0       NaN    normal  notpresent
# 27   1.010  3.0  4.0    normal  abnormal  notpresent
# 28     NaN  1.0  3.0       NaN       NaN  notpresent
# 29   1.005  1.0  0.0  abnormal  abnormal     present
# ..     ...  ...  ...       ...       ...         ...
# 370  1.020  0.0  0.0    normal    normal  notpresent
# 371  1.025  0.0  0.0    normal    normal  notpresent
# 372  1.020  0.0  0.0    normal    normal  notpresent
# 373  1.025  0.0  0.0    normal    normal  notpresent
# 374  1.025  0.0  0.0    normal    normal  notpresent
# 375  1.020  0.0  0.0    normal    normal  notpresent
# 376  1.025  0.0  0.0    normal    normal  notpresent
# 377  1.020  0.0  0.0    normal    normal  notpresent
# 378  1.025  0.0  0.0    normal    normal  notpresent
# 379  1.025  0.0  0.0    normal    normal  notpresent
# 380  1.020  0.0  0.0    normal    normal  notpresent
# 381  1.025  0.0  0.0       NaN       NaN  notpresent
# 382  1.025  0.0  0.0    normal    normal  notpresent
# 383  1.025  0.0  0.0    normal    normal  notpresent
# 384  1.020  0.0  0.0    normal    normal  notpresent
# 385  1.020  0.0  0.0    normal    normal  notpresent
# 386  1.025  0.0  0.0    normal    normal  notpresent
# 387  1.025  0.0  0.0    normal    normal  notpresent
# 388  1.020  0.0  0.0    normal    normal  notpresent
# 389  1.025  0.0  0.0    normal    normal  notpresent
# 390  1.025  0.0  0.0    normal    normal  notpresent
# 391  1.025  0.0  0.0    normal    normal  notpresent
# 392  1.020  0.0  0.0    normal    normal  notpresent
# 393  1.025  0.0  0.0    normal    normal  notpresent
# 394  1.020  0.0  0.0    normal    normal  notpresent
# 395  1.020  0.0  0.0    normal    normal  notpresent
# 396  1.025  0.0  0.0    normal    normal  notpresent
# 397  1.020  0.0  0.0    normal    normal  notpresent
# 398  1.025  0.0  0.0    normal    normal  notpresent
# 399  1.025  0.0  0.0    normal    normal  notpresent
#
# [400 rows x 6 columns]

# %% [markdown]
# ### Access with Boolean Array - Series:

# %%
series_1.iloc[2] > 1
# Out:
# True

# %%
### Access with Boolean Array - DataFrame:

# %%
my_df.iloc[:, 2] > 3
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13      True
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20      True
# 21     False
# 22     False
# 23     False
# 24      True
# 25      True
# 26      True
# 27      True
# 28     False
# 29      True
#        ...
# 440    False
# 441     True
# 442    False
# 443     True
# 444     True
# 445    False
# 446     True
# 447     True
# 448    False
# 449    False
# 450    False
# 451    False
# 452    False
# 453    False
# 454    False
# 455    False
# 456    False
# 457     True
# 458    False
# 459     True
# 460     True
# 461    False
# 462    False
# 463    False
# 464    False
# 465    False
# 466     True
# 467    False
# 468    False
# 469     True
# Name: PRE5, Length: 470, dtype: bool

# %% [markdown]
# ### Boolean Indexing - Series:

# %%
series_1[series_1 > 2] # all rows greater than 2
# Out:
# d    3
# 4    4
# dtype: int64

# %%
series_1[(series_1 > 2) & (series_1 < 4)] # all rows greater than 2 AND less than 4
# Out:
# d    3
# dtype: int64

# %%
series_1[~(series_1 == 0)] # all rows not equal to 0

# %% [markdown]
# ### Boolean Indexing - DataFrames:

# %%
my_df[my_df["age"] > 30] # all rows with PRE4 greater than 3
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 0    48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 2    62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent
# 3    48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 4    51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 5    60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent  notpresent
# 6    68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 8    52.0  100.0  1.015  3.0  0.0    normal  abnormal     present  notpresent
# 9    53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 10   50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present  notpresent
# 11   63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 12   68.0   70.0  1.015  3.0  1.0       NaN    normal     present  notpresent
# 13   68.0   70.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 14   68.0   80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 15   40.0   80.0  1.015  3.0  0.0       NaN    normal  notpresent  notpresent
# 16   47.0   70.0  1.015  2.0  0.0       NaN    normal  notpresent  notpresent
# 17   47.0   80.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 18   60.0  100.0  1.025  0.0  3.0       NaN    normal  notpresent  notpresent
# 19   62.0   60.0  1.015  1.0  0.0       NaN  abnormal     present  notpresent
# 20   61.0   80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 21   60.0   90.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 22   48.0   80.0  1.025  4.0  0.0    normal  abnormal  notpresent  notpresent
# 24   42.0  100.0  1.015  4.0  0.0    normal  abnormal  notpresent     present
# 25   61.0   60.0  1.025  0.0  0.0       NaN    normal  notpresent  notpresent
# 26   75.0   80.0  1.015  0.0  0.0       NaN    normal  notpresent  notpresent
# 27   69.0   70.0  1.010  3.0  4.0    normal  abnormal  notpresent  notpresent
# 28   75.0   70.0    NaN  1.0  3.0       NaN       NaN  notpresent  notpresent
# 29   68.0   70.0  1.005  1.0  0.0  abnormal  abnormal     present  notpresent
# 31   73.0   90.0  1.015  3.0  0.0       NaN  abnormal     present  notpresent
# 32   61.0   90.0  1.010  1.0  1.0       NaN    normal  notpresent  notpresent
# 33   60.0  100.0  1.020  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# ..    ...    ...    ...  ...  ...       ...       ...         ...         ...
# 364  73.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 366  60.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 367  68.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 369  75.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 370  69.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 372  72.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 373  61.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 374  79.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 375  70.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 376  58.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 377  64.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 378  71.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 379  62.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 380  59.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 381  71.0   70.0  1.025  0.0  0.0       NaN       NaN  notpresent  notpresent
# 382  48.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 383  80.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 384  57.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 385  63.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 386  46.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 388  51.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 389  41.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 390  52.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 391  36.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 392  57.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 393  43.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 394  50.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 395  55.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 396  42.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 399  58.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
#
#        bgr   ...     pcv       wc   rc  htn   dm  cad  appet   pe  ane   class
# 0    121.0   ...    44.0   7800.0  5.2  yes  yes   no   good   no   no     ckd
# 2    423.0   ...    31.0   7500.0  NaN   no  yes   no   poor   no  yes     ckd
# 3    117.0   ...    32.0   6700.0  3.9  yes   no   no   poor  yes  yes     ckd
# 4    106.0   ...    35.0   7300.0  4.6   no   no   no   good   no   no     ckd
# 5     74.0   ...    39.0   7800.0  4.4  yes  yes   no   good  yes   no     ckd
# 6    100.0   ...    36.0      NaN  NaN   no   no   no   good   no   no     ckd
# 8    138.0   ...    33.0   9600.0  4.0  yes  yes   no   good   no  yes     ckd
# 9     70.0   ...    29.0  12100.0  3.7  yes  yes   no   poor   no  yes     ckd
# 10   490.0   ...    28.0      NaN  NaN  yes  yes   no   good   no  yes     ckd
# 11   380.0   ...    32.0   4500.0  3.8  yes  yes   no   poor  yes   no     ckd
# 12   208.0   ...    28.0  12200.0  3.4  yes  yes  yes   poor  yes   no     ckd
# 13    98.0   ...     NaN      NaN  NaN  yes  yes  yes   poor  yes   no     ckd
# 14   157.0   ...    16.0  11000.0  2.6  yes  yes  yes   poor  yes   no     ckd
# 15    76.0   ...    24.0   3800.0  2.8  yes   no   no   good   no  yes     ckd
# 16    99.0   ...     NaN      NaN  NaN   no   no   no   good   no   no     ckd
# 17   114.0   ...     NaN      NaN  NaN  yes   no   no   poor   no   no     ckd
# 18   263.0   ...    37.0  11400.0  4.3  yes  yes  yes   good   no   no     ckd
# 19   100.0   ...    30.0   5300.0  3.7  yes   no  yes   good   no   no     ckd
# 20   173.0   ...    24.0   9200.0  3.2  yes  yes  yes   poor  yes  yes     ckd
# 21     NaN   ...    32.0   6200.0  3.6  yes  yes  yes   good   no   no     ckd
# 22    95.0   ...    32.0   6900.0  3.4  yes   no   no   good   no  yes     ckd
# 24     NaN   ...    39.0   8300.0  4.6  yes   no   no   poor   no   no     ckd
# 25   108.0   ...    29.0   8400.0  3.7  yes  yes   no   good   no  yes     ckd
# 26   156.0   ...    35.0  10300.0  4.0  yes  yes   no   poor   no   no     ckd
# 27   264.0   ...    37.0   9600.0  4.1  yes  yes  yes   good  yes   no     ckd
# 28   123.0   ...     NaN      NaN  NaN   no  yes   no   good   no   no     ckd
# 29     NaN   ...    38.0      NaN  NaN   no   no  yes   good   no   no     ckd
# 31   107.0   ...    30.0   7800.0  4.0   no   no   no   poor   no   no     ckd
# 32   159.0   ...    34.0   9600.0  4.0  yes  yes   no   poor   no   no     ckd
# 33   140.0   ...    29.0      NaN  NaN  yes   no   no   poor   no   no     ckd
# ..     ...   ...     ...      ...  ...  ...  ...  ...    ...  ...  ...     ...
# 364  118.0   ...    45.0   9300.0  4.7   no   no   no   good   no   no  notckd
# 366   81.0   ...    46.0  10500.0  5.3   no   no   no   good   no   no  notckd
# 367  125.0   ...    50.0   6700.0  6.1   no   no   no   good   no   no  notckd
# 369  107.0   ...    46.0  10300.0  4.8   no   no   no   good   no   no  notckd
# 370   83.0   ...    50.0   9300.0  5.4   no   no   no   good   no   no  notckd
# 372  109.0   ...    52.0  10500.0  5.5   no   no   no   good   no   no  notckd
# 373  133.0   ...    47.0   9200.0  4.9   no   no   no   good   no   no  notckd
# 374  111.0   ...    40.0   8000.0  6.4   no   no   no   good   no   no  notckd
# 375   74.0   ...    48.0   9700.0  5.6   no   no   no   good   no   no  notckd
# 376   88.0   ...    53.0   9100.0  5.2   no   no   no   good   no   no  notckd
# 377   97.0   ...    49.0   6400.0  4.8   no   no   no   good   no   no  notckd
# 378    NaN   ...    42.0   7700.0  5.5   no   no   no   good   no   no  notckd
# 379   78.0   ...    50.0   5400.0  5.7   no   no   no   good   no   no  notckd
# 380  113.0   ...    54.0   6500.0  4.9   no   no   no   good   no   no  notckd
# 381   79.0   ...    40.0   5800.0  5.9   no   no   no   good   no   no  notckd
# 382   75.0   ...    51.0   6000.0  6.5   no   no   no   good   no   no  notckd
# 383  119.0   ...    49.0   5100.0  5.0   no   no   no   good   no   no  notckd
# 384  132.0   ...    42.0  11000.0  4.5   no   no   no   good   no   no  notckd
# 385  113.0   ...    52.0   8000.0  5.1   no   no   no   good   no   no  notckd
# 386  100.0   ...    43.0   5700.0  6.5   no   no   no   good   no   no  notckd
# 388   94.0   ...    46.0   9500.0  6.4   no   no   no   good   no   no  notckd
# 389  112.0   ...    52.0   7200.0  5.8   no   no   no   good   no   no  notckd
# 390   99.0   ...    52.0   6300.0  5.3   no   no   no   good   no   no  notckd
# 391   85.0   ...    44.0   5800.0  6.3   no   no   no   good   no   no  notckd
# 392  133.0   ...    46.0   6600.0  5.5   no   no   no   good   no   no  notckd
# 393  117.0   ...    54.0   7400.0  5.4   no   no   no   good   no   no  notckd
# 394  137.0   ...    45.0   9500.0  4.6   no   no   no   good   no   no  notckd
# 395  140.0   ...    47.0   6700.0  4.9   no   no   no   good   no   no  notckd
# 396   75.0   ...    54.0   7800.0  6.2   no   no   no   good   no   no  notckd
# 399  131.0   ...    53.0   6800.0  6.1   no   no   no   good   no   no  notckd
#
# [340 rows x 25 columns]

# %%
my_df[(my_df["age"] > 30) & (my_df["bp"] < 90)] # all rows with PRE4 between 3 and 3.6 exclusive
# Out:
#       age    bp     sg   al   su       rbc        pc         pcc          ba  \
# 0    48.0  80.0  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 2    62.0  80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent
# 3    48.0  70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 4    51.0  80.0  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 6    68.0  70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 10   50.0  60.0  1.010  2.0  4.0       NaN  abnormal     present  notpresent
# 11   63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 12   68.0  70.0  1.015  3.0  1.0       NaN    normal     present  notpresent
# 13   68.0  70.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 14   68.0  80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 15   40.0  80.0  1.015  3.0  0.0       NaN    normal  notpresent  notpresent
# 16   47.0  70.0  1.015  2.0  0.0       NaN    normal  notpresent  notpresent
# 17   47.0  80.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 19   62.0  60.0  1.015  1.0  0.0       NaN  abnormal     present  notpresent
# 20   61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 22   48.0  80.0  1.025  4.0  0.0    normal  abnormal  notpresent  notpresent
# 25   61.0  60.0  1.025  0.0  0.0       NaN    normal  notpresent  notpresent
# 26   75.0  80.0  1.015  0.0  0.0       NaN    normal  notpresent  notpresent
# 27   69.0  70.0  1.010  3.0  4.0    normal  abnormal  notpresent  notpresent
# 28   75.0  70.0    NaN  1.0  3.0       NaN       NaN  notpresent  notpresent
# 29   68.0  70.0  1.005  1.0  0.0  abnormal  abnormal     present  notpresent
# 34   70.0  70.0  1.010  1.0  0.0    normal       NaN     present     present
# 36   76.0  70.0  1.015  1.0  0.0    normal    normal  notpresent  notpresent
# 37   72.0  80.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 38   69.0  80.0  1.020  3.0  0.0  abnormal    normal  notpresent  notpresent
# 39   82.0  80.0  1.010  2.0  2.0    normal       NaN  notpresent  notpresent
# 41   45.0  70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 43   35.0  80.0  1.010  1.0  0.0  abnormal       NaN  notpresent  notpresent
# 44   54.0  80.0  1.010  3.0  0.0  abnormal  abnormal  notpresent  notpresent
# 45   54.0  80.0  1.020  3.0  0.0       NaN  abnormal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...       ...       ...         ...         ...
# 364  73.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 366  60.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 367  68.0  60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 369  75.0  70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 370  69.0  70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 372  72.0  60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 373  61.0  70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 374  79.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 375  70.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 376  58.0  70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 377  64.0  70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 378  71.0  60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 379  62.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 380  59.0  60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 381  71.0  70.0  1.025  0.0  0.0       NaN       NaN  notpresent  notpresent
# 382  48.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 383  80.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 384  57.0  60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 385  63.0  70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 386  46.0  70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 388  51.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 389  41.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 390  52.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 391  36.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 392  57.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 393  43.0  60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 394  50.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
#
#        bgr   ...     pcv       wc   rc  htn   dm  cad  appet   pe  ane   class
# 0    121.0   ...    44.0   7800.0  5.2  yes  yes   no   good   no   no     ckd
# 2    423.0   ...    31.0   7500.0  NaN   no  yes   no   poor   no  yes     ckd
# 3    117.0   ...    32.0   6700.0  3.9  yes   no   no   poor  yes  yes     ckd
# 4    106.0   ...    35.0   7300.0  4.6   no   no   no   good   no   no     ckd
# 6    100.0   ...    36.0      NaN  NaN   no   no   no   good   no   no     ckd
# 10   490.0   ...    28.0      NaN  NaN  yes  yes   no   good   no  yes     ckd
# 11   380.0   ...    32.0   4500.0  3.8  yes  yes   no   poor  yes   no     ckd
# 12   208.0   ...    28.0  12200.0  3.4  yes  yes  yes   poor  yes   no     ckd
# 13    98.0   ...     NaN      NaN  NaN  yes  yes  yes   poor  yes   no     ckd
# 14   157.0   ...    16.0  11000.0  2.6  yes  yes  yes   poor  yes   no     ckd
# 15    76.0   ...    24.0   3800.0  2.8  yes   no   no   good   no  yes     ckd
# 16    99.0   ...     NaN      NaN  NaN   no   no   no   good   no   no     ckd
# 17   114.0   ...     NaN      NaN  NaN  yes   no   no   poor   no   no     ckd
# 19   100.0   ...    30.0   5300.0  3.7  yes   no  yes   good   no   no     ckd
# 20   173.0   ...    24.0   9200.0  3.2  yes  yes  yes   poor  yes  yes     ckd
# 22    95.0   ...    32.0   6900.0  3.4  yes   no   no   good   no  yes     ckd
# 25   108.0   ...    29.0   8400.0  3.7  yes  yes   no   good   no  yes     ckd
# 26   156.0   ...    35.0  10300.0  4.0  yes  yes   no   poor   no   no     ckd
# 27   264.0   ...    37.0   9600.0  4.1  yes  yes  yes   good  yes   no     ckd
# 28   123.0   ...     NaN      NaN  NaN   no  yes   no   good   no   no     ckd
# 29     NaN   ...    38.0      NaN  NaN   no   no  yes   good   no   no     ckd
# 34   171.0   ...     NaN      NaN  NaN   no  yes   no   poor   no   no     ckd
# 36    92.0   ...    32.0      NaN  NaN  yes   no   no   good   no   no     ckd
# 37   137.0   ...    28.0   6900.0  2.5  yes  yes   no   poor   no  yes     ckd
# 38     NaN   ...     NaN      NaN  NaN  yes   no   no   good   no   no     ckd
# 39   140.0   ...    40.0   9800.0  4.2  yes  yes   no   good   no   no     ckd
# 41     NaN   ...     NaN      NaN  NaN   no   no   no   good  yes   no     ckd
# 43    79.0   ...    24.0   7900.0  3.1   no  yes   no   good   no   no     ckd
# 44   207.0   ...    28.0      NaN  NaN  yes  yes   no   poor  yes   no     ckd
# 45   208.0   ...     NaN      NaN  NaN  yes  yes   no   poor  yes   no     ckd
# ..     ...   ...     ...      ...  ...  ...  ...  ...    ...  ...  ...     ...
# 364  118.0   ...    45.0   9300.0  4.7   no   no   no   good   no   no  notckd
# 366   81.0   ...    46.0  10500.0  5.3   no   no   no   good   no   no  notckd
# 367  125.0   ...    50.0   6700.0  6.1   no   no   no   good   no   no  notckd
# 369  107.0   ...    46.0  10300.0  4.8   no   no   no   good   no   no  notckd
# 370   83.0   ...    50.0   9300.0  5.4   no   no   no   good   no   no  notckd
# 372  109.0   ...    52.0  10500.0  5.5   no   no   no   good   no   no  notckd
# 373  133.0   ...    47.0   9200.0  4.9   no   no   no   good   no   no  notckd
# 374  111.0   ...    40.0   8000.0  6.4   no   no   no   good   no   no  notckd
# 375   74.0   ...    48.0   9700.0  5.6   no   no   no   good   no   no  notckd
# 376   88.0   ...    53.0   9100.0  5.2   no   no   no   good   no   no  notckd
# 377   97.0   ...    49.0   6400.0  4.8   no   no   no   good   no   no  notckd
# 378    NaN   ...    42.0   7700.0  5.5   no   no   no   good   no   no  notckd
# 379   78.0   ...    50.0   5400.0  5.7   no   no   no   good   no   no  notckd
# 380  113.0   ...    54.0   6500.0  4.9   no   no   no   good   no   no  notckd
# 381   79.0   ...    40.0   5800.0  5.9   no   no   no   good   no   no  notckd
# 382   75.0   ...    51.0   6000.0  6.5   no   no   no   good   no   no  notckd
# 383  119.0   ...    49.0   5100.0  5.0   no   no   no   good   no   no  notckd
# 384  132.0   ...    42.0  11000.0  4.5   no   no   no   good   no   no  notckd
# 385  113.0   ...    52.0   8000.0  5.1   no   no   no   good   no   no  notckd
# 386  100.0   ...    43.0   5700.0  6.5   no   no   no   good   no   no  notckd
# 388   94.0   ...    46.0   9500.0  6.4   no   no   no   good   no   no  notckd
# 389  112.0   ...    52.0   7200.0  5.8   no   no   no   good   no   no  notckd
# 390   99.0   ...    52.0   6300.0  5.3   no   no   no   good   no   no  notckd
# 391   85.0   ...    44.0   5800.0  6.3   no   no   no   good   no   no  notckd
# 392  133.0   ...    46.0   6600.0  5.5   no   no   no   good   no   no  notckd
# 393  117.0   ...    54.0   7400.0  5.4   no   no   no   good   no   no  notckd
# 394  137.0   ...    45.0   9500.0  4.6   no   no   no   good   no   no  notckd
# 395  140.0   ...    47.0   6700.0  4.9   no   no   no   good   no   no  notckd
# 396   75.0   ...    54.0   7800.0  6.2   no   no   no   good   no   no  notckd
# 399  131.0   ...    53.0   6800.0  6.1   no   no   no   good   no   no  notckd
#
# [254 rows x 25 columns]

# %%
my_df[~(my_df["rbc"] == "abnormal")] # all rows where rbc does not equal abnormal
# Out:
#       age     bp     sg   al   su     rbc        pc         pcc          ba  \
# 0    48.0   80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1     7.0   50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2    62.0   80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3    48.0   70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4    51.0   80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# 5    60.0   90.0  1.015  3.0  0.0     NaN       NaN  notpresent  notpresent
# 6    68.0   70.0  1.010  0.0  0.0     NaN    normal  notpresent  notpresent
# 7    24.0    NaN  1.015  2.0  4.0  normal  abnormal  notpresent  notpresent
# 8    52.0  100.0  1.015  3.0  0.0  normal  abnormal     present  notpresent
# 10   50.0   60.0  1.010  2.0  4.0     NaN  abnormal     present  notpresent
# 12   68.0   70.0  1.015  3.0  1.0     NaN    normal     present  notpresent
# 13   68.0   70.0    NaN  NaN  NaN     NaN       NaN  notpresent  notpresent
# 14   68.0   80.0  1.010  3.0  2.0  normal  abnormal     present     present
# 15   40.0   80.0  1.015  3.0  0.0     NaN    normal  notpresent  notpresent
# 16   47.0   70.0  1.015  2.0  0.0     NaN    normal  notpresent  notpresent
# 17   47.0   80.0    NaN  NaN  NaN     NaN       NaN  notpresent  notpresent
# 18   60.0  100.0  1.025  0.0  3.0     NaN    normal  notpresent  notpresent
# 19   62.0   60.0  1.015  1.0  0.0     NaN  abnormal     present  notpresent
# 21   60.0   90.0    NaN  NaN  NaN     NaN       NaN  notpresent  notpresent
# 22   48.0   80.0  1.025  4.0  0.0  normal  abnormal  notpresent  notpresent
# 23   21.0   70.0  1.010  0.0  0.0     NaN    normal  notpresent  notpresent
# 24   42.0  100.0  1.015  4.0  0.0  normal  abnormal  notpresent     present
# 25   61.0   60.0  1.025  0.0  0.0     NaN    normal  notpresent  notpresent
# 26   75.0   80.0  1.015  0.0  0.0     NaN    normal  notpresent  notpresent
# 27   69.0   70.0  1.010  3.0  4.0  normal  abnormal  notpresent  notpresent
# 28   75.0   70.0    NaN  1.0  3.0     NaN       NaN  notpresent  notpresent
# 30    NaN   70.0    NaN  NaN  NaN     NaN       NaN  notpresent  notpresent
# 31   73.0   90.0  1.015  3.0  0.0     NaN  abnormal     present  notpresent
# 32   61.0   90.0  1.010  1.0  1.0     NaN    normal  notpresent  notpresent
# 34   70.0   70.0  1.010  1.0  0.0  normal       NaN     present     present
# ..    ...    ...    ...  ...  ...     ...       ...         ...         ...
# 370  69.0   70.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 371  28.0   60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 372  72.0   60.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 373  61.0   70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 374  79.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 375  70.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 376  58.0   70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 377  64.0   70.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 378  71.0   60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 379  62.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 380  59.0   60.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 381  71.0   70.0  1.025  0.0  0.0     NaN       NaN  notpresent  notpresent
# 382  48.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 383  80.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 384  57.0   60.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 385  63.0   70.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 386  46.0   70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 387  15.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 388  51.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 389  41.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 390  52.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 391  36.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 392  57.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 393  43.0   60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 394  50.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 395  55.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396  42.0   70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397  12.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398  17.0   60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399  58.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
#        bgr   ...     pcv       wc   rc  htn    dm  cad  appet   pe  ane  \
# 0    121.0   ...    44.0   7800.0  5.2  yes   yes   no   good   no   no
# 1      NaN   ...    38.0   6000.0  NaN   no    no   no   good   no   no
# 2    423.0   ...    31.0   7500.0  NaN   no   yes   no   poor   no  yes
# 3    117.0   ...    32.0   6700.0  3.9  yes    no   no   poor  yes  yes
# 4    106.0   ...    35.0   7300.0  4.6   no    no   no   good   no   no
# 5     74.0   ...    39.0   7800.0  4.4  yes   yes   no   good  yes   no
# 6    100.0   ...    36.0      NaN  NaN   no    no   no   good   no   no
# 7    410.0   ...    44.0   6900.0  5.0   no   yes   no   good  yes   no
# 8    138.0   ...    33.0   9600.0  4.0  yes   yes   no   good   no  yes
# 10   490.0   ...    28.0      NaN  NaN  yes   yes   no   good   no  yes
# 12   208.0   ...    28.0  12200.0  3.4  yes   yes  yes   poor  yes   no
# 13    98.0   ...     NaN      NaN  NaN  yes   yes  yes   poor  yes   no
# 14   157.0   ...    16.0  11000.0  2.6  yes   yes  yes   poor  yes   no
# 15    76.0   ...    24.0   3800.0  2.8  yes    no   no   good   no  yes
# 16    99.0   ...     NaN      NaN  NaN   no    no   no   good   no   no
# 17   114.0   ...     NaN      NaN  NaN  yes    no   no   poor   no   no
# 18   263.0   ...    37.0  11400.0  4.3  yes   yes  yes   good   no   no
# 19   100.0   ...    30.0   5300.0  3.7  yes    no  yes   good   no   no
# 21     NaN   ...    32.0   6200.0  3.6  yes   yes  yes   good   no   no
# 22    95.0   ...    32.0   6900.0  3.4  yes    no   no   good   no  yes
# 23     NaN   ...     NaN      NaN  NaN   no    no   no   poor   no  yes
# 24     NaN   ...    39.0   8300.0  4.6  yes    no   no   poor   no   no
# 25   108.0   ...    29.0   8400.0  3.7  yes   yes   no   good   no  yes
# 26   156.0   ...    35.0  10300.0  4.0  yes   yes   no   poor   no   no
# 27   264.0   ...    37.0   9600.0  4.1  yes   yes  yes   good  yes   no
# 28   123.0   ...     NaN      NaN  NaN   no   yes   no   good   no   no
# 30    93.0   ...     NaN      NaN  NaN  yes   yes   no   good   no   no
# 31   107.0   ...    30.0   7800.0  4.0   no    no   no   poor   no   no
# 32   159.0   ...    34.0   9600.0  4.0  yes   yes   no   poor   no   no
# 34   171.0   ...     NaN      NaN  NaN   no   yes   no   poor   no   no
# ..     ...   ...     ...      ...  ...  ...   ...  ...    ...  ...  ...
# 370   83.0   ...    50.0   9300.0  5.4   no    no   no   good   no   no
# 371   79.0   ...    51.0   6500.0  5.0   no    no   no   good   no   no
# 372  109.0   ...    52.0  10500.0  5.5   no    no   no   good   no   no
# 373  133.0   ...    47.0   9200.0  4.9   no    no   no   good   no   no
# 374  111.0   ...    40.0   8000.0  6.4   no    no   no   good   no   no
# 375   74.0   ...    48.0   9700.0  5.6   no    no   no   good   no   no
# 376   88.0   ...    53.0   9100.0  5.2   no    no   no   good   no   no
# 377   97.0   ...    49.0   6400.0  4.8   no    no   no   good   no   no
# 378    NaN   ...    42.0   7700.0  5.5   no    no   no   good   no   no
# 379   78.0   ...    50.0   5400.0  5.7   no    no   no   good   no   no
# 380  113.0   ...    54.0   6500.0  4.9   no    no   no   good   no   no
# 381   79.0   ...    40.0   5800.0  5.9   no    no   no   good   no   no
# 382   75.0   ...    51.0   6000.0  6.5   no    no   no   good   no   no
# 383  119.0   ...    49.0   5100.0  5.0   no    no   no   good   no   no
# 384  132.0   ...    42.0  11000.0  4.5   no    no   no   good   no   no
# 385  113.0   ...    52.0   8000.0  5.1   no    no   no   good   no   no
# 386  100.0   ...    43.0   5700.0  6.5   no    no   no   good   no   no
# 387   93.0   ...    50.0   6200.0  5.2   no    no   no   good   no   no
# 388   94.0   ...    46.0   9500.0  6.4   no    no   no   good   no   no
# 389  112.0   ...    52.0   7200.0  5.8   no    no   no   good   no   no
# 390   99.0   ...    52.0   6300.0  5.3   no    no   no   good   no   no
# 391   85.0   ...    44.0   5800.0  6.3   no    no   no   good   no   no
# 392  133.0   ...    46.0   6600.0  5.5   no    no   no   good   no   no
# 393  117.0   ...    54.0   7400.0  5.4   no    no   no   good   no   no
# 394  137.0   ...    45.0   9500.0  4.6   no    no   no   good   no   no
# 395  140.0   ...    47.0   6700.0  4.9   no    no   no   good   no   no
# 396   75.0   ...    54.0   7800.0  6.2   no    no   no   good   no   no
# 397  100.0   ...    49.0   6600.0  5.4   no    no   no   good   no   no
# 398  114.0   ...    51.0   7200.0  5.9   no    no   no   good   no   no
# 399  131.0   ...    53.0   6800.0  6.1   no    no   no   good   no   no
#
#       class
# 0       ckd
# 1       ckd
# 2       ckd
# 3       ckd
# 4       ckd
# 5       ckd
# 6       ckd
# 7       ckd
# 8       ckd
# 10      ckd
# 12      ckd
# 13      ckd
# 14      ckd
# 15      ckd
# 16      ckd
# 17      ckd
# 18      ckd
# 19      ckd
# 21      ckd
# 22      ckd
# 23      ckd
# 24      ckd
# 25      ckd
# 26      ckd
# 27      ckd
# 28      ckd
# 30      ckd
# 31      ckd
# 32      ckd
# 34      ckd
# ..      ...
# 370  notckd
# 371  notckd
# 372  notckd
# 373  notckd
# 374  notckd
# 375  notckd
# 376  notckd
# 377  notckd
# 378  notckd
# 379  notckd
# 380  notckd
# 381  notckd
# 382  notckd
# 383  notckd
# 384  notckd
# 385  notckd
# 386  notckd
# 387  notckd
# 388  notckd
# 389  notckd
# 390  notckd
# 391  notckd
# 392  notckd
# 393  notckd
# 394  notckd
# 395  notckd
# 396  notckd
# 397  notckd
# 398  notckd
# 399  notckd
#
# [353 rows x 25 columns]

# %%
my_df[my_df["rbc"] != "abnormal"] # another way of saying the same thing
# Out:
#       age     bp     sg   al   su     rbc        pc         pcc          ba  \
# 0    48.0   80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1     7.0   50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2    62.0   80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3    48.0   70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4    51.0   80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# 5    60.0   90.0  1.015  3.0  0.0     NaN       NaN  notpresent  notpresent
# 6    68.0   70.0  1.010  0.0  0.0     NaN    normal  notpresent  notpresent
# 7    24.0    NaN  1.015  2.0  4.0  normal  abnormal  notpresent  notpresent
# 8    52.0  100.0  1.015  3.0  0.0  normal  abnormal     present  notpresent
# 10   50.0   60.0  1.010  2.0  4.0     NaN  abnormal     present  notpresent
# 12   68.0   70.0  1.015  3.0  1.0     NaN    normal     present  notpresent
# 13   68.0   70.0    NaN  NaN  NaN     NaN       NaN  notpresent  notpresent
# 14   68.0   80.0  1.010  3.0  2.0  normal  abnormal     present     present
# 15   40.0   80.0  1.015  3.0  0.0     NaN    normal  notpresent  notpresent
# 16   47.0   70.0  1.015  2.0  0.0     NaN    normal  notpresent  notpresent
# 17   47.0   80.0    NaN  NaN  NaN     NaN       NaN  notpresent  notpresent
# 18   60.0  100.0  1.025  0.0  3.0     NaN    normal  notpresent  notpresent
# 19   62.0   60.0  1.015  1.0  0.0     NaN  abnormal     present  notpresent
# 21   60.0   90.0    NaN  NaN  NaN     NaN       NaN  notpresent  notpresent
# 22   48.0   80.0  1.025  4.0  0.0  normal  abnormal  notpresent  notpresent
# 23   21.0   70.0  1.010  0.0  0.0     NaN    normal  notpresent  notpresent
# 24   42.0  100.0  1.015  4.0  0.0  normal  abnormal  notpresent     present
# 25   61.0   60.0  1.025  0.0  0.0     NaN    normal  notpresent  notpresent
# 26   75.0   80.0  1.015  0.0  0.0     NaN    normal  notpresent  notpresent
# 27   69.0   70.0  1.010  3.0  4.0  normal  abnormal  notpresent  notpresent
# 28   75.0   70.0    NaN  1.0  3.0     NaN       NaN  notpresent  notpresent
# 30    NaN   70.0    NaN  NaN  NaN     NaN       NaN  notpresent  notpresent
# 31   73.0   90.0  1.015  3.0  0.0     NaN  abnormal     present  notpresent
# 32   61.0   90.0  1.010  1.0  1.0     NaN    normal  notpresent  notpresent
# 34   70.0   70.0  1.010  1.0  0.0  normal       NaN     present     present
# ..    ...    ...    ...  ...  ...     ...       ...         ...         ...
# 370  69.0   70.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 371  28.0   60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 372  72.0   60.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 373  61.0   70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 374  79.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 375  70.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 376  58.0   70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 377  64.0   70.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 378  71.0   60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 379  62.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 380  59.0   60.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 381  71.0   70.0  1.025  0.0  0.0     NaN       NaN  notpresent  notpresent
# 382  48.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 383  80.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 384  57.0   60.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 385  63.0   70.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 386  46.0   70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 387  15.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 388  51.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 389  41.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 390  52.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 391  36.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 392  57.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 393  43.0   60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 394  50.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 395  55.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396  42.0   70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397  12.0   80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398  17.0   60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399  58.0   80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
#        bgr   ...     pcv       wc   rc  htn    dm  cad  appet   pe  ane  \
# 0    121.0   ...    44.0   7800.0  5.2  yes   yes   no   good   no   no
# 1      NaN   ...    38.0   6000.0  NaN   no    no   no   good   no   no
# 2    423.0   ...    31.0   7500.0  NaN   no   yes   no   poor   no  yes
# 3    117.0   ...    32.0   6700.0  3.9  yes    no   no   poor  yes  yes
# 4    106.0   ...    35.0   7300.0  4.6   no    no   no   good   no   no
# 5     74.0   ...    39.0   7800.0  4.4  yes   yes   no   good  yes   no
# 6    100.0   ...    36.0      NaN  NaN   no    no   no   good   no   no
# 7    410.0   ...    44.0   6900.0  5.0   no   yes   no   good  yes   no
# 8    138.0   ...    33.0   9600.0  4.0  yes   yes   no   good   no  yes
# 10   490.0   ...    28.0      NaN  NaN  yes   yes   no   good   no  yes
# 12   208.0   ...    28.0  12200.0  3.4  yes   yes  yes   poor  yes   no
# 13    98.0   ...     NaN      NaN  NaN  yes   yes  yes   poor  yes   no
# 14   157.0   ...    16.0  11000.0  2.6  yes   yes  yes   poor  yes   no
# 15    76.0   ...    24.0   3800.0  2.8  yes    no   no   good   no  yes
# 16    99.0   ...     NaN      NaN  NaN   no    no   no   good   no   no
# 17   114.0   ...     NaN      NaN  NaN  yes    no   no   poor   no   no
# 18   263.0   ...    37.0  11400.0  4.3  yes   yes  yes   good   no   no
# 19   100.0   ...    30.0   5300.0  3.7  yes    no  yes   good   no   no
# 21     NaN   ...    32.0   6200.0  3.6  yes   yes  yes   good   no   no
# 22    95.0   ...    32.0   6900.0  3.4  yes    no   no   good   no  yes
# 23     NaN   ...     NaN      NaN  NaN   no    no   no   poor   no  yes
# 24     NaN   ...    39.0   8300.0  4.6  yes    no   no   poor   no   no
# 25   108.0   ...    29.0   8400.0  3.7  yes   yes   no   good   no  yes
# 26   156.0   ...    35.0  10300.0  4.0  yes   yes   no   poor   no   no
# 27   264.0   ...    37.0   9600.0  4.1  yes   yes  yes   good  yes   no
# 28   123.0   ...     NaN      NaN  NaN   no   yes   no   good   no   no
# 30    93.0   ...     NaN      NaN  NaN  yes   yes   no   good   no   no
# 31   107.0   ...    30.0   7800.0  4.0   no    no   no   poor   no   no
# 32   159.0   ...    34.0   9600.0  4.0  yes   yes   no   poor   no   no
# 34   171.0   ...     NaN      NaN  NaN   no   yes   no   poor   no   no
# ..     ...   ...     ...      ...  ...  ...   ...  ...    ...  ...  ...
# 370   83.0   ...    50.0   9300.0  5.4   no    no   no   good   no   no
# 371   79.0   ...    51.0   6500.0  5.0   no    no   no   good   no   no
# 372  109.0   ...    52.0  10500.0  5.5   no    no   no   good   no   no
# 373  133.0   ...    47.0   9200.0  4.9   no    no   no   good   no   no
# 374  111.0   ...    40.0   8000.0  6.4   no    no   no   good   no   no
# 375   74.0   ...    48.0   9700.0  5.6   no    no   no   good   no   no
# 376   88.0   ...    53.0   9100.0  5.2   no    no   no   good   no   no
# 377   97.0   ...    49.0   6400.0  4.8   no    no   no   good   no   no
# 378    NaN   ...    42.0   7700.0  5.5   no    no   no   good   no   no
# 379   78.0   ...    50.0   5400.0  5.7   no    no   no   good   no   no
# 380  113.0   ...    54.0   6500.0  4.9   no    no   no   good   no   no
# 381   79.0   ...    40.0   5800.0  5.9   no    no   no   good   no   no
# 382   75.0   ...    51.0   6000.0  6.5   no    no   no   good   no   no
# 383  119.0   ...    49.0   5100.0  5.0   no    no   no   good   no   no
# 384  132.0   ...    42.0  11000.0  4.5   no    no   no   good   no   no
# 385  113.0   ...    52.0   8000.0  5.1   no    no   no   good   no   no
# 386  100.0   ...    43.0   5700.0  6.5   no    no   no   good   no   no
# 387   93.0   ...    50.0   6200.0  5.2   no    no   no   good   no   no
# 388   94.0   ...    46.0   9500.0  6.4   no    no   no   good   no   no
# 389  112.0   ...    52.0   7200.0  5.8   no    no   no   good   no   no
# 390   99.0   ...    52.0   6300.0  5.3   no    no   no   good   no   no
# 391   85.0   ...    44.0   5800.0  6.3   no    no   no   good   no   no
# 392  133.0   ...    46.0   6600.0  5.5   no    no   no   good   no   no
# 393  117.0   ...    54.0   7400.0  5.4   no    no   no   good   no   no
# 394  137.0   ...    45.0   9500.0  4.6   no    no   no   good   no   no
# 395  140.0   ...    47.0   6700.0  4.9   no    no   no   good   no   no
# 396   75.0   ...    54.0   7800.0  6.2   no    no   no   good   no   no
# 397  100.0   ...    49.0   6600.0  5.4   no    no   no   good   no   no
# 398  114.0   ...    51.0   7200.0  5.9   no    no   no   good   no   no
# 399  131.0   ...    53.0   6800.0  6.1   no    no   no   good   no   no
#
#       class
# 0       ckd
# 1       ckd
# 2       ckd
# 3       ckd
# 4       ckd
# 5       ckd
# 6       ckd
# 7       ckd
# 8       ckd
# 10      ckd
# 12      ckd
# 13      ckd
# 14      ckd
# 15      ckd
# 16      ckd
# 17      ckd
# 18      ckd
# 19      ckd
# 21      ckd
# 22      ckd
# 23      ckd
# 24      ckd
# 25      ckd
# 26      ckd
# 27      ckd
# 28      ckd
# 30      ckd
# 31      ckd
# 32      ckd
# 34      ckd
# ..      ...
# 370  notckd
# 371  notckd
# 372  notckd
# 373  notckd
# 374  notckd
# 375  notckd
# 376  notckd
# 377  notckd
# 378  notckd
# 379  notckd
# 380  notckd
# 381  notckd
# 382  notckd
# 383  notckd
# 384  notckd
# 385  notckd
# 386  notckd
# 387  notckd
# 388  notckd
# 389  notckd
# 390  notckd
# 391  notckd
# 392  notckd
# 393  notckd
# 394  notckd
# 395  notckd
# 396  notckd
# 397  notckd
# 398  notckd
# 399  notckd
#
# [353 rows x 25 columns]

# %% [markdown]
# ### Indexing Method Using isin - Series:

# %%
series_1 = pd.Series(np.arange(5), index = ["a", "b", "c", "d", 4])
series_1
# Out:
# a    0
# b    1
# c    2
# d    3
# 4    4
# dtype: int64

# %%
series_1.isin([1,3,4])
# Out:
# a    False
# b     True
# c    False
# d     True
# 4     True
# dtype: bool

# %%
series_1[series_1.isin([1,3,4])]
# Out:
# b    1
# d    3
# 4    4
# dtype: int64

# %% [markdown]
# ### Indexing Method Using isin - DataFrames:

# %%
values = ["abnormal"] 
my_df.rbc.isin(values)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20      True
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 370    False
# 371    False
# 372    False
# 373    False
# 374    False
# 375    False
# 376    False
# 377    False
# 378    False
# 379    False
# 380    False
# 381    False
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# Name: rbc, Length: 400, dtype: bool

# %%
values = ["abnormal"]
my_df.loc[my_df.rbc.isin(values)]
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 9    53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 11   63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 20   61.0   80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 29   68.0   70.0  1.005  1.0  0.0  abnormal  abnormal     present  notpresent
# 33   60.0  100.0  1.020  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 35   65.0   90.0  1.020  2.0  1.0  abnormal    normal  notpresent  notpresent
# 38   69.0   80.0  1.020  3.0  0.0  abnormal    normal  notpresent  notpresent
# 43   35.0   80.0  1.010  1.0  0.0  abnormal       NaN  notpresent  notpresent
# 44   54.0   80.0  1.010  3.0  0.0  abnormal  abnormal  notpresent  notpresent
# 55   35.0   80.0  1.005  3.0  0.0  abnormal    normal  notpresent  notpresent
# 58   73.0   80.0  1.020  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 63   46.0   70.0  1.015  1.0  0.0  abnormal    normal  notpresent  notpresent
# 66   67.0   70.0  1.020  2.0  0.0  abnormal    normal  notpresent  notpresent
# 73    NaN  100.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 74   56.0   90.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 76   48.0   80.0  1.005  4.0  0.0  abnormal  abnormal  notpresent     present
# 91   56.0   70.0  1.015  4.0  1.0  abnormal    normal  notpresent  notpresent
# 93   73.0  100.0  1.010  3.0  2.0  abnormal  abnormal     present  notpresent
# 100  34.0   70.0  1.015  4.0  0.0  abnormal  abnormal  notpresent  notpresent
# 112   NaN   60.0  1.015  3.0  0.0  abnormal  abnormal  notpresent  notpresent
# 114  12.0   60.0  1.015  3.0  0.0  abnormal  abnormal     present  notpresent
# 116   NaN   70.0  1.015  4.0  0.0  abnormal    normal  notpresent  notpresent
# 143  41.0   80.0  1.015  1.0  4.0  abnormal    normal  notpresent  notpresent
# 144  60.0   90.0  1.010  2.0  0.0  abnormal    normal  notpresent  notpresent
# 145  57.0   90.0  1.015  5.0  0.0  abnormal  abnormal  notpresent     present
# 146  53.0  100.0  1.010  1.0  3.0  abnormal    normal  notpresent  notpresent
# 149  65.0   70.0  1.020  1.0  0.0  abnormal  abnormal  notpresent  notpresent
# 153  55.0   90.0  1.010  2.0  1.0  abnormal  abnormal  notpresent  notpresent
# 154  56.0   90.0  1.005  4.0  3.0  abnormal  abnormal  notpresent  notpresent
# 155  50.0   70.0  1.020  3.0  0.0  abnormal    normal     present     present
# 159  59.0   80.0  1.010  1.0  0.0  abnormal    normal  notpresent  notpresent
# 161  62.0    NaN  1.015  3.0  0.0  abnormal       NaN  notpresent  notpresent
# 167  34.0   70.0  1.020  0.0  0.0  abnormal    normal  notpresent  notpresent
# 173  17.0   70.0  1.015  1.0  0.0  abnormal    normal  notpresent  notpresent
# 178  42.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 180  73.0   90.0  1.010  1.0  4.0  abnormal  abnormal     present  notpresent
# 189  64.0   60.0  1.010  4.0  1.0  abnormal  abnormal  notpresent     present
# 190   6.0   60.0  1.010  4.0  0.0  abnormal  abnormal  notpresent     present
# 193  32.0   90.0  1.025  1.0  0.0  abnormal  abnormal  notpresent  notpresent
# 195  70.0   90.0  1.020  2.0  1.0  abnormal  abnormal  notpresent     present
# 196  49.0  100.0  1.010  3.0  0.0  abnormal  abnormal  notpresent  notpresent
# 225  60.0   90.0  1.010  3.0  5.0  abnormal    normal  notpresent     present
# 226  64.0  100.0  1.015  4.0  2.0  abnormal  abnormal  notpresent     present
# 232  50.0   90.0  1.015  1.0  0.0  abnormal  abnormal  notpresent  notpresent
# 234  37.0  100.0  1.010  0.0  0.0  abnormal    normal  notpresent  notpresent
# 246  48.0  110.0  1.015  3.0  0.0  abnormal    normal     present  notpresent
# 248  59.0   70.0  1.010  1.0  3.0  abnormal  abnormal  notpresent  notpresent
#
#        bgr  ...    pcv       wc   rc  htn   dm  cad  appet   pe  ane class
# 9     70.0  ...   29.0  12100.0  3.7  yes  yes   no   poor   no  yes   ckd
# 11   380.0  ...   32.0   4500.0  3.8  yes  yes   no   poor  yes   no   ckd
# 20   173.0  ...   24.0   9200.0  3.2  yes  yes  yes   poor  yes  yes   ckd
# 29     NaN  ...   38.0      NaN  NaN   no   no  yes   good   no   no   ckd
# 33   140.0  ...   29.0      NaN  NaN  yes   no   no   poor   no   no   ckd
# 35   270.0  ...   36.0   9800.0  4.9  yes  yes   no   poor   no  yes   ckd
# 38     NaN  ...    NaN      NaN  NaN  yes   no   no   good   no   no   ckd
# 43    79.0  ...   24.0   7900.0  3.1   no  yes   no   good   no   no   ckd
# 44   207.0  ...   28.0      NaN  NaN  yes  yes   no   poor  yes   no   ckd
# 55     NaN  ...   28.0      NaN  NaN   no   no   no   good  yes   no   ckd
# 58   253.0  ...   33.0   7200.0  4.3  yes  yes  yes   good   no   no   ckd
# 63   150.0  ...   27.0      NaN  NaN   no   no   no   good   no  yes   ckd
# 66   150.0  ...    NaN      NaN  NaN  yes  yes   no   good  yes   no   ckd
# 73   129.0  ...   14.0   6300.0  NaN  yes   no   no   good  yes  yes   ckd
# 74   129.0  ...   29.0   6400.0  3.4  yes   no   no   good   no   no   ckd
# 76   133.0  ...   36.0   6200.0  4.0   no  yes   no   good  yes   no   ckd
# 91   210.0  ...   52.0  12500.0  5.6   no   no   no   good   no   no   ckd
# 93   295.0  ...   30.0   7000.0  3.2  yes  yes  yes   poor   no   no   ckd
# 100  153.0  ...    NaN      NaN  NaN   no   no   no   good  yes   no   ckd
# 112    NaN  ...   33.0      NaN  NaN   no   no   no   good   no   no   ckd
# 114    NaN  ...    NaN  10300.0  NaN   no   no   no   good   no   no   ckd
# 116  104.0  ...    NaN      NaN  NaN   no   no   no   good  yes   no   ckd
# 143  210.0  ...    NaN      NaN  NaN   no  yes   no   good   no   no   ckd
# 144  105.0  ...   33.0  10500.0  4.1   no   no   no   good   no   no   ckd
# 145    NaN  ...   24.0   4200.0  3.3  yes  yes  yes   poor  yes  yes   ckd
# 146  213.0  ...    NaN      NaN  NaN   no  yes   no   good   no   no   ckd
# 149  139.0  ...   32.0      NaN  NaN  yes   no   no   good  yes   no   ckd
# 153  273.0  ...   22.0  14600.0  2.9  yes  yes   no   poor  yes  yes   ckd
# 154  242.0  ...   26.0      NaN  3.0  yes  yes   no   poor  yes  yes   ckd
# 155  123.0  ...   36.0   4700.0  NaN   no   no   no   good   no   no   ckd
# 159  303.0  ...   35.0  10900.0  4.3   no  yes   no   poor   no   no   ckd
# 161    NaN  ...   42.0  10200.0  4.8  yes  yes   no   good   no   no   ckd
# 167  139.0  ...   42.0   2200.0  NaN   no   no   no   poor   no   no   ckd
# 173   22.0  ...   41.0  11200.0  NaN   no   no   no   good   no   no   ckd
# 178   93.0  ...   34.0   9800.0  NaN   no   no   no   poor  yes  yes   ckd
# 180  234.0  ...   28.0      NaN  NaN   no  yes   no   good   no   no   ckd
# 189  239.0  ...   29.0   7500.0  3.4  yes  yes   no   poor  yes   no   ckd
# 190   94.0  ...   30.0  16700.0  4.8   no   no   no   poor   no   no   ckd
# 193    NaN  ...   15.0   2600.0  2.8  yes  yes   no   poor  yes  yes   ckd
# 195  184.0  ...    NaN      NaN  NaN  yes  yes  yes   poor   no   no   ckd
# 196  129.0  ...   24.0   9600.0  3.5  yes  yes   no   poor  yes  yes   ckd
# 225  490.0  ...   35.0  12000.0  4.5  yes  yes   no   good   no   no   ckd
# 226  163.0  ...   26.0   7500.0  3.4  yes  yes   no   good  yes   no   ckd
# 232    NaN  ...    NaN      NaN  NaN   no   no   no   good  yes   no   ckd
# 234    NaN  ...   44.0   4100.0  5.2  yes   no   no   good   no   no   ckd
# 246  106.0  ...   26.0   5000.0  2.5  yes   no  yes   good   no  yes   ckd
# 248  424.0  ...   37.0  10200.0  4.1  yes  yes  yes   good   no   no   ckd
#
# [47 rows x 25 columns]

# %% [markdown]
# ### Sorting Rows - Method 1:
#
# Method 1 is Sorting rows based on column values (`df.sort_values(by = ["col_name_1", "col_name_2"])`)
# ### DataFrames:
#
# Documentation: http://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.sort_values.html

# %%
# ".sort_values" - sort from smallest to largest by default
my_df.sort_values(by = "age", # sort by Age column in ascending fashion
                 inplace = False, # this will save the sorted dataframe; unless you want to create a copy 
                 ascending = True) # ascending or descending?
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 215   2.0    NaN  1.010  3.0  0.0    normal  abnormal  notpresent  notpresent
# 187   3.0    NaN  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 185   4.0    NaN  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 75    5.0    NaN  1.015  1.0  0.0       NaN    normal  notpresent  notpresent
# 131   5.0   50.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 190   6.0   60.0  1.010  4.0  0.0  abnormal  abnormal  notpresent     present
# 1     7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent  notpresent
# 186   8.0   50.0  1.020  4.0  0.0    normal    normal  notpresent  notpresent
# 188   8.0    NaN    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 150   8.0   60.0  1.025  3.0  0.0    normal    normal  notpresent  notpresent
# 47   11.0   80.0  1.010  3.0  0.0       NaN    normal  notpresent  notpresent
# 397  12.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 114  12.0   60.0  1.015  3.0  0.0  abnormal  abnormal     present  notpresent
# 164  14.0    NaN  1.015  0.0  0.0       NaN       NaN  notpresent  notpresent
# 62   15.0   60.0  1.020  3.0  0.0       NaN    normal  notpresent  notpresent
# 387  15.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 173  17.0   70.0  1.015  1.0  0.0  abnormal    normal  notpresent  notpresent
# 102  17.0   60.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 398  17.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 274  19.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 209  19.0   70.0  1.020  0.0  0.0       NaN    normal  notpresent  notpresent
# 282  20.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 276  20.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 176  21.0   90.0  1.010  4.0  0.0    normal  abnormal     present     present
# 23   21.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 345  22.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 333  23.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 355  23.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 270  23.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 251  23.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# ..    ...    ...    ...  ...  ...       ...       ...         ...         ...
# 80   74.0   80.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 129  75.0   70.0  1.025  1.0  0.0       NaN    normal  notpresent  notpresent
# 28   75.0   70.0    NaN  1.0  3.0       NaN       NaN  notpresent  notpresent
# 294  75.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 369  75.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 26   75.0   80.0  1.015  0.0  0.0       NaN    normal  notpresent  notpresent
# 56   76.0   70.0  1.015  3.0  4.0    normal  abnormal     present  notpresent
# 57   76.0   90.0    NaN  NaN  NaN       NaN    normal  notpresent  notpresent
# 36   76.0   70.0  1.015  1.0  0.0    normal    normal  notpresent  notpresent
# 103  76.0   70.0  1.015  2.0  0.0    normal  abnormal     present  notpresent
# 151  76.0   90.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 202  78.0   60.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 374  79.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 312  80.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 194  80.0   70.0  1.010  2.0  NaN       NaN  abnormal  notpresent  notpresent
# 383  80.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 237  80.0   70.0  1.015  2.0  2.0       NaN    normal  notpresent  notpresent
# 160  81.0   60.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 39   82.0   80.0  1.010  2.0  2.0    normal       NaN  notpresent  notpresent
# 171  83.0   70.0  1.020  3.0  0.0    normal    normal  notpresent  notpresent
# 200  90.0   90.0  1.025  1.0  0.0       NaN    normal  notpresent  notpresent
# 30    NaN   70.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 73    NaN  100.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 112   NaN   60.0  1.015  3.0  0.0  abnormal  abnormal  notpresent  notpresent
# 116   NaN   70.0  1.015  4.0  0.0  abnormal    normal  notpresent  notpresent
# 117   NaN   70.0  1.020  0.0  0.0       NaN       NaN  notpresent  notpresent
# 169   NaN   70.0  1.010  0.0  2.0       NaN    normal  notpresent  notpresent
# 191   NaN   70.0  1.010  3.0  0.0    normal    normal  notpresent  notpresent
# 203   NaN   90.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 268   NaN   80.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
#
#        bgr   ...     pcv       wc   rc  htn    dm  cad  appet   pe  ane  \
# 215    NaN   ...     NaN      NaN  NaN   no    no   no   good  yes   no
# 187    NaN   ...    34.0  12300.0  NaN   no    no   no   good   no   no
# 185   99.0   ...    34.0      NaN  NaN   no    no   no   good   no   no
# 75     NaN   ...     NaN      NaN  NaN   no    no   no   good   no  yes
# 131    NaN   ...    36.0  12400.0  NaN   no    no   no   good   no   no
# 190   94.0   ...    30.0  16700.0  4.8   no    no   no   poor   no   no
# 1      NaN   ...    38.0   6000.0  NaN   no    no   no   good   no   no
# 186    NaN   ...     NaN      NaN  NaN   no    no   no   good  yes   no
# 188   80.0   ...    38.0      NaN  NaN   no    no   no   good   no   no
# 150   78.0   ...    41.0   6700.0  NaN   no    no   no   poor  yes   no
# 47     NaN   ...    45.0   8600.0  NaN   no    no   no   good   no   no
# 397  100.0   ...    49.0   6600.0  5.4   no    no   no   good   no   no
# 114    NaN   ...     NaN  10300.0  NaN   no    no   no   good   no   no
# 164  192.0   ...    40.0   9500.0  5.4   no   yes   no   poor  yes   no
# 62    86.0   ...    33.0   7700.0  3.8  yes   yes   no   good   no   no
# 387   93.0   ...    50.0   6200.0  5.2   no    no   no   good   no   no
# 173   22.0   ...    41.0  11200.0  NaN   no    no   no   good   no   no
# 102   92.0   ...    52.0   7000.0  NaN   no    no   no   good   no   no
# 398  114.0   ...    51.0   7200.0  5.9   no    no   no   good   no   no
# 274  107.0   ...    44.0      NaN  NaN   no    no   no   good   no   no
# 209    NaN   ...     NaN   6900.0  NaN   no    no   no   good   no   no
# 282  123.0   ...    44.0   5500.0  4.8   no    no   no   good   no   no
# 276    NaN   ...    41.0   4500.0  5.5   no    no   no   good   no   no
# 176  107.0   ...    23.0  12400.0  3.9   no    no   no   good   no  yes
# 23     NaN   ...     NaN      NaN  NaN   no    no   no   poor   no  yes
# 345   97.0   ...    42.0   7900.0  6.4   no    no   no   good   no   no
# 333   99.0   ...    46.0   4300.0  5.5   no    no   no   good   no   no
# 355   95.0   ...    52.0   6300.0  4.6   no    no   no   good   no   no
# 270  111.0   ...    41.0   7200.0  5.0   no    no   no   good   no   no
# 251   70.0   ...    52.0   9800.0  5.0   no    no   no   good   no   no
# ..     ...   ...     ...      ...  ...  ...   ...  ...    ...  ...  ...
# 80   132.0   ...    31.0   9400.0  3.8  yes   yes   no   good   no   no
# 129  158.0   ...     NaN      NaN  NaN  yes    no   no   poor  yes   no
# 28   123.0   ...     NaN      NaN  NaN   no   yes   no   good   no   no
# 294  110.0   ...    40.0   8300.0  5.8   no    no   no    NaN  NaN  NaN
# 369  107.0   ...    46.0  10300.0  4.8   no    no   no   good   no   no
# 26   156.0   ...    35.0  10300.0  4.0  yes   yes   no   poor   no   no
# 56     NaN   ...    30.0  11300.0  3.4  yes   yes  yes   poor  yes   no
# 57    93.0   ...     NaN      NaN  NaN  yes   yes  yes   poor   no   no
# 36    92.0   ...    32.0      NaN  NaN  yes    no   no   good   no   no
# 103  226.0   ...    36.0  12700.0  4.2  yes    no   no   poor  yes  yes
# 151  172.0   ...    30.0      NaN  NaN  yes   yes   no   good   no  yes
# 202  114.0   ...    24.0      NaN  NaN   no   yes   no   good   no  yes
# 374  111.0   ...    40.0   8000.0  6.4   no    no   no   good   no   no
# 312    NaN   ...    48.0   6300.0  6.1   no    no   no   good   no   no
# 194    NaN   ...     NaN      NaN  NaN  yes   yes   no   good   no   no
# 383  119.0   ...    49.0   5100.0  5.0   no    no   no   good   no   no
# 237  141.0   ...    40.0   9600.0  NaN  yes   yes   no   poor  yes   no
# 160  148.0   ...    35.0   9400.0  2.4  yes   yes  yes   poor  yes   no
# 39   140.0   ...    40.0   9800.0  4.2  yes   yes   no   good   no   no
# 171  102.0   ...    26.0  12800.0  3.1  yes    no   no   poor   no  yes
# 200  139.0   ...    37.0   7900.0  3.9  yes   yes   no   good   no   no
# 30    93.0   ...     NaN      NaN  NaN  yes   yes   no   good   no   no
# 73   129.0   ...    14.0   6300.0  NaN  yes    no   no   good  yes  yes
# 112    NaN   ...    33.0      NaN  NaN   no    no   no   good   no   no
# 116  104.0   ...     NaN      NaN  NaN   no    no   no   good  yes   no
# 117  219.0   ...    37.0   9800.0  4.4   no    no   no   good   no   no
# 169  220.0   ...    27.0      NaN  NaN  yes   yes   no   good   no  yes
# 191  110.0   ...    26.0   9200.0  3.4  yes   yes   no   poor   no   no
# 203  207.0   ...     NaN      NaN  NaN  yes   yes   no   good   no  yes
# 268  100.0   ...    53.0   8500.0  4.9   no    no   no   good   no   no
#
#       class
# 215     ckd
# 187     ckd
# 185     ckd
# 75      ckd
# 131     ckd
# 190     ckd
# 1       ckd
# 186     ckd
# 188     ckd
# 150     ckd
# 47      ckd
# 397  notckd
# 114     ckd
# 164     ckd
# 62      ckd
# 387  notckd
# 173     ckd
# 102     ckd
# 398  notckd
# 274  notckd
# 209     ckd
# 282  notckd
# 276  notckd
# 176     ckd
# 23      ckd
# 345  notckd
# 333  notckd
# 355  notckd
# 270  notckd
# 251  notckd
# ..      ...
# 80      ckd
# 129     ckd
# 28      ckd
# 294  notckd
# 369  notckd
# 26      ckd
# 56      ckd
# 57      ckd
# 36      ckd
# 103     ckd
# 151     ckd
# 202     ckd
# 374  notckd
# 312  notckd
# 194     ckd
# 383  notckd
# 237     ckd
# 160     ckd
# 39      ckd
# 171     ckd
# 200     ckd
# 30      ckd
# 73      ckd
# 112     ckd
# 116     ckd
# 117     ckd
# 169     ckd
# 191     ckd
# 203     ckd
# 268  notckd
#
# [400 rows x 25 columns]

# %%
my_df.sort_values(by = "age", ascending = False) # sort by First column in descending fashion
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 200  90.0   90.0  1.025  1.0  0.0       NaN    normal  notpresent  notpresent
# 171  83.0   70.0  1.020  3.0  0.0    normal    normal  notpresent  notpresent
# 39   82.0   80.0  1.010  2.0  2.0    normal       NaN  notpresent  notpresent
# 160  81.0   60.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 237  80.0   70.0  1.015  2.0  2.0       NaN    normal  notpresent  notpresent
# 383  80.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 312  80.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 194  80.0   70.0  1.010  2.0  NaN       NaN  abnormal  notpresent  notpresent
# 374  79.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 202  78.0   60.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 57   76.0   90.0    NaN  NaN  NaN       NaN    normal  notpresent  notpresent
# 36   76.0   70.0  1.015  1.0  0.0    normal    normal  notpresent  notpresent
# 151  76.0   90.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 56   76.0   70.0  1.015  3.0  4.0    normal  abnormal     present  notpresent
# 103  76.0   70.0  1.015  2.0  0.0    normal  abnormal     present  notpresent
# 129  75.0   70.0  1.025  1.0  0.0       NaN    normal  notpresent  notpresent
# 369  75.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 294  75.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 26   75.0   80.0  1.015  0.0  0.0       NaN    normal  notpresent  notpresent
# 28   75.0   70.0    NaN  1.0  3.0       NaN       NaN  notpresent  notpresent
# 222  74.0   60.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 359  74.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 80   74.0   80.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 31   73.0   90.0  1.015  3.0  0.0       NaN  abnormal     present  notpresent
# 58   73.0   80.0  1.020  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 48   73.0   70.0  1.005  0.0  0.0    normal    normal  notpresent  notpresent
# 364  73.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 138  73.0    NaN  1.010  1.0  0.0       NaN       NaN  notpresent  notpresent
# 299  73.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 93   73.0  100.0  1.010  3.0  2.0  abnormal  abnormal     present  notpresent
# ..    ...    ...    ...  ...  ...       ...       ...         ...         ...
# 274  19.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 209  19.0   70.0  1.020  0.0  0.0       NaN    normal  notpresent  notpresent
# 173  17.0   70.0  1.015  1.0  0.0  abnormal    normal  notpresent  notpresent
# 398  17.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 102  17.0   60.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 387  15.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 62   15.0   60.0  1.020  3.0  0.0       NaN    normal  notpresent  notpresent
# 164  14.0    NaN  1.015  0.0  0.0       NaN       NaN  notpresent  notpresent
# 114  12.0   60.0  1.015  3.0  0.0  abnormal  abnormal     present  notpresent
# 397  12.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 47   11.0   80.0  1.010  3.0  0.0       NaN    normal  notpresent  notpresent
# 150   8.0   60.0  1.025  3.0  0.0    normal    normal  notpresent  notpresent
# 188   8.0    NaN    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 186   8.0   50.0  1.020  4.0  0.0    normal    normal  notpresent  notpresent
# 1     7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent  notpresent
# 190   6.0   60.0  1.010  4.0  0.0  abnormal  abnormal  notpresent     present
# 131   5.0   50.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 75    5.0    NaN  1.015  1.0  0.0       NaN    normal  notpresent  notpresent
# 185   4.0    NaN  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 187   3.0    NaN  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 215   2.0    NaN  1.010  3.0  0.0    normal  abnormal  notpresent  notpresent
# 30    NaN   70.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 73    NaN  100.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 112   NaN   60.0  1.015  3.0  0.0  abnormal  abnormal  notpresent  notpresent
# 116   NaN   70.0  1.015  4.0  0.0  abnormal    normal  notpresent  notpresent
# 117   NaN   70.0  1.020  0.0  0.0       NaN       NaN  notpresent  notpresent
# 169   NaN   70.0  1.010  0.0  2.0       NaN    normal  notpresent  notpresent
# 191   NaN   70.0  1.010  3.0  0.0    normal    normal  notpresent  notpresent
# 203   NaN   90.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 268   NaN   80.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
#
#        bgr   ...     pcv       wc   rc  htn    dm  cad  appet   pe  ane  \
# 200  139.0   ...    37.0   7900.0  3.9  yes   yes   no   good   no   no
# 171  102.0   ...    26.0  12800.0  3.1  yes    no   no   poor   no  yes
# 39   140.0   ...    40.0   9800.0  4.2  yes   yes   no   good   no   no
# 160  148.0   ...    35.0   9400.0  2.4  yes   yes  yes   poor  yes   no
# 237  141.0   ...    40.0   9600.0  NaN  yes   yes   no   poor  yes   no
# 383  119.0   ...    49.0   5100.0  5.0   no    no   no   good   no   no
# 312    NaN   ...    48.0   6300.0  6.1   no    no   no   good   no   no
# 194    NaN   ...     NaN      NaN  NaN  yes   yes   no   good   no   no
# 374  111.0   ...    40.0   8000.0  6.4   no    no   no   good   no   no
# 202  114.0   ...    24.0      NaN  NaN   no   yes   no   good   no  yes
# 57    93.0   ...     NaN      NaN  NaN  yes   yes  yes   poor   no   no
# 36    92.0   ...    32.0      NaN  NaN  yes    no   no   good   no   no
# 151  172.0   ...    30.0      NaN  NaN  yes   yes   no   good   no  yes
# 56     NaN   ...    30.0  11300.0  3.4  yes   yes  yes   poor  yes   no
# 103  226.0   ...    36.0  12700.0  4.2  yes    no   no   poor  yes  yes
# 129  158.0   ...     NaN      NaN  NaN  yes    no   no   poor  yes   no
# 369  107.0   ...    46.0  10300.0  4.8   no    no   no   good   no   no
# 294  110.0   ...    40.0   8300.0  5.8   no    no   no    NaN  NaN  NaN
# 26   156.0   ...    35.0  10300.0  4.0  yes   yes   no   poor   no   no
# 28   123.0   ...     NaN      NaN  NaN   no   yes   no   good   no   no
# 222  108.0   ...     NaN      NaN  NaN  yes   yes   no   good   no   no
# 359   88.0   ...    53.0   6000.0  4.5   no    no   no   good   no   no
# 80   132.0   ...    31.0   9400.0  3.8  yes   yes   no   good   no   no
# 31   107.0   ...    30.0   7800.0  4.0   no    no   no   poor   no   no
# 58   253.0   ...    33.0   7200.0  4.3  yes   yes  yes   good   no   no
# 48    70.0   ...    29.0  18900.0  3.5  yes   yes   no   good  yes   no
# 364  118.0   ...    45.0   9300.0  4.7   no    no   no   good   no   no
# 138   95.0   ...     NaN      NaN  NaN   no    no   no   good   no   no
# 299  127.0   ...    52.0  11000.0  4.7   no    no   no   good   no   no
# 93   295.0   ...    30.0   7000.0  3.2  yes   yes  yes   poor   no   no
# ..     ...   ...     ...      ...  ...  ...   ...  ...    ...  ...  ...
# 274  107.0   ...    44.0      NaN  NaN   no    no   no   good   no   no
# 209    NaN   ...     NaN   6900.0  NaN   no    no   no   good   no   no
# 173   22.0   ...    41.0  11200.0  NaN   no    no   no   good   no   no
# 398  114.0   ...    51.0   7200.0  5.9   no    no   no   good   no   no
# 102   92.0   ...    52.0   7000.0  NaN   no    no   no   good   no   no
# 387   93.0   ...    50.0   6200.0  5.2   no    no   no   good   no   no
# 62    86.0   ...    33.0   7700.0  3.8  yes   yes   no   good   no   no
# 164  192.0   ...    40.0   9500.0  5.4   no   yes   no   poor  yes   no
# 114    NaN   ...     NaN  10300.0  NaN   no    no   no   good   no   no
# 397  100.0   ...    49.0   6600.0  5.4   no    no   no   good   no   no
# 47     NaN   ...    45.0   8600.0  NaN   no    no   no   good   no   no
# 150   78.0   ...    41.0   6700.0  NaN   no    no   no   poor  yes   no
# 188   80.0   ...    38.0      NaN  NaN   no    no   no   good   no   no
# 186    NaN   ...     NaN      NaN  NaN   no    no   no   good  yes   no
# 1      NaN   ...    38.0   6000.0  NaN   no    no   no   good   no   no
# 190   94.0   ...    30.0  16700.0  4.8   no    no   no   poor   no   no
# 131    NaN   ...    36.0  12400.0  NaN   no    no   no   good   no   no
# 75     NaN   ...     NaN      NaN  NaN   no    no   no   good   no  yes
# 185   99.0   ...    34.0      NaN  NaN   no    no   no   good   no   no
# 187    NaN   ...    34.0  12300.0  NaN   no    no   no   good   no   no
# 215    NaN   ...     NaN      NaN  NaN   no    no   no   good  yes   no
# 30    93.0   ...     NaN      NaN  NaN  yes   yes   no   good   no   no
# 73   129.0   ...    14.0   6300.0  NaN  yes    no   no   good  yes  yes
# 112    NaN   ...    33.0      NaN  NaN   no    no   no   good   no   no
# 116  104.0   ...     NaN      NaN  NaN   no    no   no   good  yes   no
# 117  219.0   ...    37.0   9800.0  4.4   no    no   no   good   no   no
# 169  220.0   ...    27.0      NaN  NaN  yes   yes   no   good   no  yes
# 191  110.0   ...    26.0   9200.0  3.4  yes   yes   no   poor   no   no
# 203  207.0   ...     NaN      NaN  NaN  yes   yes   no   good   no  yes
# 268  100.0   ...    53.0   8500.0  4.9   no    no   no   good   no   no
#
#       class
# 200     ckd
# 171     ckd
# 39      ckd
# 160     ckd
# 237     ckd
# 383  notckd
# 312  notckd
# 194     ckd
# 374  notckd
# 202     ckd
# 57      ckd
# 36      ckd
# 151     ckd
# 56      ckd
# 103     ckd
# 129     ckd
# 369  notckd
# 294  notckd
# 26      ckd
# 28      ckd
# 222     ckd
# 359  notckd
# 80      ckd
# 31      ckd
# 58      ckd
# 48      ckd
# 364  notckd
# 138     ckd
# 299  notckd
# 93      ckd
# ..      ...
# 274  notckd
# 209     ckd
# 173     ckd
# 398  notckd
# 102     ckd
# 387  notckd
# 62      ckd
# 164     ckd
# 114     ckd
# 397  notckd
# 47      ckd
# 150     ckd
# 188     ckd
# 186     ckd
# 1       ckd
# 190     ckd
# 131     ckd
# 75      ckd
# 185     ckd
# 187     ckd
# 215     ckd
# 30      ckd
# 73      ckd
# 112     ckd
# 116     ckd
# 117     ckd
# 169     ckd
# 191     ckd
# 203     ckd
# 268  notckd
#
# [400 rows x 25 columns]

# %%
my_df.sort_values(by = ["age","rbc"], 
                  ascending = [False,True]) # sort by first column in descending order, second column in ascending order
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 200  90.0   90.0  1.025  1.0  0.0       NaN    normal  notpresent  notpresent
# 171  83.0   70.0  1.020  3.0  0.0    normal    normal  notpresent  notpresent
# 39   82.0   80.0  1.010  2.0  2.0    normal       NaN  notpresent  notpresent
# 160  81.0   60.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 312  80.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 383  80.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 194  80.0   70.0  1.010  2.0  NaN       NaN  abnormal  notpresent  notpresent
# 237  80.0   70.0  1.015  2.0  2.0       NaN    normal  notpresent  notpresent
# 374  79.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 202  78.0   60.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 36   76.0   70.0  1.015  1.0  0.0    normal    normal  notpresent  notpresent
# 56   76.0   70.0  1.015  3.0  4.0    normal  abnormal     present  notpresent
# 103  76.0   70.0  1.015  2.0  0.0    normal  abnormal     present  notpresent
# 57   76.0   90.0    NaN  NaN  NaN       NaN    normal  notpresent  notpresent
# 151  76.0   90.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 294  75.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 369  75.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 26   75.0   80.0  1.015  0.0  0.0       NaN    normal  notpresent  notpresent
# 28   75.0   70.0    NaN  1.0  3.0       NaN       NaN  notpresent  notpresent
# 129  75.0   70.0  1.025  1.0  0.0       NaN    normal  notpresent  notpresent
# 359  74.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 80   74.0   80.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 222  74.0   60.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 58   73.0   80.0  1.020  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 93   73.0  100.0  1.010  3.0  2.0  abnormal  abnormal     present  notpresent
# 180  73.0   90.0  1.010  1.0  4.0  abnormal  abnormal     present  notpresent
# 48   73.0   70.0  1.005  0.0  0.0    normal    normal  notpresent  notpresent
# 299  73.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 364  73.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 31   73.0   90.0  1.015  3.0  0.0       NaN  abnormal     present  notpresent
# ..    ...    ...    ...  ...  ...       ...       ...         ...         ...
# 274  19.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 209  19.0   70.0  1.020  0.0  0.0       NaN    normal  notpresent  notpresent
# 173  17.0   70.0  1.015  1.0  0.0  abnormal    normal  notpresent  notpresent
# 398  17.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 102  17.0   60.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 387  15.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 62   15.0   60.0  1.020  3.0  0.0       NaN    normal  notpresent  notpresent
# 164  14.0    NaN  1.015  0.0  0.0       NaN       NaN  notpresent  notpresent
# 114  12.0   60.0  1.015  3.0  0.0  abnormal  abnormal     present  notpresent
# 397  12.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 47   11.0   80.0  1.010  3.0  0.0       NaN    normal  notpresent  notpresent
# 150   8.0   60.0  1.025  3.0  0.0    normal    normal  notpresent  notpresent
# 186   8.0   50.0  1.020  4.0  0.0    normal    normal  notpresent  notpresent
# 188   8.0    NaN    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 1     7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent  notpresent
# 190   6.0   60.0  1.010  4.0  0.0  abnormal  abnormal  notpresent     present
# 75    5.0    NaN  1.015  1.0  0.0       NaN    normal  notpresent  notpresent
# 131   5.0   50.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 185   4.0    NaN  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 187   3.0    NaN  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 215   2.0    NaN  1.010  3.0  0.0    normal  abnormal  notpresent  notpresent
# 73    NaN  100.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 112   NaN   60.0  1.015  3.0  0.0  abnormal  abnormal  notpresent  notpresent
# 116   NaN   70.0  1.015  4.0  0.0  abnormal    normal  notpresent  notpresent
# 191   NaN   70.0  1.010  3.0  0.0    normal    normal  notpresent  notpresent
# 30    NaN   70.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 117   NaN   70.0  1.020  0.0  0.0       NaN       NaN  notpresent  notpresent
# 169   NaN   70.0  1.010  0.0  2.0       NaN    normal  notpresent  notpresent
# 203   NaN   90.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 268   NaN   80.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
#
#        bgr   ...     pcv       wc   rc  htn    dm  cad  appet   pe  ane  \
# 200  139.0   ...    37.0   7900.0  3.9  yes   yes   no   good   no   no
# 171  102.0   ...    26.0  12800.0  3.1  yes    no   no   poor   no  yes
# 39   140.0   ...    40.0   9800.0  4.2  yes   yes   no   good   no   no
# 160  148.0   ...    35.0   9400.0  2.4  yes   yes  yes   poor  yes   no
# 312    NaN   ...    48.0   6300.0  6.1   no    no   no   good   no   no
# 383  119.0   ...    49.0   5100.0  5.0   no    no   no   good   no   no
# 194    NaN   ...     NaN      NaN  NaN  yes   yes   no   good   no   no
# 237  141.0   ...    40.0   9600.0  NaN  yes   yes   no   poor  yes   no
# 374  111.0   ...    40.0   8000.0  6.4   no    no   no   good   no   no
# 202  114.0   ...    24.0      NaN  NaN   no   yes   no   good   no  yes
# 36    92.0   ...    32.0      NaN  NaN  yes    no   no   good   no   no
# 56     NaN   ...    30.0  11300.0  3.4  yes   yes  yes   poor  yes   no
# 103  226.0   ...    36.0  12700.0  4.2  yes    no   no   poor  yes  yes
# 57    93.0   ...     NaN      NaN  NaN  yes   yes  yes   poor   no   no
# 151  172.0   ...    30.0      NaN  NaN  yes   yes   no   good   no  yes
# 294  110.0   ...    40.0   8300.0  5.8   no    no   no    NaN  NaN  NaN
# 369  107.0   ...    46.0  10300.0  4.8   no    no   no   good   no   no
# 26   156.0   ...    35.0  10300.0  4.0  yes   yes   no   poor   no   no
# 28   123.0   ...     NaN      NaN  NaN   no   yes   no   good   no   no
# 129  158.0   ...     NaN      NaN  NaN  yes    no   no   poor  yes   no
# 359   88.0   ...    53.0   6000.0  4.5   no    no   no   good   no   no
# 80   132.0   ...    31.0   9400.0  3.8  yes   yes   no   good   no   no
# 222  108.0   ...     NaN      NaN  NaN  yes   yes   no   good   no   no
# 58   253.0   ...    33.0   7200.0  4.3  yes   yes  yes   good   no   no
# 93   295.0   ...    30.0   7000.0  3.2  yes   yes  yes   poor   no   no
# 180  234.0   ...    28.0      NaN  NaN   no   yes   no   good   no   no
# 48    70.0   ...    29.0  18900.0  3.5  yes   yes   no   good  yes   no
# 299  127.0   ...    52.0  11000.0  4.7   no    no   no   good   no   no
# 364  118.0   ...    45.0   9300.0  4.7   no    no   no   good   no   no
# 31   107.0   ...    30.0   7800.0  4.0   no    no   no   poor   no   no
# ..     ...   ...     ...      ...  ...  ...   ...  ...    ...  ...  ...
# 274  107.0   ...    44.0      NaN  NaN   no    no   no   good   no   no
# 209    NaN   ...     NaN   6900.0  NaN   no    no   no   good   no   no
# 173   22.0   ...    41.0  11200.0  NaN   no    no   no   good   no   no
# 398  114.0   ...    51.0   7200.0  5.9   no    no   no   good   no   no
# 102   92.0   ...    52.0   7000.0  NaN   no    no   no   good   no   no
# 387   93.0   ...    50.0   6200.0  5.2   no    no   no   good   no   no
# 62    86.0   ...    33.0   7700.0  3.8  yes   yes   no   good   no   no
# 164  192.0   ...    40.0   9500.0  5.4   no   yes   no   poor  yes   no
# 114    NaN   ...     NaN  10300.0  NaN   no    no   no   good   no   no
# 397  100.0   ...    49.0   6600.0  5.4   no    no   no   good   no   no
# 47     NaN   ...    45.0   8600.0  NaN   no    no   no   good   no   no
# 150   78.0   ...    41.0   6700.0  NaN   no    no   no   poor  yes   no
# 186    NaN   ...     NaN      NaN  NaN   no    no   no   good  yes   no
# 188   80.0   ...    38.0      NaN  NaN   no    no   no   good   no   no
# 1      NaN   ...    38.0   6000.0  NaN   no    no   no   good   no   no
# 190   94.0   ...    30.0  16700.0  4.8   no    no   no   poor   no   no
# 75     NaN   ...     NaN      NaN  NaN   no    no   no   good   no  yes
# 131    NaN   ...    36.0  12400.0  NaN   no    no   no   good   no   no
# 185   99.0   ...    34.0      NaN  NaN   no    no   no   good   no   no
# 187    NaN   ...    34.0  12300.0  NaN   no    no   no   good   no   no
# 215    NaN   ...     NaN      NaN  NaN   no    no   no   good  yes   no
# 73   129.0   ...    14.0   6300.0  NaN  yes    no   no   good  yes  yes
# 112    NaN   ...    33.0      NaN  NaN   no    no   no   good   no   no
# 116  104.0   ...     NaN      NaN  NaN   no    no   no   good  yes   no
# 191  110.0   ...    26.0   9200.0  3.4  yes   yes   no   poor   no   no
# 30    93.0   ...     NaN      NaN  NaN  yes   yes   no   good   no   no
# 117  219.0   ...    37.0   9800.0  4.4   no    no   no   good   no   no
# 169  220.0   ...    27.0      NaN  NaN  yes   yes   no   good   no  yes
# 203  207.0   ...     NaN      NaN  NaN  yes   yes   no   good   no  yes
# 268  100.0   ...    53.0   8500.0  4.9   no    no   no   good   no   no
#
#       class
# 200     ckd
# 171     ckd
# 39      ckd
# 160     ckd
# 312  notckd
# 383  notckd
# 194     ckd
# 237     ckd
# 374  notckd
# 202     ckd
# 36      ckd
# 56      ckd
# 103     ckd
# 57      ckd
# 151     ckd
# 294  notckd
# 369  notckd
# 26      ckd
# 28      ckd
# 129     ckd
# 359  notckd
# 80      ckd
# 222     ckd
# 58      ckd
# 93      ckd
# 180     ckd
# 48      ckd
# 299  notckd
# 364  notckd
# 31      ckd
# ..      ...
# 274  notckd
# 209     ckd
# 173     ckd
# 398  notckd
# 102     ckd
# 387  notckd
# 62      ckd
# 164     ckd
# 114     ckd
# 397  notckd
# 47      ckd
# 150     ckd
# 186     ckd
# 188     ckd
# 1       ckd
# 190     ckd
# 75      ckd
# 131     ckd
# 185     ckd
# 187     ckd
# 215     ckd
# 73      ckd
# 112     ckd
# 116     ckd
# 191     ckd
# 30      ckd
# 117     ckd
# 169     ckd
# 203     ckd
# 268  notckd
#
# [400 rows x 25 columns]

# %% [markdown]
# # Creating a copy of the same dataframes

# %%
# creating a temporary copy that still references the main dataframe (an assignment)
my_other_df = my.df

# %%
# creating a fresh copy of the main dataframe without modifying the main df
my_copy = my.df.copy()

# %% [markdown]
# ### Sorting Rows - Method 2:
#
# Method 2 is Sorting rows based on labels (`df.sort_index(axis=0)`)
#
# ### DataFrames:
#
# Documentation: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_index.html

# %%
my_df.sort_index(axis=0) # sort rows
# Out:
#       DGN  PRE4   PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19  \
# 0    DGN2  2.88   2.16  PRZ1    F    F    F     T     T  OC14     F     F
# 1    DGN3  3.40   1.88  PRZ0    F    F    F     F     F  OC12     F     F
# 2    DGN3  2.76   2.08  PRZ1    F    F    F     T     F  OC11     F     F
# 3    DGN3  3.68   3.04  PRZ0    F    F    F     F     F  OC11     F     F
# 4    DGN3  2.44   0.96  PRZ2    F    T    F     T     T  OC11     F     F
# 5    DGN3  2.48   1.88  PRZ1    F    F    F     T     F  OC11     F     F
# 6    DGN3  4.36   3.28  PRZ1    F    F    F     T     F  OC12     T     F
# 7    DGN2  3.19   2.50  PRZ1    F    F    F     T     F  OC11     F     F
# 8    DGN3  3.16   2.64  PRZ2    F    F    F     T     T  OC11     F     F
# 9    DGN3  2.32   2.16  PRZ1    F    F    F     T     F  OC11     F     F
# 10   DGN3  2.56   2.32  PRZ0    F    T    F     T     F  OC12     F     F
# 11   DGN3  4.28   4.44  PRZ1    F    F    F     F     F  OC12     F     F
# 12   DGN3  3.00   2.36  PRZ1    F    F    F     T     T  OC11     F     F
# 13   DGN2  3.98   3.06  PRZ2    F    F    F     T     T  OC14     F     F
# 14   DGN3  1.96   1.40  PRZ1    F    F    F     T     F  OC11     F     F
# 15   DGN3  4.68   4.16  PRZ1    F    F    F     T     F  OC12     F     F
# 16   DGN2  2.21   1.88  PRZ0    F    T    F     F     F  OC12     F     F
# 17   DGN2  2.96   1.67  PRZ0    F    F    F     F     F  OC12     F     F
# 18   DGN3  2.60   1.68  PRZ1    F    F    F     T     F  OC12     F     F
# 19   DGN3  2.88   2.48  PRZ0    F    F    F     F     F  OC11     F     F
# 20   DGN3  4.48   3.48  PRZ0    F    F    F     F     F  OC12     F     F
# 21   DGN4  3.32   2.84  PRZ0    F    F    F     F     F  OC12     F     F
# 22   DGN3  2.36   1.68  PRZ0    F    F    F     F     F  OC12     F     F
# 23   DGN3  3.68   2.32  PRZ0    F    F    F     F     F  OC11     F     F
# 24   DGN8  4.32   3.20  PRZ0    F    F    F     F     F  OC11     F     F
# 25   DGN5  4.56  72.80  PRZ0    T    T    F     T     F  OC12     F     F
# 26   DGN3  3.24   3.08  PRZ1    F    F    F     T     F  OC11     F     F
# 27   DGN3  3.40   3.06  PRZ1    F    F    F     T     T  OC11     F     F
# 28   DGN3  3.16   2.69  PRZ1    F    F    F     T     T  OC11     F     F
# 29   DGN6  3.96   3.28  PRZ0    F    F    F     F     F  OC11     F     F
# ..    ...   ...    ...   ...  ...  ...  ...   ...   ...   ...   ...   ...
# 440  DGN3  3.00   2.44  PRZ1    F    F    F     T     T  OC12     F     F
# 441  DGN2  4.44   3.64  PRZ0    F    F    F     F     F  OC12     F     F
# 442  DGN2  4.08   2.24  PRZ1    F    F    T     T     F  OC12     F     F
# 443  DGN3  4.12   3.20  PRZ2    F    F    F     T     T  OC11     F     F
# 444  DGN3  2.56  60.90  PRZ0    F    F    F     F     F  OC11     F     F
# 445  DGN3  2.72   1.76  PRZ0    F    F    F     F     F  OC11     F     F
# 446  DGN8  5.20   4.10  PRZ0    F    F    F     F     F  OC12     F     F
# 447  DGN2  4.40   3.72  PRZ1    F    F    F     T     T  OC12     F     F
# 448  DGN3  2.96   2.24  PRZ0    F    F    F     F     F  OC12     F     F
# 449  DGN3  2.84   1.88  PRZ1    F    F    F     T     F  OC12     F     F
# 450  DGN3  2.28   1.68  PRZ2    F    F    F     T     T  OC11     F     F
# 451  DGN4  3.04   2.36  PRZ1    F    F    F     T     F  OC12     F     F
# 452  DGN3  2.80   2.24  PRZ1    T    F    F     T     F  OC13     F     F
# 453  DGN3  2.84   2.32  PRZ1    F    T    F     T     T  OC11     F     F
# 454  DGN3  3.24   2.76  PRZ0    F    F    F     F     F  OC11     F     F
# 455  DGN4  2.92   1.92  PRZ1    F    F    F     T     F  OC12     F     F
# 456  DGN3  2.40   1.24  PRZ1    F    F    F     T     F  OC12     F     F
# 457  DGN3  4.56   3.20  PRZ0    F    F    F     T     F  OC11     F     F
# 458  DGN3  3.60   3.00  PRZ1    F    F    F     T     F  OC11     F     F
# 459  DGN3  4.28   3.16  PRZ0    F    F    F     T     F  OC12     F     F
# 460  DGN4  4.65   3.78  PRZ1    F    F    F     T     F  OC12     F     F
# 461  DGN3  1.84   1.56  PRZ1    T    T    F     T     F  OC12     F     F
# 462  DGN3  2.12   1.68  PRZ2    T    T    F     F     F  OC11     F     F
# 463  DGN4  3.44   2.16  PRZ1    F    F    F     T     T  OC12     T     F
# 464  DGN3  3.08   2.16  PRZ1    F    F    F     T     T  OC13     F     F
# 465  DGN2  3.88   2.12  PRZ1    F    F    F     T     F  OC13     F     F
# 466  DGN3  3.76   3.12  PRZ0    F    F    F     F     F  OC11     F     F
# 467  DGN3  3.04   2.08  PRZ1    F    F    F     T     F  OC13     F     F
# 468  DGN3  1.96   1.68  PRZ1    F    F    F     T     T  OC12     F     F
# 469  DGN3  4.72   3.56  PRZ0    F    F    F     F     F  OC12     F     F
#
#     PRE25 PRE30 PRE32  AGE Risk1Yr
# 0       F     T     F   60       F
# 1       F     T     F   51       F
# 2       F     T     F   59       F
# 3       F     F     F   54       F
# 4       F     T     F   73       T
# 5       F     F     F   51       F
# 6       F     T     F   59       T
# 7       T     T     F   66       T
# 8       F     T     F   68       F
# 9       F     T     F   54       F
# 10      F     F     F   60       F
# 11      F     T     F   58       F
# 12      F     T     F   68       F
# 13      F     T     F   80       T
# 14      F     T     F   77       F
# 15      F     T     F   62       F
# 16      F     T     F   56       F
# 17      F     T     F   61       F
# 18      F     T     F   70       F
# 19      F     T     F   71       F
# 20      F     T     F   51       F
# 21      F     T     F   62       F
# 22      F     T     F   62       F
# 23      F     T     F   62       F
# 24      F     F     F   58       T
# 25      F     T     F   57       F
# 26      F     T     F   60       F
# 27      F     T     F   68       T
# 28      F     T     F   56       F
# 29      F     T     F   61       F
# ..    ...   ...   ...  ...     ...
# 440     F     T     F   65       F
# 441     F     F     F   62       F
# 442     F     F     F   61       F
# 443     F     F     F   76       F
# 444     F     T     F   50       F
# 445     F     T     F   63       F
# 446     F     F     F   49       F
# 447     F     T     F   52       F
# 448     F     T     F   69       F
# 449     F     T     F   53       T
# 450     F     F     F   77       F
# 451     F     T     F   59       F
# 452     F     T     F   70       F
# 453     F     T     F   72       F
# 454     F     T     F   70       F
# 455     F     T     F   70       F
# 456     F     T     F   62       F
# 457     F     T     F   61       F
# 458     F     F     F   46       F
# 459     F     F     F   66       F
# 460     F     F     F   55       F
# 461     F     F     F   72       F
# 462     F     T     F   74       F
# 463     F     T     F   57       T
# 464     F     T     F   79       F
# 465     F     T     F   63       F
# 466     F     T     F   61       F
# 467     F     F     F   52       F
# 468     F     T     F   79       F
# 469     F     T     F   51       F
#
# [470 rows x 17 columns]

# %% [markdown]
# ### Advanced Manipulation in Pandas - Introduction to GroupBy:
#
# __Overview:__
# - The GroupBy functionality draws from the common "Split-Apply-Combine" strategy which is summarized below:
# > 1. __Split:__  The split step involves splitting the data into groups based on some criteria
# > 2. __Apply:__ The apply step involves applying a function to each group independently. The functions applied in this step fall in 3 main categories:
# >> a. __Aggregation:__ The aggregation functions compute a summary statistic about each group (i.e. group sums, means, sizes, counts, etc.)<br>
# >> b. __Transformation:__ The transformation functions perform some group-specific computations on each group (i.e. standardize data within each group, fill NAs within groups, etc.)<br>
# >> c. __Filtration:__ The filtration functions discard some groups according to a group-wise computation (i.e. discard data that belongs to groups with only a few members, filter out data based on group sum or mean, etc.)<br>
# > 3. __Combine:__ The combine step involves combining the results into a data structure
#
# __Helpful Points:__
# 1. The GroupBy functionality exists in the SQL command `GROUP BY` which you can read about [here](https://dev.mysql.com/doc/refman/5.7/en/group-by-modifiers.html) and [here](https://docs.microsoft.com/en-us/sql/t-sql/queries/select-group-by-transact-sql) if you are interested
# 2. Arguably the most common functionality for Data Scientists is "GroupBy-Aggregation"
#
# ### GroupBy in Pandas:
#
# __Overview:__
# - The __[GroupBy](http://pandas.pydata.org/pandas-docs/stable/groupby.html)__ function in Pandas allows us to perform the "split-apply-combine" strategy in a very efficient manner
# - The procedure is performed in the following steps where the "combine" step is implicit in the "apply" step:
#
# > 1. __STEP 1 (SPLIT):__ Splitting is completed by creating a "GroupBy" object which basically just means separating out the data into constituent groups. GroupBy objects can be created in the following way:
# >> a. `grouped = obj.groupby(key)`<br>
# >> b. `grouped = obj.groupby(key, axis=1)`<br>
# >> c. `grouped = obj.groupby([key1, key2])`
# >> - Here, the `obj` is usually a Pandas `DataFrame` object and the `key` is most commonly one of the following:<br>
# >> > a. List or NumPy array<br>
# >> > b. Dictionary or Series<br>
# >> > c. Column name<br>
# >> - In practice, the "group keys" will refer to the labels of each group (i.e. "A" and "B" are the group keys for Group "A" and Group "B" and "Group" would be passed as the `key` argument into the `groupby` function)
#
# > 2. __STEP 2 (APPLY):__ Now that a GroupBy object has been created, we can perform various "apply" methods to the object such as:
# >> a. __Aggregation:__ Aggregation returns a new DataFrame and can be completed in this fashion: `grouped.agg` or `grouped.aggregate`<br>
# >> b. __Transformation:__ Transformation returns an object that is indexed the same as the one begin grouped and can be completed in this fashion: `grouped.transform`<br>
# >> c. __Filtration:__ Filtration returns a subset of the original object and can be completed in this fashion: `grouped.filter`<br>
# >> d. __Other:__ `grouped.count`, `grouped.cummax`, `grouped.cumsum`, `grouped.fillna`, `grouped.max`, etc.
#
# __Helpful Points:__
# 1. GroupBy objects have a few useful attributes for analyzing the groups that were created:
# > 1. The `groups` attribute to view the groups that were created: `df.groupby(key).groups`
# > 2. The `describe` attribute to view information about the groups that were created: `df.groupby(key).describe()`
# > 3. The `ngroups` attribute to view the number of groups that were created: `df.groupby(key).ngroups`
# > 4. The `first` attribute to view the first few rows of the groups that were created: `df.groupby(key).first()`
# > 5. The `last` attribute to view the last few rows of the groups that were created: `df.groupby(key).last()`
# > 6. The `get_group` attribute to access one of the many groups that were created:`df.groupby(key).get_group()`
# 2. Remember you can always see a complete list of all the attributes of an object by selecting `obj.<TAB>`
#
# __Practice:__ Examples of GroupBy in Pandas in Python
#
# ### Step 1 - Split:
#
# ### (Group by rbc):

# %%
# data + ".groupby" creates an object 
grouped_rbc = my_df.groupby('rbc')
grouped_rbc # groupby object

# %% [markdown]
# ### Example Attributes of GroupBy Object:

# %%
grouped_rbc.groups # groups
# Out:
# {'abnormal': Int64Index([  9,  11,  20,  29,  33,  35,  38,  43,  44,  55,  58,  63,  66,
#               73,  74,  76,  91,  93, 100, 112, 114, 116, 143, 144, 145, 146,
#              149, 153, 154, 155, 159, 161, 167, 173, 178, 180, 189, 190, 193,
#              195, 196, 225, 226, 232, 234, 246, 248],
#             dtype='int64'),
#  'normal': Int64Index([  2,   3,   4,   7,   8,  14,  22,  24,  27,  34,
#              ...
#              390, 391, 392, 393, 394, 395, 396, 397, 398, 399],
#             dtype='int64', length=201)}

# %%
# grouped_df + ".describe()" 
## summary statistics for a grouped object 
grouped_rbc.describe()
# Out:
#             age                                                          al  \
#           count       mean        std  min    25%   50%    75%   max  count
# rbc
# abnormal   44.0  52.068182  15.863367  6.0  45.00  56.0  63.25  73.0   47.0
# normal    200.0  48.580000  16.973038  2.0  36.75  48.5  61.00  83.0  198.0
#
#                      ...      su          wc                            \
#               mean   ...     75%  max  count         mean          std
# rbc                  ...
# abnormal  2.319149   ...     1.0  5.0   30.0  8430.000000  3486.639524
# normal    0.742424   ...     0.0  4.0  180.0  8467.777778  3105.980095
#
#
#              min     25%     50%      75%      max
# rbc
# abnormal  2200.0  6225.0  8550.0  10450.0  16700.0
# normal    3800.0  6575.0  7850.0   9725.0  26400.0
#
# [2 rows x 112 columns]

# %%
## for single statistics test 
grouped_rbc.mean() # mean 

grouped_rbc.agg(np.mean) # passing the mean function ["np.mean"] to the aggregated groups

# %%
grouped_rbc.ngroups # number of groups
# Out:
# 2

# %%
grouped_rbc.first() # first row of each group
# Out:
#            age    bp    sg   al   su        pc         pcc          ba    bgr  \
# rbc
# abnormal  53.0  90.0  1.02  2.0  0.0  abnormal     present  notpresent   70.0
# normal    62.0  80.0  1.01  2.0  3.0    normal  notpresent  notpresent  423.0
#
#              bu  ...    pcv       wc   rc  htn   dm  cad  appet  pe  ane class
# rbc              ...
# abnormal  107.0  ...   29.0  12100.0  3.7  yes  yes   no   poor  no  yes   ckd
# normal     53.0  ...   31.0   7500.0  3.9   no  yes   no   poor  no  yes   ckd
#
# [2 rows x 24 columns]

# %%
grouped_rbc.last() # last row of each group
# Out:
#            age    bp     sg   al   su        pc         pcc          ba  \
# rbc
# abnormal  59.0  70.0  1.010  1.0  3.0  abnormal  notpresent  notpresent
# normal    58.0  80.0  1.025  0.0  0.0    normal  notpresent  notpresent
#
#             bgr    bu   ...     pcv       wc   rc  htn   dm  cad  appet  pe  \
# rbc                     ...
# abnormal  424.0  55.0   ...    37.0  10200.0  4.1  yes  yes  yes   good  no
# normal    131.0  18.0   ...    53.0   6800.0  6.1   no   no   no   good  no
#
#          ane   class
# rbc
# abnormal  no     ckd
# normal    no  notckd
#
# [2 rows x 24 columns]

# %%
grouped_rbc.nth(2) # nth row of each group (if it exists)
# Out:
#            age   al  ane appet          ba    bgr    bp     bu  cad class  \
# rbc
# abnormal  61.0  2.0  yes  poor  notpresent  173.0  80.0  148.0  yes   ckd
# normal    51.0  2.0   no  good  notpresent  106.0  80.0   26.0   no   ckd
# normal    60.0  3.0   no  good  notpresent   74.0  90.0   25.0   no   ckd
#
#            ...           pcc   pcv   pe  pot   rc   sc     sg    sod   su  \
# rbc        ...
# abnormal   ...    notpresent  24.0  yes  5.2  3.2  3.9  1.015  135.0  0.0
# normal     ...    notpresent  35.0   no  NaN  4.6  1.4  1.010    NaN  0.0
# normal     ...    notpresent  39.0  yes  3.2  4.4  1.1  1.015  142.0  0.0
#
#               wc
# rbc
# abnormal  9200.0
# normal    7300.0
# normal    7800.0
#
# [3 rows x 24 columns]

# %% [markdown]
# ### Group by rbc:

# %%
grouped_rbc = my_df.groupby('rbc')
grouped_rbc # groupby object

# %%
grouped_rbc["rbc"]

# %%
grouped_rbc.groups
# Out:
# {'abnormal': Int64Index([  9,  11,  20,  29,  33,  35,  38,  43,  44,  55,  58,  63,  66,
#               73,  74,  76,  91,  93, 100, 112, 114, 116, 143, 144, 145, 146,
#              149, 153, 154, 155, 159, 161, 167, 173, 178, 180, 189, 190, 193,
#              195, 196, 225, 226, 232, 234, 246, 248],
#             dtype='int64'),
#  'normal': Int64Index([  2,   3,   4,   7,   8,  14,  22,  24,  27,  34,
#              ...
#              390, 391, 392, 393, 394, 395, 396, 397, 398, 399],
#             dtype='int64', length=201)}

# %%
grouped_rbc.get_group("abnormal") # get one group
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 9    53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 11   63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 20   61.0   80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 29   68.0   70.0  1.005  1.0  0.0  abnormal  abnormal     present  notpresent
# 33   60.0  100.0  1.020  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 35   65.0   90.0  1.020  2.0  1.0  abnormal    normal  notpresent  notpresent
# 38   69.0   80.0  1.020  3.0  0.0  abnormal    normal  notpresent  notpresent
# 43   35.0   80.0  1.010  1.0  0.0  abnormal       NaN  notpresent  notpresent
# 44   54.0   80.0  1.010  3.0  0.0  abnormal  abnormal  notpresent  notpresent
# 55   35.0   80.0  1.005  3.0  0.0  abnormal    normal  notpresent  notpresent
# 58   73.0   80.0  1.020  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 63   46.0   70.0  1.015  1.0  0.0  abnormal    normal  notpresent  notpresent
# 66   67.0   70.0  1.020  2.0  0.0  abnormal    normal  notpresent  notpresent
# 73    NaN  100.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 74   56.0   90.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 76   48.0   80.0  1.005  4.0  0.0  abnormal  abnormal  notpresent     present
# 91   56.0   70.0  1.015  4.0  1.0  abnormal    normal  notpresent  notpresent
# 93   73.0  100.0  1.010  3.0  2.0  abnormal  abnormal     present  notpresent
# 100  34.0   70.0  1.015  4.0  0.0  abnormal  abnormal  notpresent  notpresent
# 112   NaN   60.0  1.015  3.0  0.0  abnormal  abnormal  notpresent  notpresent
# 114  12.0   60.0  1.015  3.0  0.0  abnormal  abnormal     present  notpresent
# 116   NaN   70.0  1.015  4.0  0.0  abnormal    normal  notpresent  notpresent
# 143  41.0   80.0  1.015  1.0  4.0  abnormal    normal  notpresent  notpresent
# 144  60.0   90.0  1.010  2.0  0.0  abnormal    normal  notpresent  notpresent
# 145  57.0   90.0  1.015  5.0  0.0  abnormal  abnormal  notpresent     present
# 146  53.0  100.0  1.010  1.0  3.0  abnormal    normal  notpresent  notpresent
# 149  65.0   70.0  1.020  1.0  0.0  abnormal  abnormal  notpresent  notpresent
# 153  55.0   90.0  1.010  2.0  1.0  abnormal  abnormal  notpresent  notpresent
# 154  56.0   90.0  1.005  4.0  3.0  abnormal  abnormal  notpresent  notpresent
# 155  50.0   70.0  1.020  3.0  0.0  abnormal    normal     present     present
# 159  59.0   80.0  1.010  1.0  0.0  abnormal    normal  notpresent  notpresent
# 161  62.0    NaN  1.015  3.0  0.0  abnormal       NaN  notpresent  notpresent
# 167  34.0   70.0  1.020  0.0  0.0  abnormal    normal  notpresent  notpresent
# 173  17.0   70.0  1.015  1.0  0.0  abnormal    normal  notpresent  notpresent
# 178  42.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 180  73.0   90.0  1.010  1.0  4.0  abnormal  abnormal     present  notpresent
# 189  64.0   60.0  1.010  4.0  1.0  abnormal  abnormal  notpresent     present
# 190   6.0   60.0  1.010  4.0  0.0  abnormal  abnormal  notpresent     present
# 193  32.0   90.0  1.025  1.0  0.0  abnormal  abnormal  notpresent  notpresent
# 195  70.0   90.0  1.020  2.0  1.0  abnormal  abnormal  notpresent     present
# 196  49.0  100.0  1.010  3.0  0.0  abnormal  abnormal  notpresent  notpresent
# 225  60.0   90.0  1.010  3.0  5.0  abnormal    normal  notpresent     present
# 226  64.0  100.0  1.015  4.0  2.0  abnormal  abnormal  notpresent     present
# 232  50.0   90.0  1.015  1.0  0.0  abnormal  abnormal  notpresent  notpresent
# 234  37.0  100.0  1.010  0.0  0.0  abnormal    normal  notpresent  notpresent
# 246  48.0  110.0  1.015  3.0  0.0  abnormal    normal     present  notpresent
# 248  59.0   70.0  1.010  1.0  3.0  abnormal  abnormal  notpresent  notpresent
#
#        bgr  ...    pcv       wc   rc  htn   dm  cad  appet   pe  ane class
# 9     70.0  ...   29.0  12100.0  3.7  yes  yes   no   poor   no  yes   ckd
# 11   380.0  ...   32.0   4500.0  3.8  yes  yes   no   poor  yes   no   ckd
# 20   173.0  ...   24.0   9200.0  3.2  yes  yes  yes   poor  yes  yes   ckd
# 29     NaN  ...   38.0      NaN  NaN   no   no  yes   good   no   no   ckd
# 33   140.0  ...   29.0      NaN  NaN  yes   no   no   poor   no   no   ckd
# 35   270.0  ...   36.0   9800.0  4.9  yes  yes   no   poor   no  yes   ckd
# 38     NaN  ...    NaN      NaN  NaN  yes   no   no   good   no   no   ckd
# 43    79.0  ...   24.0   7900.0  3.1   no  yes   no   good   no   no   ckd
# 44   207.0  ...   28.0      NaN  NaN  yes  yes   no   poor  yes   no   ckd
# 55     NaN  ...   28.0      NaN  NaN   no   no   no   good  yes   no   ckd
# 58   253.0  ...   33.0   7200.0  4.3  yes  yes  yes   good   no   no   ckd
# 63   150.0  ...   27.0      NaN  NaN   no   no   no   good   no  yes   ckd
# 66   150.0  ...    NaN      NaN  NaN  yes  yes   no   good  yes   no   ckd
# 73   129.0  ...   14.0   6300.0  NaN  yes   no   no   good  yes  yes   ckd
# 74   129.0  ...   29.0   6400.0  3.4  yes   no   no   good   no   no   ckd
# 76   133.0  ...   36.0   6200.0  4.0   no  yes   no   good  yes   no   ckd
# 91   210.0  ...   52.0  12500.0  5.6   no   no   no   good   no   no   ckd
# 93   295.0  ...   30.0   7000.0  3.2  yes  yes  yes   poor   no   no   ckd
# 100  153.0  ...    NaN      NaN  NaN   no   no   no   good  yes   no   ckd
# 112    NaN  ...   33.0      NaN  NaN   no   no   no   good   no   no   ckd
# 114    NaN  ...    NaN  10300.0  NaN   no   no   no   good   no   no   ckd
# 116  104.0  ...    NaN      NaN  NaN   no   no   no   good  yes   no   ckd
# 143  210.0  ...    NaN      NaN  NaN   no  yes   no   good   no   no   ckd
# 144  105.0  ...   33.0  10500.0  4.1   no   no   no   good   no   no   ckd
# 145    NaN  ...   24.0   4200.0  3.3  yes  yes  yes   poor  yes  yes   ckd
# 146  213.0  ...    NaN      NaN  NaN   no  yes   no   good   no   no   ckd
# 149  139.0  ...   32.0      NaN  NaN  yes   no   no   good  yes   no   ckd
# 153  273.0  ...   22.0  14600.0  2.9  yes  yes   no   poor  yes  yes   ckd
# 154  242.0  ...   26.0      NaN  3.0  yes  yes   no   poor  yes  yes   ckd
# 155  123.0  ...   36.0   4700.0  NaN   no   no   no   good   no   no   ckd
# 159  303.0  ...   35.0  10900.0  4.3   no  yes   no   poor   no   no   ckd
# 161    NaN  ...   42.0  10200.0  4.8  yes  yes   no   good   no   no   ckd
# 167  139.0  ...   42.0   2200.0  NaN   no   no   no   poor   no   no   ckd
# 173   22.0  ...   41.0  11200.0  NaN   no   no   no   good   no   no   ckd
# 178   93.0  ...   34.0   9800.0  NaN   no   no   no   poor  yes  yes   ckd
# 180  234.0  ...   28.0      NaN  NaN   no  yes   no   good   no   no   ckd
# 189  239.0  ...   29.0   7500.0  3.4  yes  yes   no   poor  yes   no   ckd
# 190   94.0  ...   30.0  16700.0  4.8   no   no   no   poor   no   no   ckd
# 193    NaN  ...   15.0   2600.0  2.8  yes  yes   no   poor  yes  yes   ckd
# 195  184.0  ...    NaN      NaN  NaN  yes  yes  yes   poor   no   no   ckd
# 196  129.0  ...   24.0   9600.0  3.5  yes  yes   no   poor  yes  yes   ckd
# 225  490.0  ...   35.0  12000.0  4.5  yes  yes   no   good   no   no   ckd
# 226  163.0  ...   26.0   7500.0  3.4  yes  yes   no   good  yes   no   ckd
# 232    NaN  ...    NaN      NaN  NaN   no   no   no   good  yes   no   ckd
# 234    NaN  ...   44.0   4100.0  5.2  yes   no   no   good   no   no   ckd
# 246  106.0  ...   26.0   5000.0  2.5  yes   no  yes   good   no  yes   ckd
# 248  424.0  ...   37.0  10200.0  4.1  yes  yes  yes   good   no   no   ckd
#
# [47 rows x 25 columns]

# %% [markdown]
# ### Step 2 - Apply/Aggregate:
#
# ### Aggregate by Sum:

# %%
grouped_rbc.aggregate(np.sum) # aggregate sum based on one group
grouped_rbc.sum()
# Out:
#              age       bp       sg     al    su      bgr      bu     sc  \
# rbc
# abnormal  2291.0   3780.0   47.655  109.0  31.0   6950.0  4025.1  235.2
# normal    9716.0  14300.0  202.925  147.0  52.0  24556.0  9579.0  421.0
#
#               sod    pot    hemo     pcv         wc     rc
# rbc
# abnormal   4372.0  146.1   415.4  1183.0   252900.0   95.8
# normal    25405.0  873.1  2554.0  7887.0  1524200.0  870.7

# %%
grouped_rbc.agg(np.sum) # note: we can also just write agg instead of aggregate
# Out:
#              age       bp       sg     al    su      bgr      bu     sc  \
# rbc
# abnormal  2291.0   3780.0   47.655  109.0  31.0   6950.0  4025.1  235.2
# normal    9716.0  14300.0  202.925  147.0  52.0  24556.0  9579.0  421.0
#
#               sod    pot    hemo     pcv         wc     rc
# rbc
# abnormal   4372.0  146.1   415.4  1183.0   252900.0   95.8
# normal    25405.0  873.1  2554.0  7887.0  1524200.0  870.7

# %%
# creating the grouping variable as a new column
my_df.groupby("rbc", as_index = False).sum() # if we want the group keys as a column and not index
# Out:
#         rbc     age       bp       sg     al    su      bgr      bu     sc  \
# 0  abnormal  2291.0   3780.0   47.655  109.0  31.0   6950.0  4025.1  235.2
# 1    normal  9716.0  14300.0  202.925  147.0  52.0  24556.0  9579.0  421.0
#
#        sod    pot    hemo     pcv         wc     rc
# 0   4372.0  146.1   415.4  1183.0   252900.0   95.8
# 1  25405.0  873.1  2554.0  7887.0  1524200.0  870.7

# %%
# group by multiple components: multiindex
## new groupby object by department AND city
grouped_rbc_pc = my_df.groupby(["rbc", "pc"])

grouped_rbc_pc.aggregate(np.sum) # aggregate sum based on two groups
# Out:
#                       age       bp       sg    al    su      bgr      bu  \
# rbc      pc
# abnormal abnormal  1397.0   2310.0   28.385  71.0  17.0   4276.0  2807.6
#          normal     797.0   1390.0   17.245  34.0  14.0   2595.0  1015.5
# normal   abnormal  1616.0   2170.0   30.390  83.0  26.0   5162.0  3110.0
#          normal    7667.0  11630.0  166.460  57.0  18.0  18197.0  5987.0
#
#                       sc      sod    pot    hemo     pcv         wc     rc
# rbc      pc
# abnormal abnormal  156.6   2780.0   94.8   242.1   682.0   151900.0   56.8
#          normal     67.8   1458.0   47.9   151.1   435.0    82900.0   31.1
# normal   abnormal  165.7   2891.0  174.7   241.3   740.0   263500.0   86.5
#          normal    208.1  21691.0  670.5  2256.1  6976.0  1204100.0  764.9

# %% [markdown]
# The above is actually an example of "multiple keys" since we have both "Department" and "City" as keys and therefore the result is a __[MultiIndex](http://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced-hierarchical) or Hierarchical Index__. We can avoid this by making the group keys both into columns like we did above:

# %%
my_df.groupby(["rbc", "pc"], as_index = False).sum()
# Out:
#         rbc        pc     age       bp       sg    al    su      bgr      bu  \
# 0  abnormal  abnormal  1397.0   2310.0   28.385  71.0  17.0   4276.0  2807.6
# 1  abnormal    normal   797.0   1390.0   17.245  34.0  14.0   2595.0  1015.5
# 2    normal  abnormal  1616.0   2170.0   30.390  83.0  26.0   5162.0  3110.0
# 3    normal    normal  7667.0  11630.0  166.460  57.0  18.0  18197.0  5987.0
#
#       sc      sod    pot    hemo     pcv         wc     rc
# 0  156.6   2780.0   94.8   242.1   682.0   151900.0   56.8
# 1   67.8   1458.0   47.9   151.1   435.0    82900.0   31.1
# 2  165.7   2891.0  174.7   241.3   740.0   263500.0   86.5
# 3  208.1  21691.0  670.5  2256.1  6976.0  1204100.0  764.9

# %% [markdown]
# ### Aggregate by Mean:

# %%
grouped_rbc.aggregate(np.mean) # means based on one group
# Out:
#                 age         bp        sg        al        su         bgr  \
# rbc
# abnormal  52.068182  82.173913  1.013936  2.319149  0.659574  187.837838
# normal    48.580000  73.333333  1.019724  0.742424  0.262626  130.617021
#
#                  bu        sc         sod       pot       hemo        pcv  \
# rbc
# abnormal  91.479545  5.345455  132.484848  4.427273  10.131707  31.131579
# normal    50.151832  2.170103  139.587912  4.797253  13.805405  42.176471
#
#                    wc        rc
# rbc
# abnormal  8430.000000  3.832000
# normal    8467.777778  5.004023

# %%
grouped_rbc_pc.aggregate(np.mean) # means based on two groups
# Out:
#                          age         bp        sg        al        su  \
# rbc      pc
# abnormal abnormal  53.730769  82.500000  1.013750  2.535714  0.607143
#          normal    49.812500  81.764706  1.014412  2.000000  0.823529
# normal   abnormal  53.866667  77.500000  1.013000  2.766667  0.866667
#          normal    47.036810  72.236025  1.021227  0.349693  0.110429
#
#                           bgr          bu        sc         sod       pot  \
# rbc      pc
# abnormal abnormal  194.363636  103.985185  5.800000  132.380952  4.514286
#          normal    185.357143   63.468750  4.237500  132.545455  4.354545
# normal   abnormal  191.185185  111.071429  5.917857  131.409091  7.940909
#          normal    117.400000   37.892405  1.308805  140.850649  4.353896
#
#                         hemo        pcv            wc        rc
# rbc      pc
# abnormal abnormal   9.311538  28.416667   8438.888889  3.550000
#          normal    11.623077  36.250000   8290.000000  4.442857
# normal   abnormal   9.652000  29.600000  10134.615385  3.604167
#          normal    14.555484  44.433121   8081.208054  5.275172

# %%
grouped_rbc_pc.mean()
# Out:
#                          age         bp        sg        al        su  \
# rbc      pc
# abnormal abnormal  53.730769  82.500000  1.013750  2.535714  0.607143
#          normal    49.812500  81.764706  1.014412  2.000000  0.823529
# normal   abnormal  53.866667  77.500000  1.013000  2.766667  0.866667
#          normal    47.036810  72.236025  1.021227  0.349693  0.110429
#
#                           bgr          bu        sc         sod       pot  \
# rbc      pc
# abnormal abnormal  194.363636  103.985185  5.800000  132.380952  4.514286
#          normal    185.357143   63.468750  4.237500  132.545455  4.354545
# normal   abnormal  191.185185  111.071429  5.917857  131.409091  7.940909
#          normal    117.400000   37.892405  1.308805  140.850649  4.353896
#
#                         hemo        pcv            wc        rc
# rbc      pc
# abnormal abnormal   9.311538  28.416667   8438.888889  3.550000
#          normal    11.623077  36.250000   8290.000000  4.442857
# normal   abnormal   9.652000  29.600000  10134.615385  3.604167
#          normal    14.555484  44.433121   8081.208054  5.275172

# %% [markdown]
# ### Aggregate by Size:

# %%
grouped_rbc.size()
# Out:
# DGN
# DGN1      1
# DGN2     52
# DGN3    349
# DGN4     47
# DGN5     15
# DGN6      4
# DGN8      2
# dtype: int64

# %%
grouped_rbc_pc.size()
# Out:
# rbc       pc
# abnormal  abnormal     28
#           normal       17
# normal    abnormal     30
#           normal      164
# dtype: int64

# %% [markdown]
# ### Aggregate by Multiple Functions:

# %%
grouped_rbc.aggregate([np.sum, np.mean, np.std]) # this is similar to describe() above
# Out:
#              age                             bp                        \
#              sum       mean        std      sum       mean        std
# rbc
# abnormal  2291.0  52.068182  15.863367   3780.0  82.173913  12.980848
# normal    9716.0  48.580000  16.973038  14300.0  73.333333  10.919889
#
#                sg                         al    ...         hemo     pcv  \
#               sum      mean       std    sum    ...          std     sum
# rbc                                             ...
# abnormal   47.655  1.013936  0.004883  109.0    ...     2.429860  1183.0
# normal    202.925  1.019724  0.005394  147.0    ...     2.706368  7887.0
#
#                                       wc                               rc  \
#                mean       std        sum         mean          std    sum
# rbc
# abnormal  31.131579  7.577246   252900.0  8430.000000  3486.639524   95.8
# normal    42.176471  8.439276  1524200.0  8467.777778  3105.980095  870.7
#
#
#               mean       std
# rbc
# abnormal  3.832000  0.810720
# normal    5.004023  0.963097
#
# [2 rows x 42 columns]

# %% [markdown]
# ### Create new column that is sum of pre4 values on a per-dgn group level:

# %%
# ".transform" 
my_df["age_SUM"] = grouped_rbc["age"].transform('sum') 
my_df
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 0    48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 1     7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent  notpresent
# 2    62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent
# 3    48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 4    51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 5    60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent  notpresent
# 6    68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 7    24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent  notpresent
# 8    52.0  100.0  1.015  3.0  0.0    normal  abnormal     present  notpresent
# 9    53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 10   50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present  notpresent
# 11   63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 12   68.0   70.0  1.015  3.0  1.0       NaN    normal     present  notpresent
# 13   68.0   70.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 14   68.0   80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 15   40.0   80.0  1.015  3.0  0.0       NaN    normal  notpresent  notpresent
# 16   47.0   70.0  1.015  2.0  0.0       NaN    normal  notpresent  notpresent
# 17   47.0   80.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 18   60.0  100.0  1.025  0.0  3.0       NaN    normal  notpresent  notpresent
# 19   62.0   60.0  1.015  1.0  0.0       NaN  abnormal     present  notpresent
# 20   61.0   80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 21   60.0   90.0    NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 22   48.0   80.0  1.025  4.0  0.0    normal  abnormal  notpresent  notpresent
# 23   21.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 24   42.0  100.0  1.015  4.0  0.0    normal  abnormal  notpresent     present
# 25   61.0   60.0  1.025  0.0  0.0       NaN    normal  notpresent  notpresent
# 26   75.0   80.0  1.015  0.0  0.0       NaN    normal  notpresent  notpresent
# 27   69.0   70.0  1.010  3.0  4.0    normal  abnormal  notpresent  notpresent
# 28   75.0   70.0    NaN  1.0  3.0       NaN       NaN  notpresent  notpresent
# 29   68.0   70.0  1.005  1.0  0.0  abnormal  abnormal     present  notpresent
# ..    ...    ...    ...  ...  ...       ...       ...         ...         ...
# 370  69.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 371  28.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 372  72.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 373  61.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 374  79.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 375  70.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 376  58.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 377  64.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 378  71.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 379  62.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 380  59.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 381  71.0   70.0  1.025  0.0  0.0       NaN       NaN  notpresent  notpresent
# 382  48.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 383  80.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 384  57.0   60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 385  63.0   70.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 386  46.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 387  15.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 388  51.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 389  41.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 390  52.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 391  36.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 392  57.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 393  43.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 394  50.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 395  55.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 396  42.0   70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 397  12.0   80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 398  17.0   60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 399  58.0   80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
#
#        bgr   ...         wc   rc  htn   dm  cad  appet   pe  ane   class  \
# 0    121.0   ...     7800.0  5.2  yes  yes   no   good   no   no     ckd
# 1      NaN   ...     6000.0  NaN   no   no   no   good   no   no     ckd
# 2    423.0   ...     7500.0  NaN   no  yes   no   poor   no  yes     ckd
# 3    117.0   ...     6700.0  3.9  yes   no   no   poor  yes  yes     ckd
# 4    106.0   ...     7300.0  4.6   no   no   no   good   no   no     ckd
# 5     74.0   ...     7800.0  4.4  yes  yes   no   good  yes   no     ckd
# 6    100.0   ...        NaN  NaN   no   no   no   good   no   no     ckd
# 7    410.0   ...     6900.0  5.0   no  yes   no   good  yes   no     ckd
# 8    138.0   ...     9600.0  4.0  yes  yes   no   good   no  yes     ckd
# 9     70.0   ...    12100.0  3.7  yes  yes   no   poor   no  yes     ckd
# 10   490.0   ...        NaN  NaN  yes  yes   no   good   no  yes     ckd
# 11   380.0   ...     4500.0  3.8  yes  yes   no   poor  yes   no     ckd
# 12   208.0   ...    12200.0  3.4  yes  yes  yes   poor  yes   no     ckd
# 13    98.0   ...        NaN  NaN  yes  yes  yes   poor  yes   no     ckd
# 14   157.0   ...    11000.0  2.6  yes  yes  yes   poor  yes   no     ckd
# 15    76.0   ...     3800.0  2.8  yes   no   no   good   no  yes     ckd
# 16    99.0   ...        NaN  NaN   no   no   no   good   no   no     ckd
# 17   114.0   ...        NaN  NaN  yes   no   no   poor   no   no     ckd
# 18   263.0   ...    11400.0  4.3  yes  yes  yes   good   no   no     ckd
# 19   100.0   ...     5300.0  3.7  yes   no  yes   good   no   no     ckd
# 20   173.0   ...     9200.0  3.2  yes  yes  yes   poor  yes  yes     ckd
# 21     NaN   ...     6200.0  3.6  yes  yes  yes   good   no   no     ckd
# 22    95.0   ...     6900.0  3.4  yes   no   no   good   no  yes     ckd
# 23     NaN   ...        NaN  NaN   no   no   no   poor   no  yes     ckd
# 24     NaN   ...     8300.0  4.6  yes   no   no   poor   no   no     ckd
# 25   108.0   ...     8400.0  3.7  yes  yes   no   good   no  yes     ckd
# 26   156.0   ...    10300.0  4.0  yes  yes   no   poor   no   no     ckd
# 27   264.0   ...     9600.0  4.1  yes  yes  yes   good  yes   no     ckd
# 28   123.0   ...        NaN  NaN   no  yes   no   good   no   no     ckd
# 29     NaN   ...        NaN  NaN   no   no  yes   good   no   no     ckd
# ..     ...   ...        ...  ...  ...  ...  ...    ...  ...  ...     ...
# 370   83.0   ...     9300.0  5.4   no   no   no   good   no   no  notckd
# 371   79.0   ...     6500.0  5.0   no   no   no   good   no   no  notckd
# 372  109.0   ...    10500.0  5.5   no   no   no   good   no   no  notckd
# 373  133.0   ...     9200.0  4.9   no   no   no   good   no   no  notckd
# 374  111.0   ...     8000.0  6.4   no   no   no   good   no   no  notckd
# 375   74.0   ...     9700.0  5.6   no   no   no   good   no   no  notckd
# 376   88.0   ...     9100.0  5.2   no   no   no   good   no   no  notckd
# 377   97.0   ...     6400.0  4.8   no   no   no   good   no   no  notckd
# 378    NaN   ...     7700.0  5.5   no   no   no   good   no   no  notckd
# 379   78.0   ...     5400.0  5.7   no   no   no   good   no   no  notckd
# 380  113.0   ...     6500.0  4.9   no   no   no   good   no   no  notckd
# 381   79.0   ...     5800.0  5.9   no   no   no   good   no   no  notckd
# 382   75.0   ...     6000.0  6.5   no   no   no   good   no   no  notckd
# 383  119.0   ...     5100.0  5.0   no   no   no   good   no   no  notckd
# 384  132.0   ...    11000.0  4.5   no   no   no   good   no   no  notckd
# 385  113.0   ...     8000.0  5.1   no   no   no   good   no   no  notckd
# 386  100.0   ...     5700.0  6.5   no   no   no   good   no   no  notckd
# 387   93.0   ...     6200.0  5.2   no   no   no   good   no   no  notckd
# 388   94.0   ...     9500.0  6.4   no   no   no   good   no   no  notckd
# 389  112.0   ...     7200.0  5.8   no   no   no   good   no   no  notckd
# 390   99.0   ...     6300.0  5.3   no   no   no   good   no   no  notckd
# 391   85.0   ...     5800.0  6.3   no   no   no   good   no   no  notckd
# 392  133.0   ...     6600.0  5.5   no   no   no   good   no   no  notckd
# 393  117.0   ...     7400.0  5.4   no   no   no   good   no   no  notckd
# 394  137.0   ...     9500.0  4.6   no   no   no   good   no   no  notckd
# 395  140.0   ...     6700.0  4.9   no   no   no   good   no   no  notckd
# 396   75.0   ...     7800.0  6.2   no   no   no   good   no   no  notckd
# 397  100.0   ...     6600.0  5.4   no   no   no   good   no   no  notckd
# 398  114.0   ...     7200.0  5.9   no   no   no   good   no   no  notckd
# 399  131.0   ...     6800.0  6.1   no   no   no   good   no   no  notckd
#
#     age_SUM
# 0       NaN
# 1       NaN
# 2    9716.0
# 3    9716.0
# 4    9716.0
# 5       NaN
# 6       NaN
# 7    9716.0
# 8    9716.0
# 9    2291.0
# 10      NaN
# 11   2291.0
# 12      NaN
# 13      NaN
# 14   9716.0
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20   2291.0
# 21      NaN
# 22   9716.0
# 23      NaN
# 24   9716.0
# 25      NaN
# 26      NaN
# 27   9716.0
# 28      NaN
# 29   2291.0
# ..      ...
# 370  9716.0
# 371  9716.0
# 372  9716.0
# 373  9716.0
# 374  9716.0
# 375  9716.0
# 376  9716.0
# 377  9716.0
# 378  9716.0
# 379  9716.0
# 380  9716.0
# 381     NaN
# 382  9716.0
# 383  9716.0
# 384  9716.0
# 385  9716.0
# 386  9716.0
# 387  9716.0
# 388  9716.0
# 389  9716.0
# 390  9716.0
# 391  9716.0
# 392  9716.0
# 393  9716.0
# 394  9716.0
# 395  9716.0
# 396  9716.0
# 397  9716.0
# 398  9716.0
# 399  9716.0
#
# [400 rows x 26 columns]

# %% [markdown]
# #### Advanced Manipulation in Pandas - Merge/Join/Concatenate:
#
# __Overview:__
# - Merging, Joining, and Conatenating using Pandas Dataframes are very useful, however, advanced for the beginner programmer
# - However, the does not mean we can't explore the basics of what merging, joining, and concatenating is and how we can do it in Pandas
# - The full documentation for Merge, Join, and Concatenate can be found [here](http://pandas.pydata.org/pandas-docs/stable/merging.html)
# - All 3 methods below, in their own way, describe the act of combining together Series and DataFrame objects with some logic to handle the indexes of the objects you are combining:
# > 1. __Concatenating Objects:__ Concatenating objects in Pandas is done using the `concat` or the `append` function and you can think of this as "gluing together" multiple DataFrames or Series
# > 2. __Merging Objects:__ Merging objects in Pandas is done using the `merge` function and replicates [SQL Joins](https://en.wikipedia.org/wiki/Join_(SQL))
# > 3. __Joining Objects:__ Joining objects in Pandas is done using the `join` function and can be used for combining the columns of two potentially differently-indexed DataFrames into a single result DataFrame
#
# __Helpful Points:__
# 1. We actually have already concatenated DataFrames above when we added a new row to an existing DataFrame
# 2. Remember that indexes are very important to DataFrames and most of the "logic" that these methods employ revolve around what to do with DataFrames/Series that have different indexes
# 3. SQL and Databases is definitely not required knowledge for this course, but further reading on Data Models (for your interest only) can be found [here](https://en.wikipedia.org/wiki/One-to-one_(data_model)) for __One-to-One Relationships__ and [here](https://en.wikipedia.org/wiki/Many-to-many_(data_model)) for __Many-to-Many Relationships__
#
# __Practice:__ Examples of Advanced Manipulation of Pandas - Merge/Join/Concatenate in Python
# ### Concatenating Objects:

# %%
# initialize 3 data frames to concatenate with same column names and index labels 
df1 = pd.DataFrame({'A': ['A0', 'A1'],
                    'B': ['B0', 'B1']},
                     index=[0, 1])
 
df2 = pd.DataFrame({'A': ['A2', 'A3'],
                    'B': ['B2', 'B3']},
                     index=[2, 3])

df3 = pd.DataFrame({'B': ['B2', 'B7'],
                    'F': ['F2', 'F3']},
                     index=[1, 5])

# %%
print(df1)
print()
print(df2)
print()
print(df3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-92fdff65b36e> in <module>()
# ----> 1 print(df1)
#       2 print()
#       3 print(df2)
#       4 print()
#       5 print(df3)
#
# NameError: name 'df1' is not defined

# %% [markdown]
# ### Concatenating 2 DataFrames with Same Indexes:

# %%
### (Using Concat):
# by defualt, stacking row-wise
result = pd.concat([df1, df2]) # concatenate one dataframe on another along rows 
result
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
# to stack them by column
## problems: indexes are reserved; column names are duplicated 
pd.concat([df1, df2], axis = 1)
# Out:
#      A    B    A    B
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2  NaN  NaN   A2   B2
# 3  NaN  NaN   A3   B3

# %%
### (Using Append):

a_result = df1.append(df2)
a_result
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %% [markdown]
# ### Concatenating 2 DataFrames with Different Indexes:

# %%
# option 1 (finds unique columns, duplicates rows)
result = pd.concat([df1, df3], axis = 0) # concatenate one dataframe on another along rows
result
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#      A   B    F
# 0   A0  B0  NaN
# 1   A1  B1  NaN
# 1  NaN  B2   F2
# 5  NaN  B7   F3

# %%
# option 2 (finds unique rows, duplicates columns)
result_1 = pd.concat([df1, df3], axis = 1) # concatenate one dataframe on another along columns
result_1
# Out:
#      A    B    B    F
# 0   A0   B0  NaN  NaN
# 1   A1   B1   B2   F2
# 5  NaN  NaN   B7   F3

# %%
# option 3 (uses only index from df1)
result_2 = pd.concat([df1, df3], axis = 1, join_axes=[df1.index]) # concatenate one dataframe on another along columns
result_2
# Out:
#     A   B    B    F
# 0  A0  B0  NaN  NaN
# 1  A1  B1   B2   F2

# %%
# option 4 (ignores and resets index)
result_3 = pd.concat([df1, df3], ignore_index = True) # same as option 1 but with reset index 
result_3
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#      A   B    F
# 0   A0  B0  NaN
# 1   A1  B1  NaN
# 2  NaN  B2   F2
# 3  NaN  B7   F3

# %% [markdown]
# ### Merging Objects:

# %%
raw_data_1 = {
        'department_id': ['1', '2', '3'],
        'first_name': ['Sergey', 'John', 'Sean'], 
        'last_name': ['Fogelson', 'Smith', 'Reagin']}
df_a = pd.DataFrame(raw_data_1, columns = ['department_id', 'first_name', 'last_name'])

raw_data_2 = {
        'department_id': ['2', '3', '4'],
        'first_name': ['Kayla', 'Zach', 'Lawrence'], 
        'last_name': ['Day', 'Smola', 'Sloan']}
df_b = pd.DataFrame(raw_data_2, columns = ['department_id', 'first_name', 'last_name'])

raw_data_3 = {
        'department_id': ['1', '2', '3', '4'],
        'manager_id': ['12', '24', '13', '4']}
df_c = pd.DataFrame(raw_data_3, columns = ['department_id', 'manager_id'])

# %%
print(df_a)
print()
print(df_b)
print()
print(df_c)
# Out:
#   department_id first_name last_name
# 0             1     Sergey  Fogelson
# 1             2       John     Smith
# 2             3       Sean    Reagin
#
#   department_id first_name last_name
# 0             2      Kayla       Day
# 1             3       Zach     Smola
# 2             4   Lawrence     Sloan
#
#   department_id manager_id
# 0             1         12
# 1             2         24
# 2             3         13
# 3             4          4

# %% [markdown]
# ### Merge DataFrames - Method 1:

# %%
# "merge" by default: inner_join 
df_a.merge(df_c, # df_a is the left df
          on = "department_id",
          how = "outer") # other option: left_join
# Out:
#   department_id first_name last_name manager_id
# 0             1     Sergey  Fogelson         12
# 1             2       John     Smith         24
# 2             3       Sean    Reagin         13
# 3             4        NaN       NaN          4

# %%
# when the column names are not the same in two dfs
df_a.merge(df_c, # df_a is the left df
          on = "department_id",
          how = "left",
          #left_on = "customer_id", 
          #right_on = "cust_in",
          left_index = True) # using the left index

# %%
pd.merge(pd.concat([df_a, df_b]), df_c, 
         on = "department_id") # concatenate 2 employee df and then merge with department info df
# Out:
#   department_id first_name last_name manager_id
# 0             1     Sergey  Fogelson         12
# 1             2       John     Smith         24
# 2             2      Kayla       Day         24
# 3             3       Sean    Reagin         13
# 4             3       Zach     Smola         13
# 5             4   Lawrence     Sloan          4

# %%
# this merely stacks the two df's
pd.concat([df_a, df_b])
# Out:
#   department_id first_name last_name
# 0             1     Sergey  Fogelson
# 1             2       John     Smith
# 2             3       Sean    Reagin
# 0             2      Kayla       Day
# 1             3       Zach     Smola
# 2             4   Lawrence     Sloan

# %%
pd.merge(pd.concat([df_a, df_b]), df_c, 
         left_on = "department_id", 
         right_on = "department_id") # same as above
# Out:
#   department_id first_name last_name manager_id
# 0             1     Sergey  Fogelson         12
# 1             2       John     Smith         24
# 2             2      Kayla       Day         24
# 3             3       Sean    Reagin         13
# 4             3       Zach     Smola         13
# 5             4   Lawrence     Sloan          4

# %% [markdown]
# ### Merge DataFrames - Method 2:

# %%
pd.merge(df_a, df_b, right_index = True, left_index = True) # merge based on indexes
# Out:
#   department_id_x first_name_x last_name_x department_id_y first_name_y  \
# 0               1       Sergey    Fogelson               2        Kayla
# 1               2         John       Smith               3         Zach
# 2               3         Sean      Reagin               4     Lawrence
#
#   last_name_y
# 0         Day
# 1       Smola
# 2       Sloan

# %% [markdown]
# ### Merge DataFrames - Method 3:
#
# __[Outer Join](https://blog.codinghorror.com/a-visual-explanation-of-sql-joins/):__ “Full outer join produces the set of all records in Table A and Table B, with matching records from both sides where available. If there is no match, the missing side will contain null.”

# %%
pd.merge(df_a, df_b, on='department_id', how='outer')
# Out:
#   department_id first_name_x last_name_x first_name_y last_name_y
# 0             1       Sergey    Fogelson          NaN         NaN
# 1             2         John       Smith        Kayla         Day
# 2             3         Sean      Reagin         Zach       Smola
# 3             4          NaN         NaN     Lawrence       Sloan

# %% [markdown]
# ### Merge DataFrames - Method 4:
#
# __[Inner Join](https://blog.codinghorror.com/a-visual-explanation-of-sql-joins/):__ “Inner join produces only the set of records that match in both Table A and Table B.”

# %%
pd.merge(df_a, df_b, on='department_id', how='inner')
# Out:
#   department_id first_name_x last_name_x first_name_y last_name_y
# 0             2         John       Smith        Kayla         Day
# 1             3         Sean      Reagin         Zach       Smola

# %% [markdown]
# ### Merge DataFrames - Method 5:
#
# __[Left Join](https://blog.codinghorror.com/a-visual-explanation-of-sql-joins/):__ "Left outer join produces a complete set of records from Table A, with the matching records (where available) in Table B. If there is no match, the right side will contain null.”

# %%
pd.merge(df_a, df_b, on='department_id', how='left')
# Out:
#   department_id first_name_x last_name_x first_name_y last_name_y
# 0             1       Sergey    Fogelson          NaN         NaN
# 1             2         John       Smith        Kayla         Day
# 2             3         Sean      Reagin         Zach       Smola

# %% [markdown]
# ### Merge DataFrames - Method 6:
#
# __[Right Join](https://en.wikipedia.org/wiki/Relational_algebra#Right_outer_join_(%E2%9F%96):__ "Right outer join produces a complete set of records from Table B, with the matching records (where available) in Table A. If there is no match, the right side will contain null.”

# %%
pd.merge(df_a, df_b, on='department_id', how='right')
# Out:
#   department_id first_name_x last_name_x first_name_y last_name_y
# 0             2         John       Smith        Kayla         Day
# 1             3         Sean      Reagin         Zach       Smola
# 2             4          NaN         NaN     Lawrence       Sloan

# %% [markdown]
# ### Handling Categorical Features
#
# ML algorithms expect all features to be numeric. So how do we include categorical columns (features) in our model? Before we decide how to encode categorical features, we need to understand the kind of categorical features we have:
#
# - **Ordered categories:** transform them to sensible numeric values (example: small=1, medium=2, large=3)
# - **Unordered categories:** use dummy encoding
#
# We will look at one case of unordered categorical columns here:
# - **unordered categories with more than 2 levels**
#
# These are the kinds of categories that exist in the dataset we started working with during this class.
#
# How do we include an unordered categorical feature with more than two levels, like **DGN**? We can't simply encode it as DGN1=1, DGN2=2, DGN3=3, etc. because that would imply an **ordered relationship** in which DGN2 is somehow "double" DGN1 and DGN3 is somehow "triple" DGN1.
#
# Instead, we create **additional dummy variables** and append them to the original dataset:

# %%
# dummy coding 
## 
rbc_dummies = pd.get_dummies(my_df.rbc).astype(int) # astype can be specified as "bool"
rbc_dummies
# Out:
#      abnormal  normal
# 0           0       0
# 1           0       0
# 2           0       1
# 3           0       1
# 4           0       1
# 5           0       0
# 6           0       0
# 7           0       1
# 8           0       1
# 9           1       0
# 10          0       0
# 11          1       0
# 12          0       0
# 13          0       0
# 14          0       1
# 15          0       0
# 16          0       0
# 17          0       0
# 18          0       0
# 19          0       0
# 20          1       0
# 21          0       0
# 22          0       1
# 23          0       0
# 24          0       1
# 25          0       0
# 26          0       0
# 27          0       1
# 28          0       0
# 29          1       0
# ..        ...     ...
# 370         0       1
# 371         0       1
# 372         0       1
# 373         0       1
# 374         0       1
# 375         0       1
# 376         0       1
# 377         0       1
# 378         0       1
# 379         0       1
# 380         0       1
# 381         0       0
# 382         0       1
# 383         0       1
# 384         0       1
# 385         0       1
# 386         0       1
# 387         0       1
# 388         0       1
# 389         0       1
# 390         0       1
# 391         0       1
# 392         0       1
# 393         0       1
# 394         0       1
# 395         0       1
# 396         0       1
# 397         0       1
# 398         0       1
# 399         0       1
#
# [400 rows x 2 columns]

# %% [markdown]
# However, we actually only need **one dummy variable, not two**. Why? Because one dummy capture all of the "information" about the **rbc** feature, and implicitly defines the final one as the **baseline level** (0 for the other rbc value):

# %%
rbc_dummies = pd.get_dummies(my_df.rbc,
                             drop_first=True).astype(int) # binary coding
rbc_dummies
# Out:
#      normal
# 0         0
# 1         0
# 2         1
# 3         1
# 4         1
# 5         0
# 6         0
# 7         1
# 8         1
# 9         0
# 10        0
# 11        0
# 12        0
# 13        0
# 14        1
# 15        0
# 16        0
# 17        0
# 18        0
# 19        0
# 20        0
# 21        0
# 22        1
# 23        0
# 24        1
# 25        0
# 26        0
# 27        1
# 28        0
# 29        0
# ..      ...
# 370       1
# 371       1
# 372       1
# 373       1
# 374       1
# 375       1
# 376       1
# 377       1
# 378       1
# 379       1
# 380       1
# 381       0
# 382       1
# 383       1
# 384       1
# 385       1
# 386       1
# 387       1
# 388       1
# 389       1
# 390       1
# 391       1
# 392       1
# 393       1
# 394       1
# 395       1
# 396       1
# 397       1
# 398       1
# 399       1
#
# [400 rows x 1 columns]

# %% [markdown]
# In general, if you have a categorical feature with **k levels** (k distinct values that it takes on), you create **k-1 dummy variables**.
#
# Let's reappend these features to the original dataset and drop the original `rbc` column:

# %%
my_df.head()
# Out:
#     age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr   ...        wc   rc  htn   dm  cad  appet   pe  ane class age_SUM
# 0  121.0   ...    7800.0  5.2  yes  yes   no   good   no   no   ckd     NaN
# 1    NaN   ...    6000.0  NaN   no   no   no   good   no   no   ckd     NaN
# 2  423.0   ...    7500.0  NaN   no  yes   no   poor   no  yes   ckd  9716.0
# 3  117.0   ...    6700.0  3.9  yes   no   no   poor  yes  yes   ckd  9716.0
# 4  106.0   ...    7300.0  4.6   no   no   no   good   no   no   ckd  9716.0
#
# [5 rows x 26 columns]

# %%
my_df_categorical_encoding = pd.concat((my_df.iloc[:,~my_df.columns.isin(["rbc"])],rbc_dummies),axis=1)
my_df_categorical_encoding
# Out:
#       age     bp     sg   al   su        pc         pcc          ba    bgr  \
# 0    48.0   80.0  1.020  1.0  0.0    normal  notpresent  notpresent  121.0
# 1     7.0   50.0  1.020  4.0  0.0    normal  notpresent  notpresent    NaN
# 2    62.0   80.0  1.010  2.0  3.0    normal  notpresent  notpresent  423.0
# 3    48.0   70.0  1.005  4.0  0.0  abnormal     present  notpresent  117.0
# 4    51.0   80.0  1.010  2.0  0.0    normal  notpresent  notpresent  106.0
# 5    60.0   90.0  1.015  3.0  0.0       NaN  notpresent  notpresent   74.0
# 6    68.0   70.0  1.010  0.0  0.0    normal  notpresent  notpresent  100.0
# 7    24.0    NaN  1.015  2.0  4.0  abnormal  notpresent  notpresent  410.0
# 8    52.0  100.0  1.015  3.0  0.0  abnormal     present  notpresent  138.0
# 9    53.0   90.0  1.020  2.0  0.0  abnormal     present  notpresent   70.0
# 10   50.0   60.0  1.010  2.0  4.0  abnormal     present  notpresent  490.0
# 11   63.0   70.0  1.010  3.0  0.0  abnormal     present  notpresent  380.0
# 12   68.0   70.0  1.015  3.0  1.0    normal     present  notpresent  208.0
# 13   68.0   70.0    NaN  NaN  NaN       NaN  notpresent  notpresent   98.0
# 14   68.0   80.0  1.010  3.0  2.0  abnormal     present     present  157.0
# 15   40.0   80.0  1.015  3.0  0.0    normal  notpresent  notpresent   76.0
# 16   47.0   70.0  1.015  2.0  0.0    normal  notpresent  notpresent   99.0
# 17   47.0   80.0    NaN  NaN  NaN       NaN  notpresent  notpresent  114.0
# 18   60.0  100.0  1.025  0.0  3.0    normal  notpresent  notpresent  263.0
# 19   62.0   60.0  1.015  1.0  0.0  abnormal     present  notpresent  100.0
# 20   61.0   80.0  1.015  2.0  0.0  abnormal  notpresent  notpresent  173.0
# 21   60.0   90.0    NaN  NaN  NaN       NaN  notpresent  notpresent    NaN
# 22   48.0   80.0  1.025  4.0  0.0  abnormal  notpresent  notpresent   95.0
# 23   21.0   70.0  1.010  0.0  0.0    normal  notpresent  notpresent    NaN
# 24   42.0  100.0  1.015  4.0  0.0  abnormal  notpresent     present    NaN
# 25   61.0   60.0  1.025  0.0  0.0    normal  notpresent  notpresent  108.0
# 26   75.0   80.0  1.015  0.0  0.0    normal  notpresent  notpresent  156.0
# 27   69.0   70.0  1.010  3.0  4.0  abnormal  notpresent  notpresent  264.0
# 28   75.0   70.0    NaN  1.0  3.0       NaN  notpresent  notpresent  123.0
# 29   68.0   70.0  1.005  1.0  0.0  abnormal     present  notpresent    NaN
# ..    ...    ...    ...  ...  ...       ...         ...         ...    ...
# 370  69.0   70.0  1.020  0.0  0.0    normal  notpresent  notpresent   83.0
# 371  28.0   60.0  1.025  0.0  0.0    normal  notpresent  notpresent   79.0
# 372  72.0   60.0  1.020  0.0  0.0    normal  notpresent  notpresent  109.0
# 373  61.0   70.0  1.025  0.0  0.0    normal  notpresent  notpresent  133.0
# 374  79.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent  111.0
# 375  70.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent   74.0
# 376  58.0   70.0  1.025  0.0  0.0    normal  notpresent  notpresent   88.0
# 377  64.0   70.0  1.020  0.0  0.0    normal  notpresent  notpresent   97.0
# 378  71.0   60.0  1.025  0.0  0.0    normal  notpresent  notpresent    NaN
# 379  62.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent   78.0
# 380  59.0   60.0  1.020  0.0  0.0    normal  notpresent  notpresent  113.0
# 381  71.0   70.0  1.025  0.0  0.0       NaN  notpresent  notpresent   79.0
# 382  48.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent   75.0
# 383  80.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent  119.0
# 384  57.0   60.0  1.020  0.0  0.0    normal  notpresent  notpresent  132.0
# 385  63.0   70.0  1.020  0.0  0.0    normal  notpresent  notpresent  113.0
# 386  46.0   70.0  1.025  0.0  0.0    normal  notpresent  notpresent  100.0
# 387  15.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent   93.0
# 388  51.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent   94.0
# 389  41.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent  112.0
# 390  52.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent   99.0
# 391  36.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent   85.0
# 392  57.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent  133.0
# 393  43.0   60.0  1.025  0.0  0.0    normal  notpresent  notpresent  117.0
# 394  50.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent  137.0
# 395  55.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent  140.0
# 396  42.0   70.0  1.025  0.0  0.0    normal  notpresent  notpresent   75.0
# 397  12.0   80.0  1.020  0.0  0.0    normal  notpresent  notpresent  100.0
# 398  17.0   60.0  1.025  0.0  0.0    normal  notpresent  notpresent  114.0
# 399  58.0   80.0  1.025  0.0  0.0    normal  notpresent  notpresent  131.0
#
#         bu  ...     rc  htn   dm  cad  appet   pe  ane   class age_SUM normal
# 0     36.0  ...    5.2  yes  yes   no   good   no   no     ckd     NaN      0
# 1     18.0  ...    NaN   no   no   no   good   no   no     ckd     NaN      0
# 2     53.0  ...    NaN   no  yes   no   poor   no  yes     ckd  9716.0      1
# 3     56.0  ...    3.9  yes   no   no   poor  yes  yes     ckd  9716.0      1
# 4     26.0  ...    4.6   no   no   no   good   no   no     ckd  9716.0      1
# 5     25.0  ...    4.4  yes  yes   no   good  yes   no     ckd     NaN      0
# 6     54.0  ...    NaN   no   no   no   good   no   no     ckd     NaN      0
# 7     31.0  ...    5.0   no  yes   no   good  yes   no     ckd  9716.0      1
# 8     60.0  ...    4.0  yes  yes   no   good   no  yes     ckd  9716.0      1
# 9    107.0  ...    3.7  yes  yes   no   poor   no  yes     ckd  2291.0      0
# 10    55.0  ...    NaN  yes  yes   no   good   no  yes     ckd     NaN      0
# 11    60.0  ...    3.8  yes  yes   no   poor  yes   no     ckd  2291.0      0
# 12    72.0  ...    3.4  yes  yes  yes   poor  yes   no     ckd     NaN      0
# 13    86.0  ...    NaN  yes  yes  yes   poor  yes   no     ckd     NaN      0
# 14    90.0  ...    2.6  yes  yes  yes   poor  yes   no     ckd  9716.0      1
# 15   162.0  ...    2.8  yes   no   no   good   no  yes     ckd     NaN      0
# 16    46.0  ...    NaN   no   no   no   good   no   no     ckd     NaN      0
# 17    87.0  ...    NaN  yes   no   no   poor   no   no     ckd     NaN      0
# 18    27.0  ...    4.3  yes  yes  yes   good   no   no     ckd     NaN      0
# 19    31.0  ...    3.7  yes   no  yes   good   no   no     ckd     NaN      0
# 20   148.0  ...    3.2  yes  yes  yes   poor  yes  yes     ckd  2291.0      0
# 21   180.0  ...    3.6  yes  yes  yes   good   no   no     ckd     NaN      0
# 22   163.0  ...    3.4  yes   no   no   good   no  yes     ckd  9716.0      1
# 23     NaN  ...    NaN   no   no   no   poor   no  yes     ckd     NaN      0
# 24    50.0  ...    4.6  yes   no   no   poor   no   no     ckd  9716.0      1
# 25    75.0  ...    3.7  yes  yes   no   good   no  yes     ckd     NaN      0
# 26    45.0  ...    4.0  yes  yes   no   poor   no   no     ckd     NaN      0
# 27    87.0  ...    4.1  yes  yes  yes   good  yes   no     ckd  9716.0      1
# 28    31.0  ...    NaN   no  yes   no   good   no   no     ckd     NaN      0
# 29    28.0  ...    NaN   no   no  yes   good   no   no     ckd  2291.0      0
# ..     ...  ...    ...  ...  ...  ...    ...  ...  ...     ...     ...    ...
# 370   42.0  ...    5.4   no   no   no   good   no   no  notckd  9716.0      1
# 371   50.0  ...    5.0   no   no   no   good   no   no  notckd  9716.0      1
# 372   26.0  ...    5.5   no   no   no   good   no   no  notckd  9716.0      1
# 373   38.0  ...    4.9   no   no   no   good   no   no  notckd  9716.0      1
# 374   44.0  ...    6.4   no   no   no   good   no   no  notckd  9716.0      1
# 375   41.0  ...    5.6   no   no   no   good   no   no  notckd  9716.0      1
# 376   16.0  ...    5.2   no   no   no   good   no   no  notckd  9716.0      1
# 377   27.0  ...    4.8   no   no   no   good   no   no  notckd  9716.0      1
# 378    NaN  ...    5.5   no   no   no   good   no   no  notckd  9716.0      1
# 379   45.0  ...    5.7   no   no   no   good   no   no  notckd  9716.0      1
# 380   23.0  ...    4.9   no   no   no   good   no   no  notckd  9716.0      1
# 381   47.0  ...    5.9   no   no   no   good   no   no  notckd     NaN      0
# 382   22.0  ...    6.5   no   no   no   good   no   no  notckd  9716.0      1
# 383   46.0  ...    5.0   no   no   no   good   no   no  notckd  9716.0      1
# 384   18.0  ...    4.5   no   no   no   good   no   no  notckd  9716.0      1
# 385   25.0  ...    5.1   no   no   no   good   no   no  notckd  9716.0      1
# 386   47.0  ...    6.5   no   no   no   good   no   no  notckd  9716.0      1
# 387   17.0  ...    5.2   no   no   no   good   no   no  notckd  9716.0      1
# 388   15.0  ...    6.4   no   no   no   good   no   no  notckd  9716.0      1
# 389   48.0  ...    5.8   no   no   no   good   no   no  notckd  9716.0      1
# 390   25.0  ...    5.3   no   no   no   good   no   no  notckd  9716.0      1
# 391   16.0  ...    6.3   no   no   no   good   no   no  notckd  9716.0      1
# 392   48.0  ...    5.5   no   no   no   good   no   no  notckd  9716.0      1
# 393   45.0  ...    5.4   no   no   no   good   no   no  notckd  9716.0      1
# 394   46.0  ...    4.6   no   no   no   good   no   no  notckd  9716.0      1
# 395   49.0  ...    4.9   no   no   no   good   no   no  notckd  9716.0      1
# 396   31.0  ...    6.2   no   no   no   good   no   no  notckd  9716.0      1
# 397   26.0  ...    5.4   no   no   no   good   no   no  notckd  9716.0      1
# 398   50.0  ...    5.9   no   no   no   good   no   no  notckd  9716.0      1
# 399   18.0  ...    6.1   no   no   no   good   no   no  notckd  9716.0      1
#
# [400 rows x 26 columns]

# %% [markdown]
# Keep in mind, you want to do this for every single categorical column before you can actually train a machine learning algorithm to this dataset.

# %% [markdown]
# ### Handling Missing Values:
# __Overview:__
# - In Data Science, when working with real-world data, it is very common to encounter missing data that may be a result of data not available, data not recorded, or data not present for some other reason.
# - You should be aware of the possibile options that Pandas provides for storing missing data, finding missing data, inserting missing data, and cleaning/filling missing data which can be read about in detail [here](http://pandas.pydata.org/pandas-docs/stable/missing_data.html) and explained below:
#
# > 1. __Storing Missing Data:__ The value `NaN` is the default missing value marker, but sometimes `None` is used as well
# > 2. __Finding Missing Data:__ Pandas offers many convenient functions for testing if values are missing such as: `df.isna()`, `df.notna()`, `df.isnull()`, `df.notnull()` which all return a boolean same-sized object indicating if the values are missing. It is also possible to use these functions to count the number of missing values (i.e. `np.count_nonzero(df.isnull())`, `np.count_nonzero(np.any(df.isnull(), axis=)`)
# > 3. __Cleaning/Filling Missing Data:__ Pandas offers many convenient functions for filling missing values such as: `df.fillna(value)` and `df.dropna(axis)`
#
# __Helpful Points:__
# 1. Note two `NaN` values do not compare (i.e. `np.nan == np.nan` is evaluated as `False`)
#
# __Practice:__ Examples of Operations to Handle Missing Data in Pandas Data Structures in Python

# %%
na_df = df = pd.DataFrame(np.random.random(15).reshape(5, 3), index=['a', 'c', 'e', 'f', 'h'],
                          columns=['one', 'two', 'three'])
na_df = na_df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
na_df
# Out:
#         one       two     three
# a  0.974880  0.838568  0.246047
# b       NaN       NaN       NaN
# c  0.875164  0.896370  0.514346
# d       NaN       NaN       NaN
# e  0.052383  0.672401  0.256049
# f  0.801195  0.757267  0.281445
# g       NaN       NaN       NaN
# h  0.525561  0.160615  0.228707

# %%
### Finding Missing Data - Method 1:
# "isna"
na_df.isna() # check elements that are missing 
na_df.isna().sum() # colsums of the # of NA's
na_df.isna().sum() / na_df.shape[0] # dividng the number of NA's by the number of rows = overall NA's
# Out:
#      one    two  three
# a  False  False  False
# b   True   True   True
# c  False  False  False
# d   True   True   True
# e  False  False  False
# f  False  False  False
# g   True   True   True
# h  False  False  False

# %%
na_df.notna() # check elements that are not missing
# Out:
#      one    two  three
# a   True   True   True
# b  False  False  False
# c   True   True   True
# d  False  False  False
# e   True   True   True
# f   True   True   True
# g  False  False  False
# h   True   True   True

# %% [markdown]
# Now let's look at which cells have `NaN`'s in them by calling `isnull()` on the `kidney_data` `DataFrame`:

# %%
na_df.isnull().head()
# Out:
#      one    two  three
# a  False  False  False
# b   True   True   True
# c  False  False  False
# d   True   True   True
# e  False  False  False

# %% [markdown]
# Let's check the total number of rows missing values per column:

# %%
# check for number of missing values per column
na_df.isnull().sum()
# Out:
# one      3
# two      3
# three    3
# dtype: int64

# %% [markdown]
# For numerical columns, there are 3 common strategies for filling in missing values:
#
# 1. Fill in using the mean
# 2. Fill in using the median (when many outliers are present)
# 3. Fill in with some default value (e.g. 0).
#
# Let's do each in turn:

# %%
mean_per_column = na_df.apply(lambda x: x.mean(),axis=0)
mean_per_column
# Out:
# one      0.645837
# two      0.665044
# three    0.305319
# dtype: float64

# %%
# ".fillna" 
numeric_mean_filled = na_df.fillna(mean_per_column,axis=0)
numeric_mean_filled
# Out:
#         one       two     three
# a  0.974880  0.838568  0.246047
# b  0.645837  0.665044  0.305319
# c  0.875164  0.896370  0.514346
# d  0.645837  0.665044  0.305319
# e  0.052383  0.672401  0.256049
# f  0.801195  0.757267  0.281445
# g  0.645837  0.665044  0.305319
# h  0.525561  0.160615  0.228707

# %%
median_per_column = na_df.apply(lambda x: x.median(),axis=0)
median_per_column
# Out:
# one      0.801195
# two      0.757267
# three    0.256049
# dtype: float64

# %%
numeric_median_filled = na_df.fillna(median_per_column,axis=0)
numeric_median_filled
# Out:
#         one       two     three
# a  0.974880  0.838568  0.246047
# b  0.801195  0.757267  0.256049
# c  0.875164  0.896370  0.514346
# d  0.801195  0.757267  0.256049
# e  0.052383  0.672401  0.256049
# f  0.801195  0.757267  0.281445
# g  0.801195  0.757267  0.256049
# h  0.525561  0.160615  0.228707

# %%
default_value_per_column = na_df.fillna(0.0)
default_value_per_column.head()
# Out:
#         one       two     three
# a  0.974880  0.838568  0.246047
# b  0.000000  0.000000  0.000000
# c  0.875164  0.896370  0.514346
# d  0.000000  0.000000  0.000000
# e  0.052383  0.672401  0.256049

# %% [markdown]
# Now let's look at which cells have `NaN`'s in them for our kidney dataset by calling `isnull()` on the `kidney_data` `DataFrame`:

# %%
my_df.isnull().head()
# Out:
#      age     bp     sg     al     su    rbc     pc    pcc     ba    bgr  \
# 0  False  False  False  False  False   True  False  False  False  False
# 1  False  False  False  False  False   True  False  False  False   True
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False  False  False
# 4  False  False  False  False  False  False  False  False  False  False
#
#     ...        wc     rc    htn     dm    cad  appet     pe    ane  class  \
# 0   ...     False  False  False  False  False  False  False  False  False
# 1   ...     False   True  False  False  False  False  False  False  False
# 2   ...     False   True  False  False  False  False  False  False  False
# 3   ...     False  False  False  False  False  False  False  False  False
# 4   ...     False  False  False  False  False  False  False  False  False
#
#    age_SUM
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
#
# [5 rows x 26 columns]

# %% [markdown]
# Let's check the total number of rows missing values per column:

# %%
# check for number of missing values per column
my_df.isnull().sum()
# Out:
# age          9
# bp          12
# sg          47
# al          46
# su          49
# rbc        152
# pc          65
# pcc          4
# ba           4
# bgr         44
# bu          19
# sc          17
# sod         87
# pot         88
# hemo        52
# pcv         71
# wc         106
# rc         131
# htn          2
# dm           2
# cad          2
# appet        1
# pe           1
# ane          1
# class        0
# age_SUM    152
# dtype: int64

# %% [markdown]
# Let's rearrange the numeric and categorical columns for easier access later, and lets remove the response column (`class`) into a separate `Series`:

# %%
print("column names before rearranging:\n",kidney_columns)
kidney_columns = kidney_columns[:5] + kidney_columns[9:18] + kidney_columns[5:9] + kidney_columns[18:]

print("column names after rearranging:\n", kidney_columns)
# Out:
# column names before rearranging:
#  ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'class']
# column names after rearranging:
#  ['age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'class']

# %%
my_df = my_df.iloc[:,:-1] # drop the random column we made at the end earlier
my_df = my_df[kidney_columns]

# %%
target = my_df["class"]
print(my_df.dtypes)
my_df.head()
# Out:
# age      float64
# bp       float64
# sg       float64
# al       float64
# su       float64
# bgr      float64
# bu       float64
# sc       float64
# sod      float64
# pot      float64
# hemo     float64
# pcv      float64
# wc       float64
# rc       float64
# rbc       object
# pc        object
# pcc       object
# ba        object
# htn       object
# dm        object
# cad       object
# appet     object
# pe        object
# ane       object
# class     object
# dtype: object
#     age    bp     sg   al   su    bgr    bu   sc    sod  pot  ...         pc  \
# 0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2    NaN  NaN  ...     normal
# 1   7.0  50.0  1.020  4.0  0.0    NaN  18.0  0.8    NaN  NaN  ...     normal
# 2  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8    NaN  NaN  ...     normal
# 3  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  ...   abnormal
# 4  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4    NaN  NaN  ...     normal
#
#           pcc          ba  htn   dm cad appet   pe  ane class
# 0  notpresent  notpresent  yes  yes  no  good   no   no   ckd
# 1  notpresent  notpresent   no   no  no  good   no   no   ckd
# 2  notpresent  notpresent   no  yes  no  poor   no  yes   ckd
# 3     present  notpresent  yes   no  no  poor  yes  yes   ckd
# 4  notpresent  notpresent   no   no  no  good   no   no   ckd
#
# [5 rows x 25 columns]

# %% [markdown]
# Ok, now that our data is arranged in a way that's amenable with dealing with the numeric and the categorical columns separately, let's work through the ways in which we can handle null values.
#
# The first thing we can do, is simply throw out any samples that have nulls in any column:

# %%
my_df_nonnull = my_df.dropna()
print("Fraction of data kept:\n", float(my_df_nonnull.shape[0]) / my_df.shape[0])
# Out:
# Fraction of data kept:
#  0.395

# %% [markdown]
# So throwing out ~60% of the data is no bueno. What else can we do?
#
# We can **impute** (fill in) the data on a per-column basis. The imputation strategy for categorical columns is usually one of the following:
#   1. fill in with the most common categorical value
#   2. fill in with a special "missing" category
#
# Let's do each in turn.
#
# Here's how we would do **1.**
#
# We are going to get the most common category per column, and store it in a `Series` first, then we will apply it per-column to those columns:

# %%
# value counts
## ordered by the most frequent to least 
my_df.rbc.value_counts()

my_df.rbc.value_counts().head(1).index[0] # extracting the name of the most frequent category
# Out:
# normal      201
# abnormal     47
# Name: rbc, dtype: int64

# %%
# function to return the most frequent value in a pandas Series
def get_most_frequent_value(my_column):
    return my_column.value_counts().index[0]

# apply the function
most_frequent_values_per_column = my_df[kidney_columns[14:-1]].apply(get_most_frequent_value, 
                                                                     axis = 0)
print("Most frequent value in each column:\n",most_frequent_values_per_column)
# Out:
# Most frequent value in each column:
#  hemo       15
# pcv        52
# wc       9800
# rc        5.2
# htn        no
# dm         no
# cad        no
# appet    good
# pe         no
# ane        no
# dtype: object

# %%
categorical_most_frequent = my_df[kidney_columns[14:-1]].fillna(most_frequent_values_per_column,axis=0)
categorical_most_frequent.head()
# Out:
#    hemo   pcv      wc   rc  htn   dm cad appet   pe  ane
# 0  15.4  44.0  7800.0  5.2  yes  yes  no  good   no   no
# 1  11.3  38.0  6000.0  5.2   no   no  no  good   no   no
# 2   9.6  31.0  7500.0  5.2   no  yes  no  poor   no  yes
# 3  11.2  32.0  6700.0  3.9  yes   no  no  poor  yes  yes
# 4  11.6  35.0  7300.0  4.6   no   no  no  good   no   no

# %% [markdown]
# Now let's do **2.** (Which is much easier):

# %%
special_missing_category = my_df[kidney_columns[14:-1]].fillna("missing")
special_missing_category.head()
# Out:
#    hemo pcv    wc       rc  htn   dm cad appet   pe  ane
# 0  15.4  44  7800      5.2  yes  yes  no  good   no   no
# 1  11.3  38  6000  missing   no   no  no  good   no   no
# 2   9.6  31  7500  missing   no  yes  no  poor   no  yes
# 3  11.2  32  6700      3.9  yes   no  no  poor  yes  yes
# 4  11.6  35  7300      4.6   no   no  no  good   no   no

# %% [markdown]
# For numerical columns, there are 3 common strategies for filling in missing values:
#
# 1. Fill in using the mean
# 2. Fill in using the median (when many outliers are present)
# 3. Fill in with some default value (e.g. 0).
#
# Let's do each in turn:

# %%
#1.
print("Lots of missing data here:\n",my_df[kidney_columns[:14]].head())
mean_per_column = my_df[kidney_columns[:14]].apply(lambda x: x.mean(),axis = 0)
print("Mean value per column:\n", mean_per_column)
# Out:
# Lots of missing data here:
#      age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr    bu   sc    sod  pot
# 0  121.0  36.0  1.2    NaN  NaN
# 1    NaN  18.0  0.8    NaN  NaN
# 2  423.0  53.0  1.8    NaN  NaN
# 3  117.0  56.0  3.8  111.0  2.5
# 4  106.0  26.0  1.4    NaN  NaN
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     354     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 355     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     356
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims)
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-26fa79cff106> in <module>()
#       1 #1.
#       2 print("Lots of missing data here:\n",my_df[kidney_columns[:14]].head())
# ----> 3 mean_per_column = my_df[kidney_columns[:14]].apply(lambda x: x.mean(),axis = 0)
#       4 print("Mean value per column:\n", mean_per_column)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-74-26fa79cff106> in <lambda>(x)
#       1 #1.
#       2 print("Lots of missing data here:\n",my_df[kidney_columns[:14]].head())
# ----> 3 mean_per_column = my_df[kidney_columns[:14]].apply(lambda x: x.mean(),axis = 0)
#       4 print("Mean value per column:\n", mean_per_column)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    9587                                       skipna=skipna)
#    9588         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9589                             numeric_only=numeric_only)
#    9590
#    9591     return set_function_name(stat_func, name, cls)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3216                                           'numeric_only.'.format(name))
#    3217             with np.errstate(all='ignore'):
# -> 3218                 return op(delegate, skipna=skipna, **kwds)
#    3219
#    3220         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      75             try:
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#      79                 # we want to transform an object array
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     129             except Exception:
#     130                 try:
# --> 131                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     132                 except ValueError as e:
#     133                     # we want to transform an object array
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna)
#     353         dtype_count = dtype
#     354     count = _get_counts(mask, axis, dtype=dtype_count)
# --> 355     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     356
#     357     if axis is not None and getattr(the_sum, 'ndim', False):
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# TypeError: ("unsupported operand type(s) for +: 'int' and 'str'", 'occurred at index rbc')

# %%
#1. cont'd.
numeric_mean_filled = my_df[kidney_columns[:14]].fillna(mean_per_column,axis=0)
numeric_mean_filled.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-b1e364f8b91e> in <module>()
#       1 #1. cont'd.
# ----> 2 numeric_mean_filled = my_df[kidney_columns[:14]].fillna(mean_per_column,axis=0)
#       3 numeric_mean_filled.head()
#
# NameError: name 'mean_per_column' is not defined

# %%
#2.
print(my_df[kidney_columns[:14]].head())
median_per_column = my_df[kidney_columns[:14]].apply(lambda x: x.median(), axis = 0)
print("Median per column:\n", median_per_column)

#2. cont'd.
numeric_median_filled = my_df[kidney_columns[:14]].fillna(median_per_column, axis = 0)
numeric_median_filled.head()

default_value_per_column = my_df[kidney_columns[:14]].fillna(0.0)
default_value_per_column.head()
# Out:
#     age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr    bu   sc    sod  pot
# 0  121.0  36.0  1.2    NaN  NaN
# 1    NaN  18.0  0.8    NaN  NaN
# 2  423.0  53.0  1.8    NaN  NaN
# 3  117.0  56.0  3.8  111.0  2.5
# 4  106.0  26.0  1.4    NaN  NaN
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                 else:
# --> 128                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     129             except Exception:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna)
#     379     if not is_float_dtype(values):
# --> 380         values = values.astype('f8')
#     381         values[mask] = np.nan
#
# ValueError: could not convert string to float: 'normal'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     130                 try:
# --> 131                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     132                 except ValueError as e:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna)
#     379     if not is_float_dtype(values):
# --> 380         values = values.astype('f8')
#     381         values[mask] = np.nan
#
# ValueError: could not convert string to float: 'normal'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-9afd871fb61f> in <module>()
#       1 #2.
#       2 print(my_df[kidney_columns[:14]].head())
# ----> 3 median_per_column = my_df[kidney_columns[:14]].apply(lambda x: x.median(), axis = 0)
#       4 print("Median per column:\n", median_per_column)
#       5
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-76-9afd871fb61f> in <lambda>(x)
#       1 #2.
#       2 print(my_df[kidney_columns[:14]].head())
# ----> 3 median_per_column = my_df[kidney_columns[:14]].apply(lambda x: x.median(), axis = 0)
#       4 print("Median per column:\n", median_per_column)
#       5
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#    9587                                       skipna=skipna)
#    9588         return self._reduce(f, name, axis=axis, skipna=skipna,
# -> 9589                             numeric_only=numeric_only)
#    9590
#    9591     return set_function_name(stat_func, name, cls)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3216                                           'numeric_only.'.format(name))
#    3217             with np.errstate(all='ignore'):
# -> 3218                 return op(delegate, skipna=skipna, **kwds)
#    3219
#    3220         return delegate._reduce(op=op, name=name, axis=axis, skipna=skipna,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      75             try:
#      76                 with np.errstate(invalid='ignore'):
# ---> 77                     return f(*args, **kwargs)
#      78             except ValueError as e:
#      79                 # we want to transform an object array
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     137
#     138                     if is_object_dtype(values):
# --> 139                         raise TypeError(e)
#     140                     raise
#     141
#
# TypeError: (ValueError("could not convert string to float: 'normal'",), 'occurred at index rbc')

# %% [markdown]
# All of these imputation methods will have distinct effects on the performance of your classification model.
#
# Much fancier methods for imputing values, including [EM (expectation maximization)](https://en.wikipedia.org/wiki/Expectation–maximization_algorithm), [multiple imputation](https://en.wikipedia.org/wiki/Imputation_%28statistics%29), etc. exist.
#
# These fancy imputation methods attempt to preserve the statistical relationships among the variables, and "fill in" the most likely values, given the values of all of the other columns (these are "distributional" imputation methods, as they attempt to keep the distributions of the columns as similar as possible after imputation to what they were prior to imputation).
#
# **However, they give really unstable/unreliable results when you have lots of missing data (>10% missing values), so I don't recommend using them when you have a dataset that is missing lots of values.**
#
# Look into these to find out more.
