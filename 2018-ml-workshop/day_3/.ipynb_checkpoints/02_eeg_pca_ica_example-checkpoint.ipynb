# %%
# %matplotlib inline

# %% [markdown]
# # Analysis of evoked response using ICA and PCA reduction techniques
#
#
# This example computes PCA and ICA of evoked or epochs data. Then the
# PCA / ICA components, a.k.a. spatial filters, are used to transform
# the channel data to new sources / virtual channels. The output is
# visualized on the average of all the epochs.

# %%
import numpy as np
import matplotlib.pyplot as plt

import mne
from mne.datasets import sample
from mne.decoding import UnsupervisedSpatialFilter

from sklearn.decomposition import PCA, FastICA

# Preprocess data
data_path = sample.data_path()

# %%
# Load and filter data, set up epochs
raw_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw.fif'
event_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw-eve.fif'
tmin, tmax = -0.1, 0.5 #keep 100 ms before onset to 500ms post-onset
event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)

raw = mne.io.read_raw_fif(raw_fname, preload=True)
raw.filter(1, 20, fir_design='firwin') #only select frequencies between 1-20Hz.
events = mne.read_events(event_fname) #captures what events are associated with what categories

picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads') #removes bad trials

epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True,
                    verbose=False) #generates necessary epoch data for each trial

X = epochs.get_data()
# Out:
# Opening raw data file /Users/suesong/mne_data/MNE-sample-data/MEG/sample/sample_audvis_filt-0-40_raw.fif...
#     Read a total of 4 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#         Average EEG reference (1 x 60)  idle
#     Range : 6450 ... 48149 =     42.956 ...   320.665 secs
# Ready.
# Current compensation grade : 0
# Reading 0 ... 41699  =      0.000 ...   277.709 secs...
# Setting up band-pass filter from 1 - 20 Hz
# l_trans_bandwidth chosen to be 1.0 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 497 samples (3.310 sec) selected

# %%
X.shape #examples,channels,timesteps
# Out:
# (288, 59, 91)

# %%
y = epochs.events[:,-1]

# %% [markdown]
# Transform data with PCA computed on the average ie evoked response

# %%
# spatial reduction 
pca = UnsupervisedSpatialFilter(PCA(30)) #reduce 59 channels down to 30

pca_data = pca.fit_transform(X)
ev = mne.EvokedArray(np.mean(pca_data, axis=0),
                     mne.create_info(30, epochs.info['sfreq'],
                                     ch_types='eeg'), tmin=tmin)

# %%
pca_data.shape
# Out:
# (288, 30, 91)

# %%
ev.data.shape
# Out:
# (30, 91)

# %%
ev.plot(titles="PCA", time_unit='s');

# %% [markdown]
# Transform data with ICA computed on the raw epochs (no averaging)

# %%
ica = UnsupervisedSpatialFilter(FastICA(30), average=False)
ica_data = ica.fit_transform(X)
ev1 = mne.EvokedArray(np.mean(ica_data, axis=0),
                      mne.create_info(30, epochs.info['sfreq'],
                                      ch_types='eeg'), tmin=tmin)

# %%
ev1.data.shape
# Out:
# (30, 91)

# %%
ev1.plot(titles='ICA', time_unit='s');

# %% [markdown]
# ## Classify among 4 event types over time:
#
# ### Compare using all 59 channels for prediction vs. 30 PCA channels vs 30 ICA channels

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from mne.decoding import SlidingEstimator, cross_val_multiscore, LinearModel, get_coef

# %%
clf = make_pipeline(StandardScaler(), LogisticRegression(multi_class="multinomial",solver="lbfgs",max_iter=1000))

time_decod = SlidingEstimator(clf, n_jobs=-1, scoring='accuracy')

scores_allchannels = cross_val_multiscore(time_decod, X, y, cv=10, n_jobs=-1,verbose=0)
scores_pcachannels = cross_val_multiscore(time_decod, pca_data, y, cv=10, n_jobs=-1,verbose=0)
scores_icachannels = cross_val_multiscore(time_decod, ica_data, y, cv=10, n_jobs=-1,verbose=0)
# Out:
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    6.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    5.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:   10.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:   10.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:   11.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:   11.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   16.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   17.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   17.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   17.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   23.9s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   23.9s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   25.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   25.6s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   26.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   26.0s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   26.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   26.8s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    8.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    8.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    8.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    8.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:   16.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:   15.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:   15.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:   15.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   24.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   23.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   24.9s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   25.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   32.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   32.8s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   31.9s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   31.9s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   6 out of  10 | elapsed:   58.0s remaining:   38.7s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   32.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   32.6s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   33.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   33.2s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    6.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    6.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    9.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    9.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   13.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   13.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   18.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   18.6s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   18.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:   18.3s finished
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done  10 out of  10 | elapsed:  1.3min finished
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    3.0s finished
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.5s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.5s finished
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.4s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.5s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   6 out of  10 | elapsed:    6.0s remaining:    4.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    1.9s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    1.9s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done  10 out of  10 | elapsed:    8.0s finished
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# /anaconda3/envs/py36/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py:547: UserWarning: Multiprocessing-backed parallel loops cannot be nested, setting n_jobs=1
#   **self._backend_args)
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    3.0s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.9s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    3.0s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.9s finished
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.9s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    3.0s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.7s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s finished
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.8s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done   6 out of  10 | elapsed:    6.4s remaining:    4.3s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.1s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.1s finished
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Done  10 out of  10 | elapsed:    8.7s finished

# %%
# Mean scores across cross-validation splits per channel selection technique
scores_allchannels = np.mean(scores_allchannels, axis=0)
scores_pcachannels = np.mean(scores_pcachannels, axis=0)
scores_icachannels = np.mean(scores_icachannels, axis=0)

# %%
# Plot
fig, ax = plt.subplots()
ax.plot(epochs.times, scores_allchannels, label='using all channels')
ax.plot(epochs.times, scores_pcachannels, label='using pca channels')
ax.plot(epochs.times, scores_icachannels, label='using ica channels')
ax.axhline(.25, color='k', linestyle='--', label='chance')
ax.set_xlabel('Times')
ax.set_ylabel('Accuracy')  # Area Under the Curve
ax.legend()
ax.axvline(.0, color='k', linestyle='-')
ax.set_title('Sensor space decoding: All Channels, PCA, ICA')
plt.show()

# %%
# You can retrieve the spatial filters and spatial patterns if you explicitly
# wrap the LR in a LinearModel object
clf = make_pipeline(StandardScaler(), LinearModel(LogisticRegression(multi_class="multinomial",
                                                                     solver="lbfgs",
                                                                     max_iter=1000)))
time_decod = SlidingEstimator(clf, n_jobs=-1, scoring='accuracy')
time_decod.fit(X, y)

coef = get_coef(time_decod, 'patterns_', inverse_transform=True)
# Out:
# [Parallel(n_jobs=4)]: Done   2 out of   4 | elapsed:    2.7s remaining:    2.7s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.9s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done   4 out of   4 | elapsed:    2.9s finished

# %%
joint_kwargs = dict(ts_args=dict(time_unit='s'),
                    topomap_args=dict(time_unit='s'))

evoked_coef0 = mne.EvokedArray(coef[:,0,:], epochs.info, tmin=epochs.times[0])
evoked_coef0.plot_joint(times=np.arange(-.100, .500, .100), title='patterns_coef0',
                  **joint_kwargs);

# %%
evoked_coef1 = mne.EvokedArray(coef[:,1,:], epochs.info, tmin=epochs.times[0])
evoked_coef1.plot_joint(times=np.arange(-.100, .500, .100), title='patterns_coef1',
                  **joint_kwargs);

# %%
evoked_coef2 = mne.EvokedArray(coef[:,2,:], epochs.info, tmin=epochs.times[0])
evoked_coef2.plot_joint(times=np.arange(-.100, .500, .100), title='patterns_coef2',
                  **joint_kwargs);

# %%
evoked_coef3 = mne.EvokedArray(coef[:,3,:], epochs.info, tmin=epochs.times[0])
evoked_coef1.plot_joint(times=np.arange(-.100, .500, .100), title='patterns_coef3',
                  **joint_kwargs);
